# %% [markdown]
# # PSNR vs Compression Ratio — model size × SZ3 error bound
#
# **Dataset:** Magnetic reconnection 512×512×512 (single-field float32).
#
# **Why sweep the rel-error bound too?**  The model is tiny next to the SZ3 base (100k params ≈ 0.2 MB vs an SZ3 stream of tens–hundreds of MB), so changing the parameter count alone barely moves the total CR.  The knob that actually moves CR is the **SZ3 relative-error bound** — looser bound → smaller SZ3 stream → higher CR but lower base PSNR.
#
# So we sweep `rel_err ∈ [1e-3 … 6e-3]` (spreads CR along x) **and** a few model sizes (separate curves).  Per point:
#
# ```
# CR = original_bytes / (sz_bytes(rel_err) + n_params * 2)   # params stored as bf16
# ```
#
# Result: a family of rate–distortion curves — one per model size — plus the SZ3-only baseline.

# %%
import random, sys, os, copy, time
from pathlib import Path

import numpy as np
import torch
import matplotlib.pyplot as plt

sys.path.append("/home/sam/Halo_Finder/Final_design/base_script")

# Force-reload edited modules so re-running this cell picks up bg_stage.py changes
# WITHOUT restarting the kernel (Jupyter caches modules in sys.modules).
import importlib
import bg_stage
importlib.reload(bg_stage)

from experiment import build_bg_only_cfg, estimate_bg_model_param_bytes
from bg_stage import run_bg_inference, train_bg_only, unwrap_bg_model
from bg_shard import pick_bg_h_under_budget

pysz_dir = "/home/sam/Data_Compression/SZ3/tools/pysz"
if pysz_dir not in sys.path:
    sys.path.append(pysz_dir)
from pysz import SZ

def set_seed(seed=42):
    torch.manual_seed(seed); np.random.seed(seed); random.seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Device: {device} | GPUs: {torch.cuda.device_count()}")
# Out:
# Device: cuda:0 | GPUs: 1

# %%
# ── Paths ─────────────────────────────────────────────────────────────────────
halo_finder_root = Path("/home/sam/Halo_Finder")
raw_path    = (halo_finder_root / "halo_finder_v1/magnetic_reconnection_512x512x512_float32.raw").as_posix()
sz_lib_path = "/home/sam/Data_Compression/SZ3/build/lib64/libSZ3c.so"

# ── Dataset constants ──────────────────────────────────────────────────────────
data_shape  = (512, 512, 512)
TARGET_STEM = "magnetic_reconnection"

# Quick-test downsample: stride>1 shrinks the cube (and re-compresses it) so the
# whole sweep runs fast.  CR is then computed on the shrunk cube — still a valid
# R-D curve, just lower resolution.  Set to 1 for the real full-res study.
SPATIAL_STRIDE = 1

sz_engine = SZ(sz_lib_path)
print("SZ engine loaded")
# Out:
# SZ engine loaded

# %%
def load_gt(stride=1):
    """Load the ground-truth float32 cube once (optionally strided)."""
    vol = np.fromfile(raw_path, dtype=np.float32).reshape(data_shape)
    if stride > 1:
        vol = np.ascontiguousarray(vol[::stride, ::stride, ::stride])
    return vol

def compress_at(vol, rel_err):
    """SZ3-compress `vol` at a relative-error bound; return (Xps, sz_bytes, sz_cr)."""
    b, cr = sz_engine.compress(vol, 1, 0, float(rel_err), 0)
    x_lq  = sz_engine.decompress(b, vol.shape, np.float32).astype(np.float32)
    return [np.asarray(x_lq, np.float32)], int(len(b)), float(cr)

# %%
t0 = time.time()
gt         = load_gt(SPATIAL_STRIDE)
Xs         = [gt]
work_shape = gt.shape
orig_bytes = gt.nbytes

def psnr_from_arrays(target, recon):
    data_range = float(target.max() - target.min())
    if data_range <= 0:
        data_range = 1.0
    mse = float(np.mean((target - recon) ** 2))
    return 100.0 if mse <= 0 else 20.0 * np.log10(data_range) - 10.0 * np.log10(mse)

print(f"Loaded GT in {time.time()-t0:.1f}s | work shape: {work_shape} "
      f"(stride={SPATIAL_STRIDE}) | {orig_bytes/1e6:.1f} MB")
# Out:
# Loaded GT in 0.1s | work shape: (512, 512, 512) (stride=1) | 536.9 MB

# %%
def build_cfg(Xs_in, Xps_in, max_train_time, bg_h, steps_per_epoch,
              lr=1e-4, epochs=200, log_prefix="", patch_size=None):
    if patch_size is None:
        patch_size = Xs_in[0].shape[2]
    cfg = build_bg_only_cfg(
        X_target=Xs_in[0], Xps=Xps_in, max_train_time=max_train_time,
        epochs=epochs, steps_per_epoch=steps_per_epoch, bg_h=bg_h,
        bg_batch=1, bg_patch_size=patch_size, lr=lr,
    )
    cfg.bg_sample_mode   = "sequential"
    cfg.bg_log_prefix    = log_prefix
    cfg.bg_arch          = "spatial"
    cfg.amp              = True
    cfg.amp_dtype        = "bf16"
    cfg.bg_ddp           = False
    cfg.bg_data_parallel = False
    return cfg

def n_params_of(model):
    return int(sum(p.numel() for p in unwrap_bg_model(model).parameters()))

print("Helpers ready")
# Out:
# Helpers ready

# %% [markdown]
# ## Sweep:  rel-error bound  ×  model size
#
# Outer loop = `REL_ERRS` (each value re-compresses the cube with SZ3 → a new base CR / base PSNR).  Inner loop = `PARAM_TARGETS` (each mapped to a `bg_h` via `pick_bg_h_under_budget`).  `lr` is fixed; each model trains for `TIME_PER_CONFIG` s for the full budget (no early-stop — fair ablation).
#
# **Total trainings = len(REL_ERRS) × #distinct model sizes** — keep both lists short for full-res 512³, or use `SPATIAL_STRIDE>1` first to smoke-test the shape of the curves.

# %%
# ── Fixed knobs ───────────────────────────────────────────────────────────────
FIXED_LR        = 1e-3
TIME_PER_CONFIG = 60.0          # fixed wall-clock budget per model (no early-stop)
BYTES_PER_PARAM = 2             # bf16 storage for the model weights
FREQ_WARMUP     = 1            # epochs before the FFT/freq loss term joins the loss

# Outer sweep: SZ3 relative-error bound (this is what actually moves CR)
REL_ERRS = [1e-3, 2e-3, 3e-3, 4e-3, 5e-3, 6e-3]

# Inner sweep: model parameter budgets (separate curves)
PARAM_TARGETS = [3000, 10000, 30000, 100000]
H_CANDIDATES  = list(range(3, 80))

# Map each budget -> largest bg_h that fits; dedupe (several budgets may share a bg_h)
_seen = set()
sweep_plan = []          # list of (bg_h, est_params)
for tgt in PARAM_TARGETS:
    h, est_p = pick_bg_h_under_budget(
        tgt, shape=work_shape, n_fields=1,
        bg_arch="spatial", h_candidates=H_CANDIDATES,
    )
    if h not in _seen:
        _seen.add(h)
        sweep_plan.append((int(h), int(est_p)))
sweep_plan.sort()

n_runs = len(REL_ERRS) * len(sweep_plan)
print(f"Fixed: lr={FIXED_LR:.1e} | direction=Z | {TIME_PER_CONFIG:.0f}s/config | "
      f"freq_warmup={FREQ_WARMUP}")
print(f"REL_ERRS: {REL_ERRS}")
print(f"Model sizes ({len(sweep_plan)} distinct):")
for h, est_p in sweep_plan:
    print(f"  bg_h={h:2d}  ~{est_p:,} params")
print(f"\n>> {n_runs} trainings total (~{n_runs*TIME_PER_CONFIG/60:.0f} min "
      f"at {TIME_PER_CONFIG:.0f}s each)")
# Out:
# [Model: spatial] Total Params: 724
#  [Params] Main (BG) Network : 724 parameters
#
# [Model: spatial] Total Params: 1,216
#  [Params] Main (BG) Network : 1,216 parameters
#
# [Model: spatial] Total Params: 1,834
#  [Params] Main (BG) Network : 1,834 parameters
#
# [Model: spatial] Total Params: 2,578
#  [Params] Main (BG) Network : 2,578 parameters
#
# [Model: spatial] Total Params: 3,448
#  [Params] Main (BG) Network : 3,448 parameters
#
# [Model: spatial] Total Params: 4,444
#  [Params] Main (BG) Network : 4,444 parameters
#
# [Model: spatial] Total Params: 5,566
#  [Params] Main (BG) Network : 5,566 parameters
#
# [Model: spatial] Total Params: 6,814
#  [Params] Main (BG) Network : 6,814 parameters
#
# [Model: spatial] Total Params: 8,188
#  [Params] Main (BG) Network : 8,188 parameters
#
# [Model: spatial] Total Params: 9,688
#  [Params] Main (BG) Network : 9,688 parameters
#
# [Model: spatial] Total Params: 11,314
#  [Params] Main (BG) Network : 11,314 parameters
#
# [Model: spatial] Total Params: 13,066
#  [Params] Main (BG) Network : 13,066 parameters
#
# [Model: spatial] Total Params: 14,944
#  [Params] Main (BG) Network : 14,944 parameters
#
# [Model: spatial] Total Params: 16,948
#  [Params] Main (BG) Network : 16,948 parameters
#
# [Model: spatial] Total Params: 19,078
#  [Params] Main (BG) Network : 19,078 parameters
#
# [Model: spatial] Total Params: 21,334
#  [Params] Main (BG) Network : 21,334 parameters
#
# [Model: spatial] Total Params: 23,716
#  [Params] Main (BG) Network : 23,716 parameters
#
# [Model: spatial] Total Params: 26,224
#  [Params] Main (BG) Network : 26,224 parameters
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
#
# [Model: spatial] Total Params: 31,618
#  [Params] Main (BG) Network : 31,618 parameters
#
# [Model: spatial] Total Params: 34,504
#  [Params] Main (BG) Network : 34,504 parameters
#
# [Model: spatial] Total Params: 37,516
#  [Params] Main (BG) Network : 37,516 parameters
#
# [Model: spatial] Total Params: 40,654
#  [Params] Main (BG) Network : 40,654 parameters
#
# [Model: spatial] Total Params: 43,918
#  [Params] Main (BG) Network : 43,918 parameters
#
# [Model: spatial] Total Params: 47,308
#  [Params] Main (BG) Network : 47,308 parameters
#
# [Model: spatial] Total Params: 50,824
#  [Params] Main (BG) Network : 50,824 parameters
#
# [Model: spatial] Total Params: 54,466
#  [Params] Main (BG) Network : 54,466 parameters
#
# [Model: spatial] Total Params: 58,234
#  [Params] Main (BG) Network : 58,234 parameters
#
# [Model: spatial] Total Params: 62,128
#  [Params] Main (BG) Network : 62,128 parameters
#
# [Model: spatial] Total Params: 66,148
#  [Params] Main (BG) Network : 66,148 parameters
#
# [Model: spatial] Total Params: 70,294
#  [Params] Main (BG) Network : 70,294 parameters
#
# [Model: spatial] Total Params: 74,566
#  [Params] Main (BG) Network : 74,566 parameters
#
# [Model: spatial] Total Params: 78,964
#  [Params] Main (BG) Network : 78,964 parameters
#
# [Model: spatial] Total Params: 83,488
#  [Params] Main (BG) Network : 83,488 parameters
#
# [Model: spatial] Total Params: 88,138
#  [Params] Main (BG) Network : 88,138 parameters
#
# [Model: spatial] Total Params: 92,914
#  [Params] Main (BG) Network : 92,914 parameters
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
#
# [Model: spatial] Total Params: 102,844
#  [Params] Main (BG) Network : 102,844 parameters
#
# [Model: spatial] Total Params: 107,998
#  [Params] Main (BG) Network : 107,998 parameters
#
# [Model: spatial] Total Params: 113,278
#  [Params] Main (BG) Network : 113,278 parameters
#
# [Model: spatial] Total Params: 118,684
#  [Params] Main (BG) Network : 118,684 parameters
#
# [Model: spatial] Total Params: 124,216
#  [Params] Main (BG) Network : 124,216 parameters
#
# [Model: spatial] Total Params: 129,874
#  [Params] Main (BG) Network : 129,874 parameters
#
# [Model: spatial] Total Params: 135,658
#  [Params] Main (BG) Network : 135,658 parameters
#
# [Model: spatial] Total Params: 141,568
#  [Params] Main (BG) Network : 141,568 parameters
#
# [Model: spatial] Total Params: 147,604
#  [Params] Main (BG) Network : 147,604 parameters
#
# [Model: spatial] Total Params: 153,766
#  [Params] Main (BG) Network : 153,766 parameters
#
# [Model: spatial] Total Params: 160,054
#  [Params] Main (BG) Network : 160,054 parameters
#
# [Model: spatial] Total Params: 166,468
#  [Params] Main (BG) Network : 166,468 parameters
#
# [Model: spatial] Total Params: 173,008
#  [Params] Main (BG) Network : 173,008 parameters
#
# [Model: spatial] Total Params: 179,674
#  [Params] Main (BG) Network : 179,674 parameters
#
# [Model: spatial] Total Params: 186,466
#  [Params] Main (BG) Network : 186,466 parameters
#
# [Model: spatial] Total Params: 193,384
#  [Params] Main (BG) Network : 193,384 parameters
#
# [Model: spatial] Total Params: 200,428
#  [Params] Main (BG) Network : 200,428 parameters
#
# [Model: spatial] Total Params: 207,598
#  [Params] Main (BG) Network : 207,598 parameters
#
# [Model: spatial] Total Params: 214,894
#  [Params] Main (BG) Network : 214,894 parameters
#
# [Model: spatial] Total Params: 222,316
#  [Params] Main (BG) Network : 222,316 parameters
#
# [Model: spatial] Total Params: 229,864
#  [Params] Main (BG) Network : 229,864 parameters
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
#
# [Model: spatial] Total Params: 245,338
#  [Params] Main (BG) Network : 245,338 parameters
#
# [Model: spatial] Total Params: 253,264
#  [Params] Main (BG) Network : 253,264 parameters
#
# [Model: spatial] Total Params: 261,316
#  [Params] Main (BG) Network : 261,316 parameters
#
# [Model: spatial] Total Params: 269,494
#  [Params] Main (BG) Network : 269,494 parameters
#
# [Model: spatial] Total Params: 277,798
#  [Params] Main (BG) Network : 277,798 parameters
#
# [Model: spatial] Total Params: 286,228
#  [Params] Main (BG) Network : 286,228 parameters
#
# [Model: spatial] Total Params: 294,784
#  [Params] Main (BG) Network : 294,784 parameters
#
# [Model: spatial] Total Params: 303,466
#  [Params] Main (BG) Network : 303,466 parameters
#
# [Model: spatial] Total Params: 312,274
#  [Params] Main (BG) Network : 312,274 parameters
#
# [Model: spatial] Total Params: 321,208
#  [Params] Main (BG) Network : 321,208 parameters
#
# [Model: spatial] Total Params: 330,268
#  [Params] Main (BG) Network : 330,268 parameters
#
# [Model: spatial] Total Params: 339,454
#  [Params] Main (BG) Network : 339,454 parameters
#
# [Model: spatial] Total Params: 348,766
#  [Params] Main (BG) Network : 348,766 parameters
#
# [Model: spatial] Total Params: 358,204
#  [Params] Main (BG) Network : 358,204 parameters
#
# [Model: spatial] Total Params: 367,768
#  [Params] Main (BG) Network : 367,768 parameters
#
# [Model: spatial] Total Params: 377,458
#  [Params] Main (BG) Network : 377,458 parameters
#
# [Model: spatial] Total Params: 387,274
#  [Params] Main (BG) Network : 387,274 parameters
#
# [Model: spatial] Total Params: 397,216
#  [Params] Main (BG) Network : 397,216 parameters
#
# [Model: spatial] Total Params: 724
#  [Params] Main (BG) Network : 724 parameters
#
# [Model: spatial] Total Params: 1,216
#  [Params] Main (BG) Network : 1,216 parameters
#
# [Model: spatial] Total Params: 1,834
#  [Params] Main (BG) Network : 1,834 parameters
#
# [Model: spatial] Total Params: 2,578
#  [Params] Main (BG) Network : 2,578 parameters
#
# [Model: spatial] Total Params: 3,448
#  [Params] Main (BG) Network : 3,448 parameters
#
# [Model: spatial] Total Params: 4,444
#  [Params] Main (BG) Network : 4,444 parameters
#
# [Model: spatial] Total Params: 5,566
#  [Params] Main (BG) Network : 5,566 parameters
#
# [Model: spatial] Total Params: 6,814
#  [Params] Main (BG) Network : 6,814 parameters
#
# [Model: spatial] Total Params: 8,188
#  [Params] Main (BG) Network : 8,188 parameters
#
# [Model: spatial] Total Params: 9,688
#  [Params] Main (BG) Network : 9,688 parameters
#
# [Model: spatial] Total Params: 11,314
#  [Params] Main (BG) Network : 11,314 parameters
#
# [Model: spatial] Total Params: 13,066
#  [Params] Main (BG) Network : 13,066 parameters
#
# [Model: spatial] Total Params: 14,944
#  [Params] Main (BG) Network : 14,944 parameters
#
# [Model: spatial] Total Params: 16,948
#  [Params] Main (BG) Network : 16,948 parameters
#
# [Model: spatial] Total Params: 19,078
#  [Params] Main (BG) Network : 19,078 parameters
#
# [Model: spatial] Total Params: 21,334
#  [Params] Main (BG) Network : 21,334 parameters
#
# [Model: spatial] Total Params: 23,716
#  [Params] Main (BG) Network : 23,716 parameters
#
# [Model: spatial] Total Params: 26,224
#  [Params] Main (BG) Network : 26,224 parameters
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
#
# [Model: spatial] Total Params: 31,618
#  [Params] Main (BG) Network : 31,618 parameters
#
# [Model: spatial] Total Params: 34,504
#  [Params] Main (BG) Network : 34,504 parameters
#
# [Model: spatial] Total Params: 37,516
#  [Params] Main (BG) Network : 37,516 parameters
#
# [Model: spatial] Total Params: 40,654
#  [Params] Main (BG) Network : 40,654 parameters
#
# [Model: spatial] Total Params: 43,918
#  [Params] Main (BG) Network : 43,918 parameters
#
# [Model: spatial] Total Params: 47,308
#  [Params] Main (BG) Network : 47,308 parameters
#
# [Model: spatial] Total Params: 50,824
#  [Params] Main (BG) Network : 50,824 parameters
#
# [Model: spatial] Total Params: 54,466
#  [Params] Main (BG) Network : 54,466 parameters
#
# [Model: spatial] Total Params: 58,234
#  [Params] Main (BG) Network : 58,234 parameters
#
# [Model: spatial] Total Params: 62,128
#  [Params] Main (BG) Network : 62,128 parameters
#
# [Model: spatial] Total Params: 66,148
#  [Params] Main (BG) Network : 66,148 parameters
#
# [Model: spatial] Total Params: 70,294
#  [Params] Main (BG) Network : 70,294 parameters
#
# [Model: spatial] Total Params: 74,566
#  [Params] Main (BG) Network : 74,566 parameters
#
# [Model: spatial] Total Params: 78,964
#  [Params] Main (BG) Network : 78,964 parameters
#
# [Model: spatial] Total Params: 83,488
#  [Params] Main (BG) Network : 83,488 parameters
#
# [Model: spatial] Total Params: 88,138
#  [Params] Main (BG) Network : 88,138 parameters
#
# [Model: spatial] Total Params: 92,914
#  [Params] Main (BG) Network : 92,914 parameters
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
#
# [Model: spatial] Total Params: 102,844
#  [Params] Main (BG) Network : 102,844 parameters
#
# [Model: spatial] Total Params: 107,998
#  [Params] Main (BG) Network : 107,998 parameters
#
# [Model: spatial] Total Params: 113,278
#  [Params] Main (BG) Network : 113,278 parameters
#
# [Model: spatial] Total Params: 118,684
#  [Params] Main (BG) Network : 118,684 parameters
#
# [Model: spatial] Total Params: 124,216
#  [Params] Main (BG) Network : 124,216 parameters
#
# [Model: spatial] Total Params: 129,874
#  [Params] Main (BG) Network : 129,874 parameters
#
# [Model: spatial] Total Params: 135,658
#  [Params] Main (BG) Network : 135,658 parameters
#
# [Model: spatial] Total Params: 141,568
#  [Params] Main (BG) Network : 141,568 parameters
#
# [Model: spatial] Total Params: 147,604
#  [Params] Main (BG) Network : 147,604 parameters
#
# [Model: spatial] Total Params: 153,766
#  [Params] Main (BG) Network : 153,766 parameters
#
# [Model: spatial] Total Params: 160,054
#  [Params] Main (BG) Network : 160,054 parameters
#
# [Model: spatial] Total Params: 166,468
#  [Params] Main (BG) Network : 166,468 parameters
#
# [Model: spatial] Total Params: 173,008
#  [Params] Main (BG) Network : 173,008 parameters
#
# [Model: spatial] Total Params: 179,674
#  [Params] Main (BG) Network : 179,674 parameters
#
# [Model: spatial] Total Params: 186,466
#  [Params] Main (BG) Network : 186,466 parameters
#
# [Model: spatial] Total Params: 193,384
#  [Params] Main (BG) Network : 193,384 parameters
#
# [Model: spatial] Total Params: 200,428
#  [Params] Main (BG) Network : 200,428 parameters
#
# [Model: spatial] Total Params: 207,598
#  [Params] Main (BG) Network : 207,598 parameters
#
# [Model: spatial] Total Params: 214,894
#  [Params] Main (BG) Network : 214,894 parameters
#
# [Model: spatial] Total Params: 222,316
#  [Params] Main (BG) Network : 222,316 parameters
#
# [Model: spatial] Total Params: 229,864
#  [Params] Main (BG) Network : 229,864 parameters
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
#
# [Model: spatial] Total Params: 245,338
#  [Params] Main (BG) Network : 245,338 parameters
#
# [Model: spatial] Total Params: 253,264
#  [Params] Main (BG) Network : 253,264 parameters
#
# [Model: spatial] Total Params: 261,316
#  [Params] Main (BG) Network : 261,316 parameters
#
# [Model: spatial] Total Params: 269,494
#  [Params] Main (BG) Network : 269,494 parameters
#
# [Model: spatial] Total Params: 277,798
#  [Params] Main (BG) Network : 277,798 parameters
#
# [Model: spatial] Total Params: 286,228
#  [Params] Main (BG) Network : 286,228 parameters
#
# [Model: spatial] Total Params: 294,784
#  [Params] Main (BG) Network : 294,784 parameters
#
# [Model: spatial] Total Params: 303,466
#  [Params] Main (BG) Network : 303,466 parameters
#
# [Model: spatial] Total Params: 312,274
#  [Params] Main (BG) Network : 312,274 parameters
#
# [Model: spatial] Total Params: 321,208
#  [Params] Main (BG) Network : 321,208 parameters
#
# [Model: spatial] Total Params: 330,268
#  [Params] Main (BG) Network : 330,268 parameters
#
# [Model: spatial] Total Params: 339,454
#  [Params] Main (BG) Network : 339,454 parameters
#
# [Model: spatial] Total Params: 348,766
#  [Params] Main (BG) Network : 348,766 parameters
#
# [Model: spatial] Total Params: 358,204
#  [Params] Main (BG) Network : 358,204 parameters
#
# [Model: spatial] Total Params: 367,768
#  [Params] Main (BG) Network : 367,768 parameters
#
# [Model: spatial] Total Params: 377,458
#  [Params] Main (BG) Network : 377,458 parameters
#
# [Model: spatial] Total Params: 387,274
#  [Params] Main (BG) Network : 387,274 parameters
#
# [Model: spatial] Total Params: 397,216
#  [Params] Main (BG) Network : 397,216 parameters
#
# [Model: spatial] Total Params: 724
#  [Params] Main (BG) Network : 724 parameters
#
# [Model: spatial] Total Params: 1,216
#  [Params] Main (BG) Network : 1,216 parameters
#
# [Model: spatial] Total Params: 1,834
#  [Params] Main (BG) Network : 1,834 parameters
#
# [Model: spatial] Total Params: 2,578
#  [Params] Main (BG) Network : 2,578 parameters
#
# [Model: spatial] Total Params: 3,448
#  [Params] Main (BG) Network : 3,448 parameters
#
# [Model: spatial] Total Params: 4,444
#  [Params] Main (BG) Network : 4,444 parameters
#
# [Model: spatial] Total Params: 5,566
#  [Params] Main (BG) Network : 5,566 parameters
#
# [Model: spatial] Total Params: 6,814
#  [Params] Main (BG) Network : 6,814 parameters
#
# [Model: spatial] Total Params: 8,188
#  [Params] Main (BG) Network : 8,188 parameters
#
# [Model: spatial] Total Params: 9,688
#  [Params] Main (BG) Network : 9,688 parameters
#
# [Model: spatial] Total Params: 11,314
#  [Params] Main (BG) Network : 11,314 parameters
#
# [Model: spatial] Total Params: 13,066
#  [Params] Main (BG) Network : 13,066 parameters
#
# [Model: spatial] Total Params: 14,944
#  [Params] Main (BG) Network : 14,944 parameters
#
# [Model: spatial] Total Params: 16,948
#  [Params] Main (BG) Network : 16,948 parameters
#
# [Model: spatial] Total Params: 19,078
#  [Params] Main (BG) Network : 19,078 parameters
#
# [Model: spatial] Total Params: 21,334
#  [Params] Main (BG) Network : 21,334 parameters
#
# [Model: spatial] Total Params: 23,716
#  [Params] Main (BG) Network : 23,716 parameters
#
# [Model: spatial] Total Params: 26,224
#  [Params] Main (BG) Network : 26,224 parameters
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
#
# [Model: spatial] Total Params: 31,618
#  [Params] Main (BG) Network : 31,618 parameters
#
# [Model: spatial] Total Params: 34,504
#  [Params] Main (BG) Network : 34,504 parameters
#
# [Model: spatial] Total Params: 37,516
#  [Params] Main (BG) Network : 37,516 parameters
#
# [Model: spatial] Total Params: 40,654
#  [Params] Main (BG) Network : 40,654 parameters
#
# [Model: spatial] Total Params: 43,918
#  [Params] Main (BG) Network : 43,918 parameters
#
# [Model: spatial] Total Params: 47,308
#  [Params] Main (BG) Network : 47,308 parameters
#
# [Model: spatial] Total Params: 50,824
#  [Params] Main (BG) Network : 50,824 parameters
#
# [Model: spatial] Total Params: 54,466
#  [Params] Main (BG) Network : 54,466 parameters
#
# [Model: spatial] Total Params: 58,234
#  [Params] Main (BG) Network : 58,234 parameters
#
# [Model: spatial] Total Params: 62,128
#  [Params] Main (BG) Network : 62,128 parameters
#
# [Model: spatial] Total Params: 66,148
#  [Params] Main (BG) Network : 66,148 parameters
#
# [Model: spatial] Total Params: 70,294
#  [Params] Main (BG) Network : 70,294 parameters
#
# [Model: spatial] Total Params: 74,566
#  [Params] Main (BG) Network : 74,566 parameters
#
# [Model: spatial] Total Params: 78,964
#  [Params] Main (BG) Network : 78,964 parameters
#
# [Model: spatial] Total Params: 83,488
#  [Params] Main (BG) Network : 83,488 parameters
#
# [Model: spatial] Total Params: 88,138
#  [Params] Main (BG) Network : 88,138 parameters
#
# [Model: spatial] Total Params: 92,914
#  [Params] Main (BG) Network : 92,914 parameters
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
#
# [Model: spatial] Total Params: 102,844
#  [Params] Main (BG) Network : 102,844 parameters
#
# [Model: spatial] Total Params: 107,998
#  [Params] Main (BG) Network : 107,998 parameters
#
# [Model: spatial] Total Params: 113,278
#  [Params] Main (BG) Network : 113,278 parameters
#
# [Model: spatial] Total Params: 118,684
#  [Params] Main (BG) Network : 118,684 parameters
#
# [Model: spatial] Total Params: 124,216
#  [Params] Main (BG) Network : 124,216 parameters
#
# [Model: spatial] Total Params: 129,874
#  [Params] Main (BG) Network : 129,874 parameters
#
# [Model: spatial] Total Params: 135,658
#  [Params] Main (BG) Network : 135,658 parameters
#
# [Model: spatial] Total Params: 141,568
#  [Params] Main (BG) Network : 141,568 parameters
#
# [Model: spatial] Total Params: 147,604
#  [Params] Main (BG) Network : 147,604 parameters
#
# [Model: spatial] Total Params: 153,766
#  [Params] Main (BG) Network : 153,766 parameters
#
# [Model: spatial] Total Params: 160,054
#  [Params] Main (BG) Network : 160,054 parameters
#
# [Model: spatial] Total Params: 166,468
#  [Params] Main (BG) Network : 166,468 parameters
#
# [Model: spatial] Total Params: 173,008
#  [Params] Main (BG) Network : 173,008 parameters
#
# [Model: spatial] Total Params: 179,674
#  [Params] Main (BG) Network : 179,674 parameters
#
# [Model: spatial] Total Params: 186,466
#  [Params] Main (BG) Network : 186,466 parameters
#
# [Model: spatial] Total Params: 193,384
#  [Params] Main (BG) Network : 193,384 parameters
#
# [Model: spatial] Total Params: 200,428
#  [Params] Main (BG) Network : 200,428 parameters
#
# [Model: spatial] Total Params: 207,598
#  [Params] Main (BG) Network : 207,598 parameters
#
# [Model: spatial] Total Params: 214,894
#  [Params] Main (BG) Network : 214,894 parameters
#
# [Model: spatial] Total Params: 222,316
#  [Params] Main (BG) Network : 222,316 parameters
#
# [Model: spatial] Total Params: 229,864
#  [Params] Main (BG) Network : 229,864 parameters
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
#
# [Model: spatial] Total Params: 245,338
#  [Params] Main (BG) Network : 245,338 parameters
#
# [Model: spatial] Total Params: 253,264
#  [Params] Main (BG) Network : 253,264 parameters
#
# [Model: spatial] Total Params: 261,316
#  [Params] Main (BG) Network : 261,316 parameters
#
# [Model: spatial] Total Params: 269,494
#  [Params] Main (BG) Network : 269,494 parameters
#
# [Model: spatial] Total Params: 277,798
#  [Params] Main (BG) Network : 277,798 parameters
#
# [Model: spatial] Total Params: 286,228
#  [Params] Main (BG) Network : 286,228 parameters
#
# [Model: spatial] Total Params: 294,784
#  [Params] Main (BG) Network : 294,784 parameters
#
# [Model: spatial] Total Params: 303,466
#  [Params] Main (BG) Network : 303,466 parameters
#
# [Model: spatial] Total Params: 312,274
#  [Params] Main (BG) Network : 312,274 parameters
#
# [Model: spatial] Total Params: 321,208
#  [Params] Main (BG) Network : 321,208 parameters
#
# [Model: spatial] Total Params: 330,268
#  [Params] Main (BG) Network : 330,268 parameters
#
# [Model: spatial] Total Params: 339,454
#  [Params] Main (BG) Network : 339,454 parameters
#
# [Model: spatial] Total Params: 348,766
#  [Params] Main (BG) Network : 348,766 parameters
#
# [Model: spatial] Total Params: 358,204
#  [Params] Main (BG) Network : 358,204 parameters
#
# [Model: spatial] Total Params: 367,768
#  [Params] Main (BG) Network : 367,768 parameters
#
# [Model: spatial] Total Params: 377,458
#  [Params] Main (BG) Network : 377,458 parameters
#
# [Model: spatial] Total Params: 387,274
#  [Params] Main (BG) Network : 387,274 parameters
#
# [Model: spatial] Total Params: 397,216
#  [Params] Main (BG) Network : 397,216 parameters
#
# [Model: spatial] Total Params: 724
#  [Params] Main (BG) Network : 724 parameters
#
# [Model: spatial] Total Params: 1,216
#  [Params] Main (BG) Network : 1,216 parameters
#
# [Model: spatial] Total Params: 1,834
#  [Params] Main (BG) Network : 1,834 parameters
#
# [Model: spatial] Total Params: 2,578
#  [Params] Main (BG) Network : 2,578 parameters
#
# [Model: spatial] Total Params: 3,448
#  [Params] Main (BG) Network : 3,448 parameters
#
# [Model: spatial] Total Params: 4,444
#  [Params] Main (BG) Network : 4,444 parameters
#
# [Model: spatial] Total Params: 5,566
#  [Params] Main (BG) Network : 5,566 parameters
#
# [Model: spatial] Total Params: 6,814
#  [Params] Main (BG) Network : 6,814 parameters
#
# [Model: spatial] Total Params: 8,188
#  [Params] Main (BG) Network : 8,188 parameters
#
# [Model: spatial] Total Params: 9,688
#  [Params] Main (BG) Network : 9,688 parameters
#
# [Model: spatial] Total Params: 11,314
#  [Params] Main (BG) Network : 11,314 parameters
#
# [Model: spatial] Total Params: 13,066
#  [Params] Main (BG) Network : 13,066 parameters
#
# [Model: spatial] Total Params: 14,944
#  [Params] Main (BG) Network : 14,944 parameters
#
# [Model: spatial] Total Params: 16,948
#  [Params] Main (BG) Network : 16,948 parameters
#
# [Model: spatial] Total Params: 19,078
#  [Params] Main (BG) Network : 19,078 parameters
#
# [Model: spatial] Total Params: 21,334
#  [Params] Main (BG) Network : 21,334 parameters
#
# [Model: spatial] Total Params: 23,716
#  [Params] Main (BG) Network : 23,716 parameters
#
# [Model: spatial] Total Params: 26,224
#  [Params] Main (BG) Network : 26,224 parameters
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
#
# [Model: spatial] Total Params: 31,618
#  [Params] Main (BG) Network : 31,618 parameters
#
# [Model: spatial] Total Params: 34,504
#  [Params] Main (BG) Network : 34,504 parameters
#
# [Model: spatial] Total Params: 37,516
#  [Params] Main (BG) Network : 37,516 parameters
#
# [Model: spatial] Total Params: 40,654
#  [Params] Main (BG) Network : 40,654 parameters
#
# [Model: spatial] Total Params: 43,918
#  [Params] Main (BG) Network : 43,918 parameters
#
# [Model: spatial] Total Params: 47,308
#  [Params] Main (BG) Network : 47,308 parameters
#
# [Model: spatial] Total Params: 50,824
#  [Params] Main (BG) Network : 50,824 parameters
#
# [Model: spatial] Total Params: 54,466
#  [Params] Main (BG) Network : 54,466 parameters
#
# [Model: spatial] Total Params: 58,234
#  [Params] Main (BG) Network : 58,234 parameters
#
# [Model: spatial] Total Params: 62,128
#  [Params] Main (BG) Network : 62,128 parameters
#
# [Model: spatial] Total Params: 66,148
#  [Params] Main (BG) Network : 66,148 parameters
#
# [Model: spatial] Total Params: 70,294
#  [Params] Main (BG) Network : 70,294 parameters
#
# [Model: spatial] Total Params: 74,566
#  [Params] Main (BG) Network : 74,566 parameters
#
# [Model: spatial] Total Params: 78,964
#  [Params] Main (BG) Network : 78,964 parameters
#
# [Model: spatial] Total Params: 83,488
#  [Params] Main (BG) Network : 83,488 parameters
#
# [Model: spatial] Total Params: 88,138
#  [Params] Main (BG) Network : 88,138 parameters
#
# [Model: spatial] Total Params: 92,914
#  [Params] Main (BG) Network : 92,914 parameters
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
#
# [Model: spatial] Total Params: 102,844
#  [Params] Main (BG) Network : 102,844 parameters
#
# [Model: spatial] Total Params: 107,998
#  [Params] Main (BG) Network : 107,998 parameters
#
# [Model: spatial] Total Params: 113,278
#  [Params] Main (BG) Network : 113,278 parameters
#
# [Model: spatial] Total Params: 118,684
#  [Params] Main (BG) Network : 118,684 parameters
#
# [Model: spatial] Total Params: 124,216
#  [Params] Main (BG) Network : 124,216 parameters
#
# [Model: spatial] Total Params: 129,874
#  [Params] Main (BG) Network : 129,874 parameters
#
# [Model: spatial] Total Params: 135,658
#  [Params] Main (BG) Network : 135,658 parameters
#
# [Model: spatial] Total Params: 141,568
#  [Params] Main (BG) Network : 141,568 parameters
#
# [Model: spatial] Total Params: 147,604
#  [Params] Main (BG) Network : 147,604 parameters
#
# [Model: spatial] Total Params: 153,766
#  [Params] Main (BG) Network : 153,766 parameters
#
# [Model: spatial] Total Params: 160,054
#  [Params] Main (BG) Network : 160,054 parameters
#
# [Model: spatial] Total Params: 166,468
#  [Params] Main (BG) Network : 166,468 parameters
#
# [Model: spatial] Total Params: 173,008
#  [Params] Main (BG) Network : 173,008 parameters
#
# [Model: spatial] Total Params: 179,674
#  [Params] Main (BG) Network : 179,674 parameters
#
# [Model: spatial] Total Params: 186,466
#  [Params] Main (BG) Network : 186,466 parameters
#
# [Model: spatial] Total Params: 193,384
#  [Params] Main (BG) Network : 193,384 parameters
#
# [Model: spatial] Total Params: 200,428
#  [Params] Main (BG) Network : 200,428 parameters
#
# [Model: spatial] Total Params: 207,598
#  [Params] Main (BG) Network : 207,598 parameters
#
# [Model: spatial] Total Params: 214,894
#  [Params] Main (BG) Network : 214,894 parameters
#
# [Model: spatial] Total Params: 222,316
#  [Params] Main (BG) Network : 222,316 parameters
#
# [Model: spatial] Total Params: 229,864
#  [Params] Main (BG) Network : 229,864 parameters
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
#
# [Model: spatial] Total Params: 245,338
#  [Params] Main (BG) Network : 245,338 parameters
#
# [Model: spatial] Total Params: 253,264
#  [Params] Main (BG) Network : 253,264 parameters
#
# [Model: spatial] Total Params: 261,316
#  [Params] Main (BG) Network : 261,316 parameters
#
# [Model: spatial] Total Params: 269,494
#  [Params] Main (BG) Network : 269,494 parameters
#
# [Model: spatial] Total Params: 277,798
#  [Params] Main (BG) Network : 277,798 parameters
#
# [Model: spatial] Total Params: 286,228
#  [Params] Main (BG) Network : 286,228 parameters
#
# [Model: spatial] Total Params: 294,784
#  [Params] Main (BG) Network : 294,784 parameters
#
# [Model: spatial] Total Params: 303,466
#  [Params] Main (BG) Network : 303,466 parameters
#
# [Model: spatial] Total Params: 312,274
#  [Params] Main (BG) Network : 312,274 parameters
#
# [Model: spatial] Total Params: 321,208
#  [Params] Main (BG) Network : 321,208 parameters
#
# [Model: spatial] Total Params: 330,268
#  [Params] Main (BG) Network : 330,268 parameters
#
# [Model: spatial] Total Params: 339,454
#  [Params] Main (BG) Network : 339,454 parameters
#
# [Model: spatial] Total Params: 348,766
#  [Params] Main (BG) Network : 348,766 parameters
#
# [Model: spatial] Total Params: 358,204
#  [Params] Main (BG) Network : 358,204 parameters
#
# [Model: spatial] Total Params: 367,768
#  [Params] Main (BG) Network : 367,768 parameters
#
# [Model: spatial] Total Params: 377,458
#  [Params] Main (BG) Network : 377,458 parameters
#
# [Model: spatial] Total Params: 387,274
#  [Params] Main (BG) Network : 387,274 parameters
#
# [Model: spatial] Total Params: 397,216
#  [Params] Main (BG) Network : 397,216 parameters
# Fixed: lr=1.0e-03 | direction=Z | 60s/config | freq_warmup=1
# REL_ERRS: [0.001, 0.002, 0.003, 0.004, 0.005, 0.006]
# Model sizes (4 distinct):
#   bg_h= 6  ~2,578 params
#   bg_h=12  ~9,688 params
#   bg_h=21  ~28,858 params
#   bg_h=39  ~97,816 params
#
# >> 24 trainings total (~24 min at 60s each)

# %%
# Reload bg_stage so re-running ONLY this cell picks up early-stop edits.
import importlib, bg_stage
importlib.reload(bg_stage)
from bg_stage import run_bg_inference, train_bg_only, unwrap_bg_model
print(f"bg_stage OK: {bg_stage.__file__}\n")

depth    = work_shape[0]
patch_sz = work_shape[2]

# GPU warm-up (not timed) using the loosest rel_err
_w_Xps, _, _ = compress_at(gt, max(REL_ERRS))
_wcfg = build_cfg(Xs, _w_Xps, max_train_time=0.5, bg_h=4,
                  steps_per_epoch=2, lr=1e-3, epochs=1, log_prefix="warmup")
set_seed(42)
train_bg_only(Xs=Xs, Xps=_w_Xps, device=device, cfg=_wcfg,
              evaluator=lambda m, c=_wcfg: (0.0, 0.0))
torch.cuda.synchronize() if torch.cuda.is_available() else None
del _w_Xps
print("GPU warm-up done\n")

results   = []   # dict: rel, bg_h, n_params, psnr, cr, model_mb, sz_mb, epochs
baselines = []   # dict: rel, cr, psnr, sz_mb   (SZ3 only, no model)

sweep_t0 = time.time()
for rel in REL_ERRS:
    Xps_list, sz_bytes, sz_cr = compress_at(gt, rel)
    base_psnr = psnr_from_arrays(gt, Xps_list[0])
    base_cr   = orig_bytes / sz_bytes
    baselines.append(dict(rel=rel, cr=base_cr, psnr=base_psnr, sz_mb=sz_bytes/1e6))
    print(f"\n{'#'*60}")
    print(f"# rel={rel:.0e} | SZ3 base: CR={base_cr:.2f}x ({sz_bytes/1e6:.2f} MB) | "
          f"base PSNR={base_psnr:.2f} dB")

    for bg_h, est_p in sweep_plan:
        cfg = build_cfg(Xs, Xps_list, max_train_time=TIME_PER_CONFIG, bg_h=bg_h,
                        steps_per_epoch=depth, lr=FIXED_LR, epochs=200,
                        log_prefix=f"r{rel:.0e}-h{bg_h}", patch_size=patch_sz)
        cfg.bg_early_stop          = False   # ablation: train every model the full budget
        cfg.bg_freq_warmup_epochs  = FREQ_WARMUP

        def evaluator(m, c=cfg, Xp=Xps_list):
            xh = run_bg_inference(unwrap_bg_model(m), Xs, Xp, c, rel)
            return psnr_from_arrays(gt, xh), 0.0

        set_seed(42)
        model, hist = train_bg_only(Xs=Xs, Xps=Xps_list, device=device,
                                    cfg=cfg, evaluator=evaluator)

        n_params    = n_params_of(model)
        psnr_vals   = [v[1] if isinstance(v, tuple) else v for v in hist.get("psnr", [])]
        psnr        = max(psnr_vals) if psnr_vals else float("nan")
        model_bytes = n_params * BYTES_PER_PARAM
        cr          = orig_bytes / (sz_bytes + model_bytes)
        results.append(dict(rel=rel, bg_h=bg_h, n_params=n_params, psnr=psnr, cr=cr,
                            model_mb=model_bytes/1e6, sz_mb=sz_bytes/1e6,
                            epochs=len(hist.get("loss", []))))
        print(f"  bg_h={bg_h:2d} ({n_params:,}p): PSNR={psnr:.2f} dB | CR={cr:.2f}x "
              f"(base {base_cr:.2f}x) | +{psnr-base_psnr:.2f} dB over SZ3")
        del model
        torch.cuda.empty_cache() if torch.cuda.is_available() else None

    del Xps_list

print(f"\n--- Sweep complete in {(time.time()-sweep_t0)/60:.1f} min "
      f"({len(results)} models over {len(REL_ERRS)} rel-errors) ---")
# Out:
# bg_stage OK: /home/sam/Halo_Finder/Final_design/base_script/bg_stage.py
#
#
# [Model: spatial] Total Params: 1,216
#  [Params] Main (BG) Network : 1,216 parameters
# warmup [Init] Epoch   0 | Global PSNR: 0.00 dB | MaxErr: 0.0
# warmup [plan] pure_train_budget=0.50s | epochs_cap=1 | steps/epoch=2 | patch=512 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# warmup [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# /home/sam/Halo_Finder/Final_design/base_script/bg_stage.py:471: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp, dtype=autocast_dtype):
# warmup Epoch   1 [BG] | train_wall=0.49s | Loss: 0.056742 | Freq: 3.281250 | Global: 0.00 dB | MaxErr: 0.0
# warmup [timing] first_epoch_pure_train≈0.488s (excludes this epoch's end-of-epoch eval)
#
# warmup --- Experiment [BG_only] finished ---
# warmup --- Pure training time: 0.49 s ---
# warmup [timing] epochs=1 | train_wall/epoch: mean=0.49s min=0.49s max=0.49s | sum=0.49s
# warmup --- Best global PSNR: 0.00 dB ---
# GPU warm-up done
#
#
# ############################################################
# # rel=1e-03 | SZ3 base: CR=40.85x (13.14 MB) | base PSNR=68.32 dB
#
# [Model: spatial] Total Params: 2,578
#  [Params] Main (BG) Network : 2,578 parameters
# r1e-03-h6 [Init] Epoch   0 | Global PSNR: 68.32 dB | MaxErr: 0.0
# r1e-03-h6 [plan] pure_train_budget=60.00s | epochs_cap=200 | steps/epoch=512 | patch=512 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r1e-03-h6 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r1e-03-h6 Epoch   1 [BG] | train_wall=1.88s | Loss: 0.981885 | Freq: 3.151855 | Global: 67.81 dB | MaxErr: 0.0
# r1e-03-h6 [timing] first_epoch_pure_train≈1.880s (excludes this epoch's end-of-epoch eval)
# r1e-03-h6 Epoch   2 [BG] | train_wall=1.89s | Loss: 3.340392 | Freq: 2.417831 | Global: 68.65 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h6 Epoch   3 [BG] | train_wall=1.92s | Loss: 3.246361 | Freq: 2.370132 | Global: 68.71 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h6 Epoch   4 [BG] | train_wall=1.91s | Loss: 3.203854 | Freq: 2.351151 | Global: 68.75 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h6 Epoch   5 [BG] | train_wall=1.91s | Loss: 3.170703 | Freq: 2.335159 | Global: 69.05 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h6 Epoch   6 [BG] | train_wall=1.90s | Loss: 3.150957 | Freq: 2.323914 | Global: 69.02 dB | MaxErr: 0.0
# r1e-03-h6 Epoch   7 [BG] | train_wall=1.91s | Loss: 3.133875 | Freq: 2.315979 | Global: 69.06 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h6 Epoch   8 [BG] | train_wall=1.89s | Loss: 3.125186 | Freq: 2.311203 | Global: 69.14 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h6 Epoch   9 [BG] | train_wall=1.92s | Loss: 3.116721 | Freq: 2.307587 | Global: 69.11 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  10 [BG] | train_wall=1.93s | Loss: 3.110265 | Freq: 2.303894 | Global: 69.09 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  11 [BG] | train_wall=1.86s | Loss: 3.104247 | Freq: 2.301025 | Global: 69.19 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h6 Epoch  12 [BG] | train_wall=1.89s | Loss: 3.101198 | Freq: 2.298691 | Global: 69.19 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h6 Epoch  13 [BG] | train_wall=1.95s | Loss: 3.098922 | Freq: 2.297104 | Global: 68.90 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  14 [BG] | train_wall=1.91s | Loss: 3.097274 | Freq: 2.295898 | Global: 69.01 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  15 [BG] | train_wall=1.88s | Loss: 3.092537 | Freq: 2.294006 | Global: 69.08 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  16 [BG] | train_wall=1.91s | Loss: 3.089960 | Freq: 2.292847 | Global: 68.96 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  17 [BG] | train_wall=1.92s | Loss: 3.088438 | Freq: 2.292068 | Global: 69.14 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  18 [BG] | train_wall=1.88s | Loss: 3.085719 | Freq: 2.290939 | Global: 69.13 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  19 [BG] | train_wall=1.93s | Loss: 3.084257 | Freq: 2.289795 | Global: 69.10 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  20 [BG] | train_wall=1.89s | Loss: 3.083235 | Freq: 2.289215 | Global: 69.02 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  21 [BG] | train_wall=1.91s | Loss: 3.082121 | Freq: 2.288376 | Global: 69.15 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  22 [BG] | train_wall=1.92s | Loss: 3.080656 | Freq: 2.287750 | Global: 69.05 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  23 [BG] | train_wall=1.91s | Loss: 3.079963 | Freq: 2.287643 | Global: 69.09 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  24 [BG] | train_wall=1.89s | Loss: 3.078958 | Freq: 2.286560 | Global: 69.06 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  25 [BG] | train_wall=1.90s | Loss: 3.077648 | Freq: 2.286026 | Global: 69.14 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  26 [BG] | train_wall=1.89s | Loss: 3.076125 | Freq: 2.285858 | Global: 69.07 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  27 [BG] | train_wall=1.89s | Loss: 3.075866 | Freq: 2.285187 | Global: 69.11 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  28 [BG] | train_wall=1.90s | Loss: 3.074406 | Freq: 2.284363 | Global: 69.08 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  29 [BG] | train_wall=1.91s | Loss: 3.073801 | Freq: 2.284042 | Global: 69.10 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  30 [BG] | train_wall=1.88s | Loss: 3.072956 | Freq: 2.283524 | Global: 69.22 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h6 Epoch  31 [BG] | train_wall=1.88s | Loss: 3.072530 | Freq: 2.282852 | Global: 69.15 dB | MaxErr: 0.0
# r1e-03-h6 Epoch  32 [BG] | train_wall=1.03s | Loss: 3.193412 | Freq: 2.303047 | Global: 68.64 dB | MaxErr: 0.0
#
# r1e-03-h6 --- Experiment [BG_only] finished ---
# r1e-03-h6 --- Pure training time: 60.00 s ---
# r1e-03-h6 [timing] epochs=32 | train_wall/epoch: mean=1.87s min=1.03s max=1.95s | sum=59.99s
# r1e-03-h6 --- Best global PSNR: 69.22 dB ---
#   bg_h= 6 (2,578p): PSNR=69.22 dB | CR=40.84x (base 40.85x) | +0.90 dB over SZ3
#
# [Model: spatial] Total Params: 9,688
#  [Params] Main (BG) Network : 9,688 parameters
# r1e-03-h12 [Init] Epoch   0 | Global PSNR: 68.32 dB | MaxErr: 0.0
# r1e-03-h12 [plan] pure_train_budget=60.00s | epochs_cap=200 | steps/epoch=512 | patch=512 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r1e-03-h12 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r1e-03-h12 Epoch   1 [BG] | train_wall=2.09s | Loss: 0.970497 | Freq: 3.262756 | Global: 66.16 dB | MaxErr: 0.0
# r1e-03-h12 [timing] first_epoch_pure_train≈2.088s (excludes this epoch's end-of-epoch eval)
# r1e-03-h12 Epoch   2 [BG] | train_wall=2.09s | Loss: 3.315777 | Freq: 2.393967 | Global: 68.47 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h12 Epoch   3 [BG] | train_wall=2.07s | Loss: 3.208257 | Freq: 2.346848 | Global: 68.76 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h12 Epoch   4 [BG] | train_wall=2.09s | Loss: 3.162756 | Freq: 2.326630 | Global: 68.91 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h12 Epoch   5 [BG] | train_wall=2.06s | Loss: 3.125055 | Freq: 2.312317 | Global: 68.95 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h12 Epoch   6 [BG] | train_wall=2.06s | Loss: 3.107617 | Freq: 2.302582 | Global: 68.95 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h12 Epoch   7 [BG] | train_wall=2.09s | Loss: 3.101258 | Freq: 2.296356 | Global: 68.90 dB | MaxErr: 0.0
# r1e-03-h12 Epoch   8 [BG] | train_wall=2.07s | Loss: 3.089503 | Freq: 2.290894 | Global: 68.95 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h12 Epoch   9 [BG] | train_wall=2.12s | Loss: 3.087645 | Freq: 2.288101 | Global: 68.95 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h12 Epoch  10 [BG] | train_wall=2.09s | Loss: 3.078997 | Freq: 2.285095 | Global: 69.00 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h12 Epoch  11 [BG] | train_wall=2.08s | Loss: 3.073093 | Freq: 2.282059 | Global: 69.10 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h12 Epoch  12 [BG] | train_wall=2.06s | Loss: 3.068502 | Freq: 2.279953 | Global: 69.03 dB | MaxErr: 0.0
# r1e-03-h12 Epoch  13 [BG] | train_wall=2.08s | Loss: 3.067673 | Freq: 2.278366 | Global: 68.94 dB | MaxErr: 0.0
# r1e-03-h12 Epoch  14 [BG] | train_wall=2.08s | Loss: 3.062726 | Freq: 2.276794 | Global: 69.09 dB | MaxErr: 0.0
# r1e-03-h12 Epoch  15 [BG] | train_wall=2.09s | Loss: 3.061406 | Freq: 2.275345 | Global: 69.02 dB | MaxErr: 0.0
# r1e-03-h12 Epoch  16 [BG] | train_wall=2.07s | Loss: 3.058316 | Freq: 2.274536 | Global: 69.02 dB | MaxErr: 0.0
# r1e-03-h12 Epoch  17 [BG] | train_wall=2.09s | Loss: 3.060549 | Freq: 2.273422 | Global: 69.12 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h12 Epoch  18 [BG] | train_wall=2.09s | Loss: 3.056034 | Freq: 2.271896 | Global: 69.10 dB | MaxErr: 0.0
# r1e-03-h12 Epoch  19 [BG] | train_wall=2.09s | Loss: 3.052198 | Freq: 2.271042 | Global: 69.02 dB | MaxErr: 0.0
# r1e-03-h12 Epoch  20 [BG] | train_wall=2.10s | Loss: 3.052929 | Freq: 2.269775 | Global: 69.05 dB | MaxErr: 0.0
# r1e-03-h12 Epoch  21 [BG] | train_wall=2.09s | Loss: 3.050992 | Freq: 2.269562 | Global: 69.16 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h12 Epoch  22 [BG] | train_wall=2.09s | Loss: 3.048801 | Freq: 2.268417 | Global: 69.27 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h12 Epoch  23 [BG] | train_wall=2.10s | Loss: 3.049410 | Freq: 2.267944 | Global: 68.87 dB | MaxErr: 0.0
# r1e-03-h12 Epoch  24 [BG] | train_wall=2.09s | Loss: 3.045247 | Freq: 2.266174 | Global: 69.04 dB | MaxErr: 0.0
# r1e-03-h12 Epoch  25 [BG] | train_wall=2.10s | Loss: 3.044190 | Freq: 2.265930 | Global: 69.06 dB | MaxErr: 0.0
# r1e-03-h12 Epoch  26 [BG] | train_wall=2.10s | Loss: 3.042552 | Freq: 2.265442 | Global: 68.95 dB | MaxErr: 0.0
# r1e-03-h12 Epoch  27 [BG] | train_wall=2.09s | Loss: 3.041678 | Freq: 2.264282 | Global: 69.07 dB | MaxErr: 0.0
# r1e-03-h12 Epoch  28 [BG] | train_wall=2.10s | Loss: 3.041169 | Freq: 2.263626 | Global: 69.13 dB | MaxErr: 0.0
# r1e-03-h12 Epoch  29 [BG] | train_wall=1.54s | Loss: 3.052539 | Freq: 2.153125 | Global: 69.39 dB | MaxErr: 0.0  [New Best!]
#
# r1e-03-h12 --- Experiment [BG_only] finished ---
# r1e-03-h12 --- Pure training time: 60.00 s ---
# r1e-03-h12 [timing] epochs=29 | train_wall/epoch: mean=2.07s min=1.54s max=2.12s | sum=59.99s
# r1e-03-h12 --- Best global PSNR: 69.39 dB ---
#   bg_h=12 (9,688p): PSNR=69.39 dB | CR=40.79x (base 40.85x) | +1.07 dB over SZ3
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
# r1e-03-h21 [Init] Epoch   0 | Global PSNR: 68.32 dB | MaxErr: 0.0
# r1e-03-h21 [plan] pure_train_budget=60.00s | epochs_cap=200 | steps/epoch=512 | patch=512 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r1e-03-h21 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r1e-03-h21 Epoch   1 [BG] | train_wall=5.17s | Loss: 0.950042 | Freq: 2.839447 | Global: 66.12 dB | MaxErr: 0.0
# r1e-03-h21 [timing] first_epoch_pure_train≈5.172s (excludes this epoch's end-of-epoch eval)
# r1e-03-h21 Epoch   2 [BG] | train_wall=5.15s | Loss: 3.179680 | Freq: 2.336563 | Global: 68.69 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h21 Epoch   3 [BG] | train_wall=5.16s | Loss: 3.106683 | Freq: 2.301529 | Global: 68.76 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h21 Epoch   4 [BG] | train_wall=5.16s | Loss: 3.087611 | Freq: 2.290207 | Global: 68.97 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h21 Epoch   5 [BG] | train_wall=5.17s | Loss: 3.073644 | Freq: 2.282257 | Global: 69.00 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h21 Epoch   6 [BG] | train_wall=5.12s | Loss: 3.065362 | Freq: 2.277695 | Global: 68.96 dB | MaxErr: 0.0
# r1e-03-h21 Epoch   7 [BG] | train_wall=5.09s | Loss: 3.057696 | Freq: 2.273392 | Global: 69.07 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h21 Epoch   8 [BG] | train_wall=5.13s | Loss: 3.053493 | Freq: 2.270050 | Global: 69.02 dB | MaxErr: 0.0
# r1e-03-h21 Epoch   9 [BG] | train_wall=5.13s | Loss: 3.048189 | Freq: 2.266968 | Global: 69.16 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h21 Epoch  10 [BG] | train_wall=5.10s | Loss: 3.042843 | Freq: 2.264389 | Global: 69.29 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h21 Epoch  11 [BG] | train_wall=5.15s | Loss: 3.038628 | Freq: 2.262146 | Global: 69.09 dB | MaxErr: 0.0
# r1e-03-h21 Epoch  12 [BG] | train_wall=3.46s | Loss: 3.085133 | Freq: 2.155202 | Global: 69.39 dB | MaxErr: 0.0  [New Best!]
#
# r1e-03-h21 --- Experiment [BG_only] finished ---
# r1e-03-h21 --- Pure training time: 60.01 s ---
# r1e-03-h21 [timing] epochs=12 | train_wall/epoch: mean=5.00s min=3.46s max=5.17s | sum=60.00s
# r1e-03-h21 --- Best global PSNR: 69.39 dB ---
#   bg_h=21 (28,858p): PSNR=69.39 dB | CR=40.67x (base 40.85x) | +1.07 dB over SZ3
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
# r1e-03-h39 [Init] Epoch   0 | Global PSNR: 68.32 dB | MaxErr: 0.0
# r1e-03-h39 [plan] pure_train_budget=60.00s | epochs_cap=200 | steps/epoch=512 | patch=512 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r1e-03-h39 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r1e-03-h39 Epoch   1 [BG] | train_wall=2.76s | Loss: 0.954869 | Freq: 2.779541 | Global: 67.84 dB | MaxErr: 0.0
# r1e-03-h39 [timing] first_epoch_pure_train≈2.764s (excludes this epoch's end-of-epoch eval)
# r1e-03-h39 Epoch   2 [BG] | train_wall=2.73s | Loss: 3.206617 | Freq: 2.346039 | Global: 68.86 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h39 Epoch   3 [BG] | train_wall=2.78s | Loss: 3.112402 | Freq: 2.304718 | Global: 68.46 dB | MaxErr: 0.0
# r1e-03-h39 Epoch   4 [BG] | train_wall=2.79s | Loss: 3.075202 | Freq: 2.283127 | Global: 69.00 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h39 Epoch   5 [BG] | train_wall=2.79s | Loss: 3.059259 | Freq: 2.272736 | Global: 69.01 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h39 Epoch   6 [BG] | train_wall=2.79s | Loss: 3.047962 | Freq: 2.266647 | Global: 68.87 dB | MaxErr: 0.0
# r1e-03-h39 Epoch   7 [BG] | train_wall=2.71s | Loss: 3.038451 | Freq: 2.262054 | Global: 68.99 dB | MaxErr: 0.0
# r1e-03-h39 Epoch   8 [BG] | train_wall=2.75s | Loss: 3.033027 | Freq: 2.258118 | Global: 69.18 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h39 Epoch   9 [BG] | train_wall=2.75s | Loss: 3.026419 | Freq: 2.255234 | Global: 69.15 dB | MaxErr: 0.0
# r1e-03-h39 Epoch  10 [BG] | train_wall=2.77s | Loss: 3.021176 | Freq: 2.251572 | Global: 69.14 dB | MaxErr: 0.0
# r1e-03-h39 Epoch  11 [BG] | train_wall=2.74s | Loss: 3.014584 | Freq: 2.248001 | Global: 69.16 dB | MaxErr: 0.0
# r1e-03-h39 Epoch  12 [BG] | train_wall=2.80s | Loss: 3.009494 | Freq: 2.244690 | Global: 69.17 dB | MaxErr: 0.0
# r1e-03-h39 Epoch  13 [BG] | train_wall=2.77s | Loss: 3.004465 | Freq: 2.241272 | Global: 69.22 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h39 Epoch  14 [BG] | train_wall=2.78s | Loss: 3.004199 | Freq: 2.239777 | Global: 69.30 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h39 Epoch  15 [BG] | train_wall=2.73s | Loss: 2.998894 | Freq: 2.237274 | Global: 69.20 dB | MaxErr: 0.0
# r1e-03-h39 Epoch  16 [BG] | train_wall=2.77s | Loss: 2.993864 | Freq: 2.234818 | Global: 69.25 dB | MaxErr: 0.0
# r1e-03-h39 Epoch  17 [BG] | train_wall=2.76s | Loss: 2.992715 | Freq: 2.233414 | Global: 69.18 dB | MaxErr: 0.0
# r1e-03-h39 Epoch  18 [BG] | train_wall=2.77s | Loss: 2.990565 | Freq: 2.232666 | Global: 69.23 dB | MaxErr: 0.0
# r1e-03-h39 Epoch  19 [BG] | train_wall=2.78s | Loss: 2.988830 | Freq: 2.231323 | Global: 69.27 dB | MaxErr: 0.0
# r1e-03-h39 Epoch  20 [BG] | train_wall=2.77s | Loss: 2.986920 | Freq: 2.230042 | Global: 69.27 dB | MaxErr: 0.0
# r1e-03-h39 Epoch  21 [BG] | train_wall=2.77s | Loss: 2.984425 | Freq: 2.228653 | Global: 69.32 dB | MaxErr: 0.0  [New Best!]
# r1e-03-h39 Epoch  22 [BG] | train_wall=1.92s | Loss: 3.009813 | Freq: 2.110681 | Global: 69.48 dB | MaxErr: 0.0  [New Best!]
#
# r1e-03-h39 --- Experiment [BG_only] finished ---
# r1e-03-h39 --- Pure training time: 60.00 s ---
# r1e-03-h39 [timing] epochs=22 | train_wall/epoch: mean=2.73s min=1.92s max=2.80s | sum=59.99s
# r1e-03-h39 --- Best global PSNR: 69.48 dB ---
#   bg_h=39 (97,816p): PSNR=69.48 dB | CR=40.25x (base 40.85x) | +1.16 dB over SZ3
#
# ############################################################
# # rel=2e-03 | SZ3 base: CR=64.14x (8.37 MB) | base PSNR=64.53 dB
#
# [Model: spatial] Total Params: 2,578
#  [Params] Main (BG) Network : 2,578 parameters
# r2e-03-h6 [Init] Epoch   0 | Global PSNR: 64.53 dB | MaxErr: 0.0
# r2e-03-h6 [plan] pure_train_budget=60.00s | epochs_cap=200 | steps/epoch=512 | patch=512 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r2e-03-h6 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r2e-03-h6 Epoch   1 [BG] | train_wall=1.88s | Loss: 0.928719 | Freq: 3.189087 | Global: 64.97 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h6 [timing] first_epoch_pure_train≈1.882s (excludes this epoch's end-of-epoch eval)
# r2e-03-h6 Epoch   2 [BG] | train_wall=1.89s | Loss: 3.613074 | Freq: 2.731369 | Global: 64.56 dB | MaxErr: 0.0
# r2e-03-h6 Epoch   3 [BG] | train_wall=1.90s | Loss: 3.504872 | Freq: 2.679276 | Global: 64.22 dB | MaxErr: 0.0
# r2e-03-h6 Epoch   4 [BG] | train_wall=1.89s | Loss: 3.434736 | Freq: 2.654480 | Global: 64.84 dB | MaxErr: 0.0
# r2e-03-h6 Epoch   5 [BG] | train_wall=1.90s | Loss: 3.401224 | Freq: 2.640701 | Global: 65.21 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h6 Epoch   6 [BG] | train_wall=1.89s | Loss: 3.389131 | Freq: 2.635147 | Global: 65.20 dB | MaxErr: 0.0
# r2e-03-h6 Epoch   7 [BG] | train_wall=1.91s | Loss: 3.382269 | Freq: 2.630661 | Global: 65.22 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h6 Epoch   8 [BG] | train_wall=1.86s | Loss: 3.376835 | Freq: 2.627914 | Global: 65.20 dB | MaxErr: 0.0
# r2e-03-h6 Epoch   9 [BG] | train_wall=1.88s | Loss: 3.374698 | Freq: 2.626785 | Global: 65.35 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h6 Epoch  10 [BG] | train_wall=1.87s | Loss: 3.369707 | Freq: 2.623825 | Global: 65.27 dB | MaxErr: 0.0
# r2e-03-h6 Epoch  11 [BG] | train_wall=1.86s | Loss: 3.367000 | Freq: 2.622391 | Global: 65.36 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h6 Epoch  12 [BG] | train_wall=1.86s | Loss: 3.363596 | Freq: 2.620422 | Global: 65.30 dB | MaxErr: 0.0
# r2e-03-h6 Epoch  13 [BG] | train_wall=1.86s | Loss: 3.361443 | Freq: 2.619202 | Global: 65.40 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h6 Epoch  14 [BG] | train_wall=1.89s | Loss: 3.360503 | Freq: 2.618988 | Global: 65.50 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h6 Epoch  15 [BG] | train_wall=1.89s | Loss: 3.356062 | Freq: 2.616577 | Global: 65.43 dB | MaxErr: 0.0
# r2e-03-h6 Epoch  16 [BG] | train_wall=1.87s | Loss: 3.353219 | Freq: 2.614532 | Global: 65.42 dB | MaxErr: 0.0
# r2e-03-h6 Epoch  17 [BG] | train_wall=1.86s | Loss: 3.351778 | Freq: 2.614655 | Global: 65.48 dB | MaxErr: 0.0
# r2e-03-h6 Epoch  18 [BG] | train_wall=1.85s | Loss: 3.350037 | Freq: 2.613739 | Global: 65.44 dB | MaxErr: 0.0
# r2e-03-h6 Epoch  19 [BG] | train_wall=1.84s | Loss: 3.349403 | Freq: 2.613007 | Global: 65.33 dB | MaxErr: 0.0
# r2e-03-h6 Epoch  20 [BG] | train_wall=1.81s | Loss: 3.348703 | Freq: 2.613098 | Global: 65.49 dB | MaxErr: 0.0
# r2e-03-h6 Epoch  21 [BG] | train_wall=1.85s | Loss: 3.346353 | Freq: 2.611847 | Global: 65.51 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h6 Epoch  22 [BG] | train_wall=1.84s | Loss: 3.344361 | Freq: 2.610489 | Global: 65.54 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h6 Epoch  23 [BG] | train_wall=1.85s | Loss: 3.343186 | Freq: 2.610382 | Global: 65.49 dB | MaxErr: 0.0
# r2e-03-h6 Epoch  24 [BG] | train_wall=1.82s | Loss: 3.341628 | Freq: 2.609100 | Global: 65.44 dB | MaxErr: 0.0
# r2e-03-h6 Epoch  25 [BG] | train_wall=1.81s | Loss: 3.341441 | Freq: 2.608856 | Global: 65.49 dB | MaxErr: 0.0
# r2e-03-h6 Epoch  26 [BG] | train_wall=1.83s | Loss: 3.340415 | Freq: 2.608795 | Global: 65.55 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h6 Epoch  27 [BG] | train_wall=1.85s | Loss: 3.338795 | Freq: 2.607574 | Global: 65.57 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h6 Epoch  28 [BG] | train_wall=1.83s | Loss: 3.338478 | Freq: 2.607224 | Global: 65.52 dB | MaxErr: 0.0
# r2e-03-h6 Epoch  29 [BG] | train_wall=1.88s | Loss: 3.336748 | Freq: 2.606262 | Global: 65.54 dB | MaxErr: 0.0
# r2e-03-h6 Epoch  30 [BG] | train_wall=1.88s | Loss: 3.336108 | Freq: 2.605927 | Global: 65.63 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h6 Epoch  31 [BG] | train_wall=1.87s | Loss: 3.334838 | Freq: 2.604858 | Global: 65.47 dB | MaxErr: 0.0
# r2e-03-h6 Epoch  32 [BG] | train_wall=1.90s | Loss: 3.335284 | Freq: 2.605316 | Global: 65.52 dB | MaxErr: 0.0
# r2e-03-h6 Epoch  33 [BG] | train_wall=0.32s | Loss: 3.340547 | Freq: 3.140274 | Global: 65.73 dB | MaxErr: 0.0  [New Best!]
#
# r2e-03-h6 --- Experiment [BG_only] finished ---
# r2e-03-h6 --- Pure training time: 60.00 s ---
# r2e-03-h6 [timing] epochs=33 | train_wall/epoch: mean=1.82s min=0.32s max=1.91s | sum=59.99s
# r2e-03-h6 --- Best global PSNR: 65.73 dB ---
#   bg_h= 6 (2,578p): PSNR=65.73 dB | CR=64.10x (base 64.14x) | +1.20 dB over SZ3
#
# [Model: spatial] Total Params: 9,688
#  [Params] Main (BG) Network : 9,688 parameters
# r2e-03-h12 [Init] Epoch   0 | Global PSNR: 64.53 dB | MaxErr: 0.0
# r2e-03-h12 [plan] pure_train_budget=60.00s | epochs_cap=200 | steps/epoch=512 | patch=512 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r2e-03-h12 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r2e-03-h12 Epoch   1 [BG] | train_wall=2.09s | Loss: 0.915929 | Freq: 3.012939 | Global: 64.75 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h12 [timing] first_epoch_pure_train≈2.089s (excludes this epoch's end-of-epoch eval)
# r2e-03-h12 Epoch   2 [BG] | train_wall=2.09s | Loss: 3.492865 | Freq: 2.674805 | Global: 65.08 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h12 Epoch   3 [BG] | train_wall=2.09s | Loss: 3.387829 | Freq: 2.629669 | Global: 65.33 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h12 Epoch   4 [BG] | train_wall=2.06s | Loss: 3.359427 | Freq: 2.616333 | Global: 65.48 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h12 Epoch   5 [BG] | train_wall=2.08s | Loss: 3.346162 | Freq: 2.609055 | Global: 65.35 dB | MaxErr: 0.0
# r2e-03-h12 Epoch   6 [BG] | train_wall=2.07s | Loss: 3.338230 | Freq: 2.604721 | Global: 65.28 dB | MaxErr: 0.0
# r2e-03-h12 Epoch   7 [BG] | train_wall=2.06s | Loss: 3.330246 | Freq: 2.600464 | Global: 65.30 dB | MaxErr: 0.0
# r2e-03-h12 Epoch   8 [BG] | train_wall=2.09s | Loss: 3.325842 | Freq: 2.597794 | Global: 65.46 dB | MaxErr: 0.0
# r2e-03-h12 Epoch   9 [BG] | train_wall=2.07s | Loss: 3.320437 | Freq: 2.594833 | Global: 65.55 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h12 Epoch  10 [BG] | train_wall=2.03s | Loss: 3.316093 | Freq: 2.592682 | Global: 65.49 dB | MaxErr: 0.0
# r2e-03-h12 Epoch  11 [BG] | train_wall=2.09s | Loss: 3.311773 | Freq: 2.590622 | Global: 65.36 dB | MaxErr: 0.0
# r2e-03-h12 Epoch  12 [BG] | train_wall=2.10s | Loss: 3.308353 | Freq: 2.588165 | Global: 65.33 dB | MaxErr: 0.0
# r2e-03-h12 Epoch  13 [BG] | train_wall=2.07s | Loss: 3.305439 | Freq: 2.586334 | Global: 65.65 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h12 Epoch  14 [BG] | train_wall=2.07s | Loss: 3.300242 | Freq: 2.583954 | Global: 65.36 dB | MaxErr: 0.0
# r2e-03-h12 Epoch  15 [BG] | train_wall=2.07s | Loss: 3.296698 | Freq: 2.582443 | Global: 65.41 dB | MaxErr: 0.0
# r2e-03-h12 Epoch  16 [BG] | train_wall=2.08s | Loss: 3.295081 | Freq: 2.581070 | Global: 65.54 dB | MaxErr: 0.0
# r2e-03-h12 Epoch  17 [BG] | train_wall=2.09s | Loss: 3.290558 | Freq: 2.578629 | Global: 65.51 dB | MaxErr: 0.0
# r2e-03-h12 Epoch  18 [BG] | train_wall=2.07s | Loss: 3.289889 | Freq: 2.578552 | Global: 65.51 dB | MaxErr: 0.0
# r2e-03-h12 Epoch  19 [BG] | train_wall=2.06s | Loss: 3.287322 | Freq: 2.576859 | Global: 65.59 dB | MaxErr: 0.0
# r2e-03-h12 Epoch  20 [BG] | train_wall=2.06s | Loss: 3.285426 | Freq: 2.575607 | Global: 65.55 dB | MaxErr: 0.0
# r2e-03-h12 Epoch  21 [BG] | train_wall=2.06s | Loss: 3.284214 | Freq: 2.575409 | Global: 65.56 dB | MaxErr: 0.0
# r2e-03-h12 Epoch  22 [BG] | train_wall=2.07s | Loss: 3.284048 | Freq: 2.574860 | Global: 65.39 dB | MaxErr: 0.0
# r2e-03-h12 Epoch  23 [BG] | train_wall=2.07s | Loss: 3.281285 | Freq: 2.573776 | Global: 65.59 dB | MaxErr: 0.0
# r2e-03-h12 Epoch  24 [BG] | train_wall=2.08s | Loss: 3.279634 | Freq: 2.572662 | Global: 65.66 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h12 Epoch  25 [BG] | train_wall=2.07s | Loss: 3.278795 | Freq: 2.572495 | Global: 65.51 dB | MaxErr: 0.0
# r2e-03-h12 Epoch  26 [BG] | train_wall=2.08s | Loss: 3.277630 | Freq: 2.571899 | Global: 65.70 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h12 Epoch  27 [BG] | train_wall=2.08s | Loss: 3.275615 | Freq: 2.570877 | Global: 65.62 dB | MaxErr: 0.0
# r2e-03-h12 Epoch  28 [BG] | train_wall=2.09s | Loss: 3.274854 | Freq: 2.570526 | Global: 65.50 dB | MaxErr: 0.0
# r2e-03-h12 Epoch  29 [BG] | train_wall=1.91s | Loss: 3.294712 | Freq: 2.544963 | Global: 65.77 dB | MaxErr: 0.0  [New Best!]
#
# r2e-03-h12 --- Experiment [BG_only] finished ---
# r2e-03-h12 --- Pure training time: 60.00 s ---
# r2e-03-h12 [timing] epochs=29 | train_wall/epoch: mean=2.07s min=1.91s max=2.10s | sum=59.99s
# r2e-03-h12 --- Best global PSNR: 65.77 dB ---
#   bg_h=12 (9,688p): PSNR=65.77 dB | CR=63.99x (base 64.14x) | +1.24 dB over SZ3
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
# r2e-03-h21 [Init] Epoch   0 | Global PSNR: 64.53 dB | MaxErr: 0.0
# r2e-03-h21 [plan] pure_train_budget=60.00s | epochs_cap=200 | steps/epoch=512 | patch=512 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r2e-03-h21 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r2e-03-h21 Epoch   1 [BG] | train_wall=5.14s | Loss: 0.889900 | Freq: 2.973831 | Global: 65.05 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h21 [timing] first_epoch_pure_train≈5.141s (excludes this epoch's end-of-epoch eval)
# r2e-03-h21 Epoch   2 [BG] | train_wall=5.11s | Loss: 3.454364 | Freq: 2.655472 | Global: 65.28 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h21 Epoch   3 [BG] | train_wall=5.13s | Loss: 3.361203 | Freq: 2.614700 | Global: 65.38 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h21 Epoch   4 [BG] | train_wall=5.11s | Loss: 3.334869 | Freq: 2.600555 | Global: 65.31 dB | MaxErr: 0.0
# r2e-03-h21 Epoch   5 [BG] | train_wall=5.08s | Loss: 3.318457 | Freq: 2.592560 | Global: 65.38 dB | MaxErr: 0.0
# r2e-03-h21 Epoch   6 [BG] | train_wall=5.08s | Loss: 3.310364 | Freq: 2.587952 | Global: 65.53 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h21 Epoch   7 [BG] | train_wall=5.08s | Loss: 3.302543 | Freq: 2.583664 | Global: 65.53 dB | MaxErr: 0.0
# r2e-03-h21 Epoch   8 [BG] | train_wall=5.12s | Loss: 3.296520 | Freq: 2.580704 | Global: 65.58 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h21 Epoch   9 [BG] | train_wall=5.12s | Loss: 3.292766 | Freq: 2.578812 | Global: 65.60 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h21 Epoch  10 [BG] | train_wall=5.13s | Loss: 3.289265 | Freq: 2.576981 | Global: 65.30 dB | MaxErr: 0.0
# r2e-03-h21 Epoch  11 [BG] | train_wall=5.12s | Loss: 3.286013 | Freq: 2.575806 | Global: 65.73 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h21 Epoch  12 [BG] | train_wall=3.77s | Loss: 3.313284 | Freq: 2.420569 | Global: 65.91 dB | MaxErr: 0.0  [New Best!]
#
# r2e-03-h21 --- Experiment [BG_only] finished ---
# r2e-03-h21 --- Pure training time: 60.00 s ---
# r2e-03-h21 [timing] epochs=12 | train_wall/epoch: mean=5.00s min=3.77s max=5.14s | sum=59.99s
# r2e-03-h21 --- Best global PSNR: 65.91 dB ---
#   bg_h=21 (28,858p): PSNR=65.91 dB | CR=63.70x (base 64.14x) | +1.38 dB over SZ3
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
# r2e-03-h39 [Init] Epoch   0 | Global PSNR: 64.53 dB | MaxErr: 0.0
# r2e-03-h39 [plan] pure_train_budget=60.00s | epochs_cap=200 | steps/epoch=512 | patch=512 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r2e-03-h39 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r2e-03-h39 Epoch   1 [BG] | train_wall=2.76s | Loss: 0.866660 | Freq: 2.858078 | Global: 63.80 dB | MaxErr: 0.0
# r2e-03-h39 [timing] first_epoch_pure_train≈2.762s (excludes this epoch's end-of-epoch eval)
# r2e-03-h39 Epoch   2 [BG] | train_wall=2.73s | Loss: 3.398767 | Freq: 2.632111 | Global: 64.59 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h39 Epoch   3 [BG] | train_wall=2.75s | Loss: 3.316732 | Freq: 2.590332 | Global: 65.00 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h39 Epoch   4 [BG] | train_wall=2.75s | Loss: 3.294669 | Freq: 2.579651 | Global: 65.13 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h39 Epoch   5 [BG] | train_wall=2.79s | Loss: 3.283813 | Freq: 2.572906 | Global: 65.12 dB | MaxErr: 0.0
# r2e-03-h39 Epoch   6 [BG] | train_wall=2.77s | Loss: 3.274979 | Freq: 2.564819 | Global: 65.21 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h39 Epoch   7 [BG] | train_wall=2.78s | Loss: 3.260747 | Freq: 2.556534 | Global: 65.46 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h39 Epoch   8 [BG] | train_wall=2.75s | Loss: 3.249344 | Freq: 2.550186 | Global: 65.46 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h39 Epoch   9 [BG] | train_wall=2.72s | Loss: 3.243710 | Freq: 2.545639 | Global: 65.63 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h39 Epoch  10 [BG] | train_wall=2.75s | Loss: 3.238748 | Freq: 2.542664 | Global: 65.51 dB | MaxErr: 0.0
# r2e-03-h39 Epoch  11 [BG] | train_wall=2.78s | Loss: 3.237652 | Freq: 2.541855 | Global: 65.59 dB | MaxErr: 0.0
# r2e-03-h39 Epoch  12 [BG] | train_wall=2.74s | Loss: 3.231429 | Freq: 2.538422 | Global: 65.76 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h39 Epoch  13 [BG] | train_wall=2.78s | Loss: 3.234096 | Freq: 2.538391 | Global: 65.59 dB | MaxErr: 0.0
# r2e-03-h39 Epoch  14 [BG] | train_wall=2.77s | Loss: 3.226571 | Freq: 2.535599 | Global: 65.76 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h39 Epoch  15 [BG] | train_wall=2.75s | Loss: 3.223856 | Freq: 2.533539 | Global: 65.73 dB | MaxErr: 0.0
# r2e-03-h39 Epoch  16 [BG] | train_wall=2.76s | Loss: 3.221952 | Freq: 2.532913 | Global: 65.81 dB | MaxErr: 0.0  [New Best!]
# r2e-03-h39 Epoch  17 [BG] | train_wall=2.78s | Loss: 3.221350 | Freq: 2.531830 | Global: 65.72 dB | MaxErr: 0.0
# r2e-03-h39 Epoch  18 [BG] | train_wall=2.76s | Loss: 3.221379 | Freq: 2.532516 | Global: 65.79 dB | MaxErr: 0.0
# r2e-03-h39 Epoch  19 [BG] | train_wall=2.75s | Loss: 3.218041 | Freq: 2.530624 | Global: 65.69 dB | MaxErr: 0.0
# r2e-03-h39 Epoch  20 [BG] | train_wall=2.73s | Loss: 3.220980 | Freq: 2.531464 | Global: 65.64 dB | MaxErr: 0.0
# r2e-03-h39 Epoch  21 [BG] | train_wall=2.77s | Loss: 3.215001 | Freq: 2.528885 | Global: 65.71 dB | MaxErr: 0.0
# r2e-03-h39 Epoch  22 [BG] | train_wall=2.06s | Loss: 3.226019 | Freq: 2.377346 | Global: 66.06 dB | MaxErr: 0.0  [New Best!]
#
# r2e-03-h39 --- Experiment [BG_only] finished ---
# r2e-03-h39 --- Pure training time: 60.00 s ---
# r2e-03-h39 [timing] epochs=22 | train_wall/epoch: mean=2.73s min=2.06s max=2.79s | sum=59.99s
# r2e-03-h39 --- Best global PSNR: 66.06 dB ---
#   bg_h=39 (97,816p): PSNR=66.06 dB | CR=62.68x (base 64.14x) | +1.53 dB over SZ3
#
# ############################################################
# # rel=3e-03 | SZ3 base: CR=82.63x (6.50 MB) | base PSNR=61.98 dB
#
# [Model: spatial] Total Params: 2,578
#  [Params] Main (BG) Network : 2,578 parameters
# r3e-03-h6 [Init] Epoch   0 | Global PSNR: 61.98 dB | MaxErr: 0.0
# r3e-03-h6 [plan] pure_train_budget=60.00s | epochs_cap=200 | steps/epoch=512 | patch=512 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r3e-03-h6 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r3e-03-h6 Epoch   1 [BG] | train_wall=1.87s | Loss: 0.934244 | Freq: 3.304443 | Global: 62.34 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h6 [timing] first_epoch_pure_train≈1.870s (excludes this epoch's end-of-epoch eval)
# r3e-03-h6 Epoch   2 [BG] | train_wall=1.89s | Loss: 3.843733 | Freq: 2.916061 | Global: 62.38 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h6 Epoch   3 [BG] | train_wall=1.87s | Loss: 3.709338 | Freq: 2.841019 | Global: 62.48 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h6 Epoch   4 [BG] | train_wall=1.87s | Loss: 3.598083 | Freq: 2.815048 | Global: 62.64 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h6 Epoch   5 [BG] | train_wall=1.89s | Loss: 3.532299 | Freq: 2.792358 | Global: 62.82 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h6 Epoch   6 [BG] | train_wall=1.84s | Loss: 3.509961 | Freq: 2.783157 | Global: 62.85 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h6 Epoch   7 [BG] | train_wall=1.89s | Loss: 3.496957 | Freq: 2.776291 | Global: 62.90 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h6 Epoch   8 [BG] | train_wall=1.90s | Loss: 3.489094 | Freq: 2.772507 | Global: 62.91 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h6 Epoch   9 [BG] | train_wall=1.85s | Loss: 3.485742 | Freq: 2.769684 | Global: 63.12 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h6 Epoch  10 [BG] | train_wall=1.83s | Loss: 3.477702 | Freq: 2.766251 | Global: 63.12 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h6 Epoch  11 [BG] | train_wall=1.89s | Loss: 3.473382 | Freq: 2.763443 | Global: 63.10 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  12 [BG] | train_wall=1.88s | Loss: 3.475361 | Freq: 2.761902 | Global: 63.03 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  13 [BG] | train_wall=1.89s | Loss: 3.461226 | Freq: 2.756638 | Global: 62.83 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  14 [BG] | train_wall=1.90s | Loss: 3.456628 | Freq: 2.754242 | Global: 62.84 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  15 [BG] | train_wall=1.90s | Loss: 3.452517 | Freq: 2.751740 | Global: 62.86 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  16 [BG] | train_wall=1.85s | Loss: 3.446333 | Freq: 2.748642 | Global: 62.83 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  17 [BG] | train_wall=1.84s | Loss: 3.443756 | Freq: 2.747162 | Global: 62.59 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  18 [BG] | train_wall=1.87s | Loss: 3.440963 | Freq: 2.746216 | Global: 62.85 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  19 [BG] | train_wall=1.82s | Loss: 3.438034 | Freq: 2.744537 | Global: 62.63 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  20 [BG] | train_wall=1.83s | Loss: 3.435440 | Freq: 2.743530 | Global: 62.57 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  21 [BG] | train_wall=1.84s | Loss: 3.433324 | Freq: 2.742325 | Global: 62.77 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  22 [BG] | train_wall=1.84s | Loss: 3.430119 | Freq: 2.740898 | Global: 62.87 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  23 [BG] | train_wall=1.89s | Loss: 3.429678 | Freq: 2.741043 | Global: 62.85 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  24 [BG] | train_wall=1.90s | Loss: 3.427221 | Freq: 2.739822 | Global: 62.78 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  25 [BG] | train_wall=1.89s | Loss: 3.425182 | Freq: 2.738487 | Global: 62.93 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  26 [BG] | train_wall=1.88s | Loss: 3.424480 | Freq: 2.738403 | Global: 62.77 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  27 [BG] | train_wall=1.87s | Loss: 3.422854 | Freq: 2.737892 | Global: 62.72 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  28 [BG] | train_wall=1.87s | Loss: 3.421705 | Freq: 2.737099 | Global: 62.59 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  29 [BG] | train_wall=1.85s | Loss: 3.421113 | Freq: 2.736855 | Global: 62.72 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  30 [BG] | train_wall=1.82s | Loss: 3.420060 | Freq: 2.736481 | Global: 62.84 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  31 [BG] | train_wall=1.86s | Loss: 3.418277 | Freq: 2.735771 | Global: 62.66 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  32 [BG] | train_wall=1.92s | Loss: 3.418196 | Freq: 2.736076 | Global: 62.78 dB | MaxErr: 0.0
# r3e-03-h6 Epoch  33 [BG] | train_wall=0.19s | Loss: 3.401116 | Freq: 3.284007 | Global: 62.86 dB | MaxErr: 0.0
#
# r3e-03-h6 --- Experiment [BG_only] finished ---
# r3e-03-h6 --- Pure training time: 60.00 s ---
# r3e-03-h6 [timing] epochs=33 | train_wall/epoch: mean=1.82s min=0.19s max=1.92s | sum=59.99s
# r3e-03-h6 --- Best global PSNR: 63.12 dB ---
#   bg_h= 6 (2,578p): PSNR=63.12 dB | CR=82.57x (base 82.63x) | +1.14 dB over SZ3
#
# [Model: spatial] Total Params: 9,688
#  [Params] Main (BG) Network : 9,688 parameters
# r3e-03-h12 [Init] Epoch   0 | Global PSNR: 61.98 dB | MaxErr: 0.0
# r3e-03-h12 [plan] pure_train_budget=60.00s | epochs_cap=200 | steps/epoch=512 | patch=512 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r3e-03-h12 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r3e-03-h12 Epoch   1 [BG] | train_wall=2.07s | Loss: 0.897811 | Freq: 3.053299 | Global: 62.46 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h12 [timing] first_epoch_pure_train≈2.073s (excludes this epoch's end-of-epoch eval)
# r3e-03-h12 Epoch   2 [BG] | train_wall=2.09s | Loss: 3.598232 | Freq: 2.817368 | Global: 62.83 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h12 Epoch   3 [BG] | train_wall=2.09s | Loss: 3.495584 | Freq: 2.774582 | Global: 62.71 dB | MaxErr: 0.0
# r3e-03-h12 Epoch   4 [BG] | train_wall=2.08s | Loss: 3.471913 | Freq: 2.761002 | Global: 62.58 dB | MaxErr: 0.0
# r3e-03-h12 Epoch   5 [BG] | train_wall=2.07s | Loss: 3.458798 | Freq: 2.754745 | Global: 62.90 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h12 Epoch   6 [BG] | train_wall=2.06s | Loss: 3.446258 | Freq: 2.749138 | Global: 62.96 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h12 Epoch   7 [BG] | train_wall=2.08s | Loss: 3.440877 | Freq: 2.745224 | Global: 62.71 dB | MaxErr: 0.0
# r3e-03-h12 Epoch   8 [BG] | train_wall=2.08s | Loss: 3.433225 | Freq: 2.741486 | Global: 62.73 dB | MaxErr: 0.0
# r3e-03-h12 Epoch   9 [BG] | train_wall=2.08s | Loss: 3.427604 | Freq: 2.738495 | Global: 62.89 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  10 [BG] | train_wall=2.09s | Loss: 3.418944 | Freq: 2.734413 | Global: 62.54 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  11 [BG] | train_wall=2.08s | Loss: 3.415070 | Freq: 2.733032 | Global: 62.62 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  12 [BG] | train_wall=2.09s | Loss: 3.413779 | Freq: 2.732246 | Global: 62.46 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  13 [BG] | train_wall=2.08s | Loss: 3.409813 | Freq: 2.730156 | Global: 62.77 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  14 [BG] | train_wall=2.08s | Loss: 3.405437 | Freq: 2.729088 | Global: 62.51 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  15 [BG] | train_wall=2.07s | Loss: 3.402189 | Freq: 2.727386 | Global: 62.74 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  16 [BG] | train_wall=2.09s | Loss: 3.400030 | Freq: 2.726479 | Global: 62.55 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  17 [BG] | train_wall=2.06s | Loss: 3.397947 | Freq: 2.725548 | Global: 61.41 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  18 [BG] | train_wall=2.04s | Loss: 3.395665 | Freq: 2.724304 | Global: 62.40 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  19 [BG] | train_wall=2.03s | Loss: 3.393976 | Freq: 2.723488 | Global: 62.68 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  20 [BG] | train_wall=2.04s | Loss: 3.392690 | Freq: 2.722076 | Global: 62.84 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  21 [BG] | train_wall=2.09s | Loss: 3.391926 | Freq: 2.721497 | Global: 62.63 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  22 [BG] | train_wall=2.09s | Loss: 3.389127 | Freq: 2.720818 | Global: 61.38 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  23 [BG] | train_wall=2.08s | Loss: 3.389133 | Freq: 2.720688 | Global: 62.78 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  24 [BG] | train_wall=2.09s | Loss: 3.386860 | Freq: 2.719559 | Global: 61.45 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  25 [BG] | train_wall=2.08s | Loss: 3.389656 | Freq: 2.719460 | Global: 62.80 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  26 [BG] | train_wall=2.07s | Loss: 3.385503 | Freq: 2.717598 | Global: 62.72 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  27 [BG] | train_wall=2.09s | Loss: 3.383079 | Freq: 2.716927 | Global: 62.80 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  28 [BG] | train_wall=2.08s | Loss: 3.380477 | Freq: 2.715721 | Global: 62.66 dB | MaxErr: 0.0
# r3e-03-h12 Epoch  29 [BG] | train_wall=1.87s | Loss: 3.381623 | Freq: 2.662649 | Global: 62.93 dB | MaxErr: 0.0
#
# r3e-03-h12 --- Experiment [BG_only] finished ---
# r3e-03-h12 --- Pure training time: 60.00 s ---
# r3e-03-h12 [timing] epochs=29 | train_wall/epoch: mean=2.07s min=1.87s max=2.09s | sum=60.00s
# r3e-03-h12 --- Best global PSNR: 62.96 dB ---
#   bg_h=12 (9,688p): PSNR=62.96 dB | CR=82.39x (base 82.63x) | +0.98 dB over SZ3
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
# r3e-03-h21 [Init] Epoch   0 | Global PSNR: 61.98 dB | MaxErr: 0.0
# r3e-03-h21 [plan] pure_train_budget=60.00s | epochs_cap=200 | steps/epoch=512 | patch=512 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r3e-03-h21 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r3e-03-h21 Epoch   1 [BG] | train_wall=5.11s | Loss: 0.894941 | Freq: 3.079300 | Global: 62.49 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 [timing] first_epoch_pure_train≈5.115s (excludes this epoch's end-of-epoch eval)
# r3e-03-h21 Epoch   2 [BG] | train_wall=5.15s | Loss: 3.623571 | Freq: 2.815689 | Global: 62.71 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch   3 [BG] | train_wall=5.15s | Loss: 3.492114 | Freq: 2.770325 | Global: 61.82 dB | MaxErr: 0.0
# r3e-03-h21 Epoch   4 [BG] | train_wall=5.15s | Loss: 3.469406 | Freq: 2.757263 | Global: 62.25 dB | MaxErr: 0.0
# r3e-03-h21 Epoch   5 [BG] | train_wall=5.13s | Loss: 3.440556 | Freq: 2.745392 | Global: 62.44 dB | MaxErr: 0.0
# r3e-03-h21 Epoch   6 [BG] | train_wall=5.15s | Loss: 3.428188 | Freq: 2.739441 | Global: 62.76 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch   7 [BG] | train_wall=5.16s | Loss: 3.420783 | Freq: 2.734856 | Global: 62.99 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch   8 [BG] | train_wall=5.12s | Loss: 3.409576 | Freq: 2.729210 | Global: 62.43 dB | MaxErr: 0.0
# r3e-03-h21 Epoch   9 [BG] | train_wall=5.15s | Loss: 3.400092 | Freq: 2.724709 | Global: 62.87 dB | MaxErr: 0.0
# r3e-03-h21 Epoch  10 [BG] | train_wall=5.14s | Loss: 3.393502 | Freq: 2.721397 | Global: 62.84 dB | MaxErr: 0.0
# r3e-03-h21 Epoch  11 [BG] | train_wall=5.13s | Loss: 3.385652 | Freq: 2.717850 | Global: 63.13 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch  12 [BG] | train_wall=3.46s | Loss: 3.384986 | Freq: 2.464258 | Global: 63.56 dB | MaxErr: 0.0  [New Best!]
#
# r3e-03-h21 --- Experiment [BG_only] finished ---
# r3e-03-h21 --- Pure training time: 60.01 s ---
# r3e-03-h21 [timing] epochs=12 | train_wall/epoch: mean=5.00s min=3.46s max=5.16s | sum=60.00s
# r3e-03-h21 --- Best global PSNR: 63.56 dB ---
#   bg_h=21 (28,858p): PSNR=63.56 dB | CR=81.91x (base 82.63x) | +1.58 dB over SZ3
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
# r3e-03-h39 [Init] Epoch   0 | Global PSNR: 61.98 dB | MaxErr: 0.0
# r3e-03-h39 [plan] pure_train_budget=60.00s | epochs_cap=200 | steps/epoch=512 | patch=512 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r3e-03-h39 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r3e-03-h39 Epoch   1 [BG] | train_wall=2.76s | Loss: 0.858765 | Freq: 2.969376 | Global: 60.78 dB | MaxErr: 0.0
# r3e-03-h39 [timing] first_epoch_pure_train≈2.759s (excludes this epoch's end-of-epoch eval)
# r3e-03-h39 Epoch   2 [BG] | train_wall=2.76s | Loss: 3.482317 | Freq: 2.762276 | Global: 61.96 dB | MaxErr: 0.0
# r3e-03-h39 Epoch   3 [BG] | train_wall=2.74s | Loss: 3.418663 | Freq: 2.732292 | Global: 62.16 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 Epoch   4 [BG] | train_wall=2.78s | Loss: 3.393150 | Freq: 2.721619 | Global: 62.72 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 Epoch   5 [BG] | train_wall=2.77s | Loss: 3.378789 | Freq: 2.714455 | Global: 62.69 dB | MaxErr: 0.0
# r3e-03-h39 Epoch   6 [BG] | train_wall=2.78s | Loss: 3.373082 | Freq: 2.711487 | Global: 62.66 dB | MaxErr: 0.0
# r3e-03-h39 Epoch   7 [BG] | train_wall=2.75s | Loss: 3.368059 | Freq: 2.707596 | Global: 62.55 dB | MaxErr: 0.0
# r3e-03-h39 Epoch   8 [BG] | train_wall=2.77s | Loss: 3.360241 | Freq: 2.705551 | Global: 62.56 dB | MaxErr: 0.0
# r3e-03-h39 Epoch   9 [BG] | train_wall=2.76s | Loss: 3.360535 | Freq: 2.703209 | Global: 62.48 dB | MaxErr: 0.0
# r3e-03-h39 Epoch  10 [BG] | train_wall=2.77s | Loss: 3.360633 | Freq: 2.702225 | Global: 62.86 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 Epoch  11 [BG] | train_wall=2.76s | Loss: 3.354282 | Freq: 2.700668 | Global: 62.93 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 Epoch  12 [BG] | train_wall=2.78s | Loss: 3.369850 | Freq: 2.702522 | Global: 62.94 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 Epoch  13 [BG] | train_wall=2.75s | Loss: 3.352769 | Freq: 2.699600 | Global: 62.96 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 Epoch  14 [BG] | train_wall=2.78s | Loss: 3.346932 | Freq: 2.697021 | Global: 63.19 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 Epoch  15 [BG] | train_wall=2.75s | Loss: 3.348462 | Freq: 2.698158 | Global: 62.75 dB | MaxErr: 0.0
# r3e-03-h39 Epoch  16 [BG] | train_wall=2.76s | Loss: 3.347998 | Freq: 2.696831 | Global: 63.17 dB | MaxErr: 0.0
# r3e-03-h39 Epoch  17 [BG] | train_wall=2.77s | Loss: 3.343861 | Freq: 2.694359 | Global: 63.05 dB | MaxErr: 0.0
# r3e-03-h39 Epoch  18 [BG] | train_wall=2.77s | Loss: 3.346373 | Freq: 2.693565 | Global: 63.16 dB | MaxErr: 0.0
# r3e-03-h39 Epoch  19 [BG] | train_wall=2.79s | Loss: 3.345245 | Freq: 2.693222 | Global: 63.46 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 Epoch  20 [BG] | train_wall=2.77s | Loss: 3.339912 | Freq: 2.692642 | Global: 63.50 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 Epoch  21 [BG] | train_wall=2.76s | Loss: 3.339011 | Freq: 2.692032 | Global: 63.09 dB | MaxErr: 0.0
# r3e-03-h39 Epoch  22 [BG] | train_wall=1.94s | Loss: 3.320837 | Freq: 2.456923 | Global: 63.70 dB | MaxErr: 0.0  [New Best!]
#
# r3e-03-h39 --- Experiment [BG_only] finished ---
# r3e-03-h39 --- Pure training time: 60.01 s ---
# r3e-03-h39 [timing] epochs=22 | train_wall/epoch: mean=2.73s min=1.94s max=2.79s | sum=59.99s
# r3e-03-h39 --- Best global PSNR: 63.70 dB ---
#   bg_h=39 (97,816p): PSNR=63.70 dB | CR=80.22x (base 82.63x) | +1.72 dB over SZ3
#
# ############################################################
# # rel=4e-03 | SZ3 base: CR=98.89x (5.43 MB) | base PSNR=60.39 dB
#
# [Model: spatial] Total Params: 2,578
#  [Params] Main (BG) Network : 2,578 parameters
# r4e-03-h6 [Init] Epoch   0 | Global PSNR: 60.39 dB | MaxErr: 0.0
# r4e-03-h6 [plan] pure_train_budget=60.00s | epochs_cap=200 | steps/epoch=512 | patch=512 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r4e-03-h6 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r4e-03-h6 Epoch   1 [BG] | train_wall=1.90s | Loss: 0.972710 | Freq: 3.335480 | Global: 60.52 dB | MaxErr: 0.0  [New Best!]
# r4e-03-h6 [timing] first_epoch_pure_train≈1.905s (excludes this epoch's end-of-epoch eval)
# r4e-03-h6 Epoch   2 [BG] | train_wall=1.88s | Loss: 3.942854 | Freq: 2.960922 | Global: 60.48 dB | MaxErr: 0.0
# r4e-03-h6 Epoch   3 [BG] | train_wall=1.88s | Loss: 3.843328 | Freq: 2.886642 | Global: 60.60 dB | MaxErr: 0.0  [New Best!]
# r4e-03-h6 Epoch   4 [BG] | train_wall=1.92s | Loss: 3.764932 | Freq: 2.865677 | Global: 60.89 dB | MaxErr: 0.0  [New Best!]
# r4e-03-h6 Epoch   5 [BG] | train_wall=1.88s | Loss: 3.637881 | Freq: 2.837723 | Global: 61.37 dB | MaxErr: 0.0  [New Best!]
# r4e-03-h6 Epoch   6 [BG] | train_wall=1.85s | Loss: 3.575848 | Freq: 2.818756 | Global: 61.47 dB | MaxErr: 0.0  [New Best!]
# r4e-03-h6 Epoch   7 [BG] | train_wall=1.83s | Loss: 3.559706 | Freq: 2.811340 | Global: 61.48 dB | MaxErr: 0.0  [New Best!]
# r4e-03-h6 Epoch   8 [BG] | train_wall=1.85s | Loss: 3.552005 | Freq: 2.807877 | Global: 61.46 dB | MaxErr: 0.0
# r4e-03-h6 Epoch   9 [BG] | train_wall=1.85s | Loss: 3.544402 | Freq: 2.803467 | Global: 61.53 dB | MaxErr: 0.0  [New Best!]
# r4e-03-h6 Epoch  10 [BG] | train_wall=1.85s | Loss: 3.541056 | Freq: 2.802109 | Global: 61.49 dB | MaxErr: 0.0
# r4e-03-h6 Epoch  11 [BG] | train_wall=1.86s | Loss: 3.536527 | Freq: 2.799850 | Global: 61.47 dB | MaxErr: 0.0
# r4e-03-h6 Epoch  12 [BG] | train_wall=1.88s | Loss: 3.533145 | Freq: 2.798676 | Global: 61.45 dB | MaxErr: 0.0
# r4e-03-h6 Epoch  13 [BG] | train_wall=1.86s | Loss: 3.530554 | Freq: 2.797150 | Global: 61.41 dB | MaxErr: 0.0
# r4e-03-h6 Epoch  14 [BG] | train_wall=1.84s | Loss: 3.529207 | Freq: 2.795914 | Global: 61.49 dB | MaxErr: 0.0
# r4e-03-h6 Epoch  15 [BG] | train_wall=1.85s | Loss: 3.523919 | Freq: 2.793228 | Global: 61.48 dB | MaxErr: 0.0
# r4e-03-h6 Epoch  16 [BG] | train_wall=1.89s | Loss: 3.521447 | Freq: 2.792358 | Global: 61.42 dB | MaxErr: 0.0
# r4e-03-h6 Epoch  17 [BG] | train_wall=1.86s | Loss: 3.517697 | Freq: 2.790054 | Global: 61.45 dB | MaxErr: 0.0
# r4e-03-h6 Epoch  18 [BG] | train_wall=1.87s | Loss: 3.516404 | Freq: 2.789871 | Global: 61.31 dB | MaxErr: 0.0
# r4e-03-h6 Epoch  19 [BG] | train_wall=1.84s | Loss: 3.514529 | Freq: 2.789093 | Global: 61.56 dB | MaxErr: 0.0  [New Best!]
# r4e-03-h6 Epoch  20 [BG] | train_wall=1.91s | Loss: 3.509513 | Freq: 2.785599 | Global: 61.43 dB | MaxErr: 0.0
# r4e-03-h6 Epoch  21 [BG] | train_wall=1.92s | Loss: 3.509878 | Freq: 2.785721 | Global: 61.48 dB | MaxErr: 0.0
# r4e-03-h6 Epoch  22 [BG] | train_wall=1.89s | Loss: 3.506178 | Freq: 2.784058 | Global: 61.53 dB | MaxErr: 0.0
# r4e-03-h6 Epoch  23 [BG] | train_wall=1.85s | Loss: 3.503881 | Freq: 2.782654 | Global: 61.52 dB | MaxErr: 0.0
# r4e-03-h6 Epoch  24 [BG] | train_wall=1.90s | Loss: 3.501590 | Freq: 2.781815 | Global: 61.53 dB | MaxErr: 0.0
# r4e-03-h6 Epoch  25 [BG] | train_wall=1.90s | Loss: 3.500175 | Freq: 2.780579 | Global: 61.60 dB | MaxErr: 0.0  [New Best!]
# r4e-03-h6 Epoch  26 [BG] | train_wall=1.85s | Loss: 3.500670 | Freq: 2.781357 | Global: 61.59 dB | MaxErr: 0.0
# ...
# r5e-03-h39 Epoch  12 [BG] | train_wall=2.78s | Loss: 3.239304 | Freq: 2.641205 | Global: 59.50 dB | MaxErr: 0.0
# r5e-03-h39 Epoch  13 [BG] | train_wall=2.78s | Loss: 3.233619 | Freq: 2.639977 | Global: 58.68 dB | MaxErr: 0.0
# r5e-03-h39 Epoch  14 [BG] | train_wall=2.76s | Loss: 3.229287 | Freq: 2.638985 | Global: 58.88 dB | MaxErr: 0.0
# r5e-03-h39 Epoch  15 [BG] | train_wall=2.76s | Loss: 3.227454 | Freq: 2.638634 | Global: 58.60 dB | MaxErr: 0.0
# r5e-03-h39 Epoch  16 [BG] | train_wall=2.76s | Loss: 3.224735 | Freq: 2.636124 | Global: 59.58 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h39 Epoch  17 [BG] | train_wall=2.77s | Loss: 3.230489 | Freq: 2.637299 | Global: 59.00 dB | MaxErr: 0.0
# r5e-03-h39 Epoch  18 [BG] | train_wall=2.78s | Loss: 3.221425 | Freq: 2.635376 | Global: 59.21 dB | MaxErr: 0.0
# r5e-03-h39 Epoch  19 [BG] | train_wall=2.77s | Loss: 3.220034 | Freq: 2.634575 | Global: 59.29 dB | MaxErr: 0.0
# r5e-03-h39 Epoch  20 [BG] | train_wall=2.77s | Loss: 3.215827 | Freq: 2.632957 | Global: 59.11 dB | MaxErr: 0.0
# r5e-03-h39 Epoch  21 [BG] | train_wall=2.75s | Loss: 3.216409 | Freq: 2.632622 | Global: 59.02 dB | MaxErr: 0.0
# r5e-03-h39 Epoch  22 [BG] | train_wall=1.89s | Loss: 3.166794 | Freq: 2.332641 | Global: 60.28 dB | MaxErr: 0.0  [New Best!]
#
# r5e-03-h39 --- Experiment [BG_only] finished ---
# r5e-03-h39 --- Pure training time: 60.00 s ---
# r5e-03-h39 [timing] epochs=22 | train_wall/epoch: mean=2.73s min=1.89s max=2.79s | sum=60.00s
# r5e-03-h39 --- Best global PSNR: 60.28 dB ---
#   bg_h=39 (97,816p): PSNR=60.28 dB | CR=113.75x (base 118.67x) | +2.21 dB over SZ3
#
# ############################################################
# # rel=6e-03 | SZ3 base: CR=133.95x (4.01 MB) | base PSNR=57.61 dB
#
# [Model: spatial] Total Params: 2,578
#  [Params] Main (BG) Network : 2,578 parameters
# r6e-03-h6 [Init] Epoch   0 | Global PSNR: 57.61 dB | MaxErr: 0.0
# r6e-03-h6 [plan] pure_train_budget=60.00s | epochs_cap=200 | steps/epoch=512 | patch=512 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r6e-03-h6 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r6e-03-h6 Epoch   1 [BG] | train_wall=1.88s | Loss: 0.948479 | Freq: 3.083542 | Global: 58.05 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h6 [timing] first_epoch_pure_train≈1.886s (excludes this epoch's end-of-epoch eval)
# r6e-03-h6 Epoch   2 [BG] | train_wall=1.87s | Loss: 3.689022 | Freq: 2.861526 | Global: 58.45 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h6 Epoch   3 [BG] | train_wall=1.86s | Loss: 3.588989 | Freq: 2.820206 | Global: 58.55 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h6 Epoch   4 [BG] | train_wall=1.90s | Loss: 3.558644 | Freq: 2.806671 | Global: 58.44 dB | MaxErr: 0.0
# r6e-03-h6 Epoch   5 [BG] | train_wall=1.89s | Loss: 3.547932 | Freq: 2.800888 | Global: 58.59 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h6 Epoch   6 [BG] | train_wall=1.90s | Loss: 3.534133 | Freq: 2.794952 | Global: 58.72 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h6 Epoch   7 [BG] | train_wall=1.89s | Loss: 3.528256 | Freq: 2.791550 | Global: 58.70 dB | MaxErr: 0.0
# r6e-03-h6 Epoch   8 [BG] | train_wall=1.88s | Loss: 3.518796 | Freq: 2.788101 | Global: 58.55 dB | MaxErr: 0.0
# r6e-03-h6 Epoch   9 [BG] | train_wall=1.88s | Loss: 3.512484 | Freq: 2.783829 | Global: 58.59 dB | MaxErr: 0.0
# r6e-03-h6 Epoch  10 [BG] | train_wall=1.89s | Loss: 3.508723 | Freq: 2.782211 | Global: 58.77 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h6 Epoch  11 [BG] | train_wall=1.91s | Loss: 3.505173 | Freq: 2.780853 | Global: 58.77 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h6 Epoch  12 [BG] | train_wall=1.85s | Loss: 3.504263 | Freq: 2.780121 | Global: 58.83 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h6 Epoch  13 [BG] | train_wall=1.90s | Loss: 3.499153 | Freq: 2.777054 | Global: 58.82 dB | MaxErr: 0.0
# r6e-03-h6 Epoch  14 [BG] | train_wall=1.86s | Loss: 3.495950 | Freq: 2.775070 | Global: 58.71 dB | MaxErr: 0.0
# r6e-03-h6 Epoch  15 [BG] | train_wall=1.91s | Loss: 3.492916 | Freq: 2.774200 | Global: 58.89 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h6 Epoch  16 [BG] | train_wall=1.89s | Loss: 3.489159 | Freq: 2.772141 | Global: 58.81 dB | MaxErr: 0.0
# r6e-03-h6 Epoch  17 [BG] | train_wall=1.90s | Loss: 3.486883 | Freq: 2.771027 | Global: 58.82 dB | MaxErr: 0.0
# r6e-03-h6 Epoch  18 [BG] | train_wall=1.91s | Loss: 3.485405 | Freq: 2.770096 | Global: 58.95 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h6 Epoch  19 [BG] | train_wall=1.87s | Loss: 3.483064 | Freq: 2.768814 | Global: 58.84 dB | MaxErr: 0.0
# r6e-03-h6 Epoch  20 [BG] | train_wall=1.89s | Loss: 3.484197 | Freq: 2.767899 | Global: 58.86 dB | MaxErr: 0.0
# r6e-03-h6 Epoch  21 [BG] | train_wall=1.88s | Loss: 3.478365 | Freq: 2.766098 | Global: 58.85 dB | MaxErr: 0.0
# r6e-03-h6 Epoch  22 [BG] | train_wall=1.85s | Loss: 3.474302 | Freq: 2.765182 | Global: 58.92 dB | MaxErr: 0.0
# r6e-03-h6 Epoch  23 [BG] | train_wall=1.87s | Loss: 3.471977 | Freq: 2.763947 | Global: 58.74 dB | MaxErr: 0.0
# r6e-03-h6 Epoch  24 [BG] | train_wall=1.89s | Loss: 3.472558 | Freq: 2.763382 | Global: 58.93 dB | MaxErr: 0.0
# r6e-03-h6 Epoch  25 [BG] | train_wall=1.90s | Loss: 3.470463 | Freq: 2.761902 | Global: 58.99 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h6 Epoch  26 [BG] | train_wall=1.91s | Loss: 3.468698 | Freq: 2.761566 | Global: 59.00 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h6 Epoch  27 [BG] | train_wall=1.90s | Loss: 3.466918 | Freq: 2.761215 | Global: 58.88 dB | MaxErr: 0.0
# r6e-03-h6 Epoch  28 [BG] | train_wall=1.91s | Loss: 3.463923 | Freq: 2.760162 | Global: 58.79 dB | MaxErr: 0.0
# r6e-03-h6 Epoch  29 [BG] | train_wall=1.92s | Loss: 3.463593 | Freq: 2.760040 | Global: 58.79 dB | MaxErr: 0.0
# r6e-03-h6 Epoch  30 [BG] | train_wall=1.91s | Loss: 3.462592 | Freq: 2.759796 | Global: 58.96 dB | MaxErr: 0.0
# r6e-03-h6 Epoch  31 [BG] | train_wall=1.90s | Loss: 3.460421 | Freq: 2.758163 | Global: 58.58 dB | MaxErr: 0.0
# r6e-03-h6 Epoch  32 [BG] | train_wall=1.40s | Loss: 3.516250 | Freq: 2.579279 | Global: 58.99 dB | MaxErr: 0.0
#
# r6e-03-h6 --- Experiment [BG_only] finished ---
# r6e-03-h6 --- Pure training time: 60.00 s ---
# r6e-03-h6 [timing] epochs=32 | train_wall/epoch: mean=1.87s min=1.40s max=1.92s | sum=59.99s
# r6e-03-h6 --- Best global PSNR: 59.00 dB ---
#   bg_h= 6 (2,578p): PSNR=59.00 dB | CR=133.78x (base 133.95x) | +1.39 dB over SZ3
#
# [Model: spatial] Total Params: 9,688
#  [Params] Main (BG) Network : 9,688 parameters
# r6e-03-h12 [Init] Epoch   0 | Global PSNR: 57.61 dB | MaxErr: 0.0
# r6e-03-h12 [plan] pure_train_budget=60.00s | epochs_cap=200 | steps/epoch=512 | patch=512 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r6e-03-h12 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r6e-03-h12 Epoch   1 [BG] | train_wall=2.10s | Loss: 0.932829 | Freq: 3.077927 | Global: 58.17 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h12 [timing] first_epoch_pure_train≈2.099s (excludes this epoch's end-of-epoch eval)
# r6e-03-h12 Epoch   2 [BG] | train_wall=2.08s | Loss: 3.612187 | Freq: 2.826187 | Global: 58.27 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h12 Epoch   3 [BG] | train_wall=2.08s | Loss: 3.535170 | Freq: 2.792572 | Global: 58.68 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h12 Epoch   4 [BG] | train_wall=2.09s | Loss: 3.502563 | Freq: 2.776962 | Global: 58.53 dB | MaxErr: 0.0
# r6e-03-h12 Epoch   5 [BG] | train_wall=2.05s | Loss: 3.493788 | Freq: 2.770020 | Global: 58.62 dB | MaxErr: 0.0
# r6e-03-h12 Epoch   6 [BG] | train_wall=2.06s | Loss: 3.470285 | Freq: 2.760391 | Global: 57.92 dB | MaxErr: 0.0
# r6e-03-h12 Epoch   7 [BG] | train_wall=2.10s | Loss: 3.458434 | Freq: 2.754868 | Global: 58.50 dB | MaxErr: 0.0
# r6e-03-h12 Epoch   8 [BG] | train_wall=2.09s | Loss: 3.447774 | Freq: 2.749084 | Global: 58.42 dB | MaxErr: 0.0
# r6e-03-h12 Epoch   9 [BG] | train_wall=2.10s | Loss: 3.437341 | Freq: 2.743729 | Global: 58.65 dB | MaxErr: 0.0
# r6e-03-h12 Epoch  10 [BG] | train_wall=2.04s | Loss: 3.427189 | Freq: 2.739410 | Global: 58.86 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h12 Epoch  11 [BG] | train_wall=2.09s | Loss: 3.419276 | Freq: 2.733978 | Global: 58.12 dB | MaxErr: 0.0
# r6e-03-h12 Epoch  12 [BG] | train_wall=2.09s | Loss: 3.419002 | Freq: 2.733566 | Global: 58.67 dB | MaxErr: 0.0
# r6e-03-h12 Epoch  13 [BG] | train_wall=2.09s | Loss: 3.414712 | Freq: 2.731995 | Global: 58.67 dB | MaxErr: 0.0
# r6e-03-h12 Epoch  14 [BG] | train_wall=2.09s | Loss: 3.408193 | Freq: 2.729141 | Global: 58.79 dB | MaxErr: 0.0
# r6e-03-h12 Epoch  15 [BG] | train_wall=2.09s | Loss: 3.406309 | Freq: 2.728821 | Global: 58.77 dB | MaxErr: 0.0
# r6e-03-h12 Epoch  16 [BG] | train_wall=2.10s | Loss: 3.406425 | Freq: 2.729004 | Global: 58.56 dB | MaxErr: 0.0
# r6e-03-h12 Epoch  17 [BG] | train_wall=2.09s | Loss: 3.400923 | Freq: 2.725220 | Global: 58.69 dB | MaxErr: 0.0
# r6e-03-h12 Epoch  18 [BG] | train_wall=2.09s | Loss: 3.398141 | Freq: 2.724655 | Global: 58.55 dB | MaxErr: 0.0
# r6e-03-h12 Epoch  19 [BG] | train_wall=2.10s | Loss: 3.395265 | Freq: 2.723557 | Global: 58.62 dB | MaxErr: 0.0
# r6e-03-h12 Epoch  20 [BG] | train_wall=2.09s | Loss: 3.399478 | Freq: 2.725403 | Global: 58.91 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h12 Epoch  21 [BG] | train_wall=2.08s | Loss: 3.404314 | Freq: 2.726135 | Global: 58.93 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h12 Epoch  22 [BG] | train_wall=2.02s | Loss: 3.399191 | Freq: 2.723907 | Global: 58.51 dB | MaxErr: 0.0
# r6e-03-h12 Epoch  23 [BG] | train_wall=2.02s | Loss: 3.396366 | Freq: 2.722870 | Global: 58.74 dB | MaxErr: 0.0
# r6e-03-h12 Epoch  24 [BG] | train_wall=2.05s | Loss: 3.393340 | Freq: 2.721481 | Global: 58.95 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h12 Epoch  25 [BG] | train_wall=2.06s | Loss: 3.399397 | Freq: 2.722382 | Global: 58.63 dB | MaxErr: 0.0
# r6e-03-h12 Epoch  26 [BG] | train_wall=2.06s | Loss: 3.392971 | Freq: 2.721863 | Global: 58.59 dB | MaxErr: 0.0
# r6e-03-h12 Epoch  27 [BG] | train_wall=2.05s | Loss: 3.389534 | Freq: 2.720871 | Global: 58.65 dB | MaxErr: 0.0
# r6e-03-h12 Epoch  28 [BG] | train_wall=2.06s | Loss: 3.392327 | Freq: 2.719681 | Global: 59.11 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h12 Epoch  29 [BG] | train_wall=1.88s | Loss: 3.396342 | Freq: 2.669226 | Global: 58.85 dB | MaxErr: 0.0
#
# r6e-03-h12 --- Experiment [BG_only] finished ---
# r6e-03-h12 --- Pure training time: 60.00 s ---
# r6e-03-h12 [timing] epochs=29 | train_wall/epoch: mean=2.07s min=1.88s max=2.10s | sum=59.99s
# r6e-03-h12 --- Best global PSNR: 59.11 dB ---
#   bg_h=12 (9,688p): PSNR=59.11 dB | CR=133.31x (base 133.95x) | +1.50 dB over SZ3
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
# r6e-03-h21 [Init] Epoch   0 | Global PSNR: 57.61 dB | MaxErr: 0.0
# r6e-03-h21 [plan] pure_train_budget=60.00s | epochs_cap=200 | steps/epoch=512 | patch=512 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r6e-03-h21 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r6e-03-h21 Epoch   1 [BG] | train_wall=5.10s | Loss: 0.830210 | Freq: 2.908936 | Global: 58.05 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h21 [timing] first_epoch_pure_train≈5.100s (excludes this epoch's end-of-epoch eval)
# r6e-03-h21 Epoch   2 [BG] | train_wall=5.09s | Loss: 3.545149 | Freq: 2.796463 | Global: 57.52 dB | MaxErr: 0.0
# r6e-03-h21 Epoch   3 [BG] | train_wall=5.09s | Loss: 3.486039 | Freq: 2.769989 | Global: 58.45 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h21 Epoch   4 [BG] | train_wall=5.13s | Loss: 3.450312 | Freq: 2.748917 | Global: 58.58 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h21 Epoch   5 [BG] | train_wall=5.12s | Loss: 3.429547 | Freq: 2.737640 | Global: 58.28 dB | MaxErr: 0.0
# r6e-03-h21 Epoch   6 [BG] | train_wall=5.13s | Loss: 3.408250 | Freq: 2.729218 | Global: 58.86 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h21 Epoch   7 [BG] | train_wall=5.14s | Loss: 3.398386 | Freq: 2.724304 | Global: 59.03 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h21 Epoch   8 [BG] | train_wall=5.13s | Loss: 3.391852 | Freq: 2.721542 | Global: 58.64 dB | MaxErr: 0.0
# r6e-03-h21 Epoch   9 [BG] | train_wall=5.14s | Loss: 3.387650 | Freq: 2.719650 | Global: 58.76 dB | MaxErr: 0.0
# r6e-03-h21 Epoch  10 [BG] | train_wall=5.16s | Loss: 3.385102 | Freq: 2.718048 | Global: 59.12 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h21 Epoch  11 [BG] | train_wall=5.11s | Loss: 3.386474 | Freq: 2.716614 | Global: 59.15 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h21 Epoch  12 [BG] | train_wall=3.66s | Loss: 3.405627 | Freq: 2.491694 | Global: 58.77 dB | MaxErr: 0.0
#
# r6e-03-h21 --- Experiment [BG_only] finished ---
# r6e-03-h21 --- Pure training time: 60.00 s ---
# r6e-03-h21 [timing] epochs=12 | train_wall/epoch: mean=5.00s min=3.66s max=5.16s | sum=60.00s
# r6e-03-h21 --- Best global PSNR: 59.15 dB ---
#   bg_h=21 (28,858p): PSNR=59.15 dB | CR=132.05x (base 133.95x) | +1.54 dB over SZ3
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
# r6e-03-h39 [Init] Epoch   0 | Global PSNR: 57.61 dB | MaxErr: 0.0
# r6e-03-h39 [plan] pure_train_budget=60.00s | epochs_cap=200 | steps/epoch=512 | patch=512 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r6e-03-h39 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r6e-03-h39 Epoch   1 [BG] | train_wall=2.74s | Loss: 0.820946 | Freq: 2.902740 | Global: 58.08 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h39 [timing] first_epoch_pure_train≈2.739s (excludes this epoch's end-of-epoch eval)
# r6e-03-h39 Epoch   2 [BG] | train_wall=2.75s | Loss: 3.530544 | Freq: 2.787048 | Global: 58.16 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h39 Epoch   3 [BG] | train_wall=2.73s | Loss: 3.456165 | Freq: 2.754242 | Global: 58.48 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h39 Epoch   4 [BG] | train_wall=2.74s | Loss: 3.421077 | Freq: 2.734390 | Global: 58.18 dB | MaxErr: 0.0
# r6e-03-h39 Epoch   5 [BG] | train_wall=2.76s | Loss: 3.409853 | Freq: 2.726440 | Global: 58.75 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h39 Epoch   6 [BG] | train_wall=2.74s | Loss: 3.395171 | Freq: 2.719955 | Global: 58.48 dB | MaxErr: 0.0
# r6e-03-h39 Epoch   7 [BG] | train_wall=2.74s | Loss: 3.387513 | Freq: 2.718887 | Global: 58.47 dB | MaxErr: 0.0
# r6e-03-h39 Epoch   8 [BG] | train_wall=2.78s | Loss: 3.380149 | Freq: 2.714371 | Global: 58.80 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h39 Epoch   9 [BG] | train_wall=2.77s | Loss: 3.371843 | Freq: 2.710709 | Global: 58.63 dB | MaxErr: 0.0
# r6e-03-h39 Epoch  10 [BG] | train_wall=2.74s | Loss: 3.372238 | Freq: 2.711365 | Global: 58.78 dB | MaxErr: 0.0
# r6e-03-h39 Epoch  11 [BG] | train_wall=2.77s | Loss: 3.363835 | Freq: 2.708832 | Global: 58.43 dB | MaxErr: 0.0
# r6e-03-h39 Epoch  12 [BG] | train_wall=2.79s | Loss: 3.363548 | Freq: 2.707352 | Global: 58.72 dB | MaxErr: 0.0
# r6e-03-h39 Epoch  13 [BG] | train_wall=2.77s | Loss: 3.358289 | Freq: 2.706337 | Global: 58.86 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h39 Epoch  14 [BG] | train_wall=2.79s | Loss: 3.354202 | Freq: 2.704407 | Global: 58.70 dB | MaxErr: 0.0
# r6e-03-h39 Epoch  15 [BG] | train_wall=2.78s | Loss: 3.352754 | Freq: 2.703506 | Global: 58.65 dB | MaxErr: 0.0
# r6e-03-h39 Epoch  16 [BG] | train_wall=2.76s | Loss: 3.355762 | Freq: 2.702133 | Global: 58.81 dB | MaxErr: 0.0
# r6e-03-h39 Epoch  17 [BG] | train_wall=2.75s | Loss: 3.355929 | Freq: 2.703003 | Global: 58.94 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h39 Epoch  18 [BG] | train_wall=2.72s | Loss: 3.352381 | Freq: 2.702194 | Global: 59.15 dB | MaxErr: 0.0  [New Best!]
# r6e-03-h39 Epoch  19 [BG] | train_wall=2.72s | Loss: 3.347919 | Freq: 2.700378 | Global: 58.93 dB | MaxErr: 0.0
# r6e-03-h39 Epoch  20 [BG] | train_wall=2.74s | Loss: 3.349646 | Freq: 2.701073 | Global: 58.99 dB | MaxErr: 0.0
# r6e-03-h39 Epoch  21 [BG] | train_wall=2.72s | Loss: 3.346855 | Freq: 2.698257 | Global: 58.97 dB | MaxErr: 0.0
# r6e-03-h39 Epoch  22 [BG] | train_wall=2.21s | Loss: 3.352903 | Freq: 2.555681 | Global: 59.16 dB | MaxErr: 0.0  [New Best!]
#
# r6e-03-h39 --- Experiment [BG_only] finished ---
# r6e-03-h39 --- Pure training time: 60.01 s ---
# r6e-03-h39 [timing] epochs=22 | train_wall/epoch: mean=2.73s min=2.21s max=2.79s | sum=59.99s
# r6e-03-h39 --- Best global PSNR: 59.16 dB ---
#   bg_h=39 (97,816p): PSNR=59.16 dB | CR=127.72x (base 133.95x) | +1.55 dB over SZ3
#
# --- Sweep complete in 37.2 min (24 models over 6 rel-errors) ---

# %%
fig, ax = plt.subplots(figsize=(10, 6.5))

# One curve per model size; points span the rel_err sweep (-> CR axis)
param_sizes = sorted(set(r["n_params"] for r in results))
cmap = plt.cm.viridis
colors = {p: cmap(i / max(1, len(param_sizes) - 1)) for i, p in enumerate(param_sizes)}

def fmt_p(p):
    return f"{p/1000:.0f}k" if p >= 1000 else str(p)

for p in param_sizes:
    pts = sorted([r for r in results if r["n_params"] == p], key=lambda r: r["cr"])
    ax.plot([r["cr"] for r in pts], [r["psnr"] for r in pts],
            "-o", color=colors[p], markersize=6, linewidth=1.8, zorder=3,
            label=f"{fmt_p(p)} params")

# SZ3-only baseline curve
bl = sorted(baselines, key=lambda b: b["cr"])
ax.plot([b["cr"] for b in bl], [b["psnr"] for b in bl],
        "--s", color="black", markersize=6, linewidth=1.6, zorder=2,
        label="SZ3 only (no model)")
# Annotate baseline points with their rel_err
for b in bl:
    ax.annotate(f"{b['rel']:.0e}", xy=(b["cr"], b["psnr"]),
                xytext=(0, -14), textcoords="offset points",
                ha="center", fontsize=7, color="black")

ax.set_xlabel("Compression Ratio  (orig / [SZ3 + model bytes])")
ax.set_ylabel("PSNR (dB)  [full volume]")
ax.set_title(
    f"PSNR vs CR — Magnetic {work_shape} (stride={SPATIAL_STRIDE})\n"
    f"rel_err {min(REL_ERRS):.0e}–{max(REL_ERRS):.0e} (labels) · lr={FIXED_LR:.0e} · "
    f"{TIME_PER_CONFIG:.0f}s/config · curves = model size"
)
ax.grid(True, alpha=0.35)
ax.legend(loc="best", fontsize=9, title="model size")
plt.tight_layout()
out_png = f"psnr_vs_cr_relsweep_{TARGET_STEM}.png"
plt.savefig(out_png, dpi=150, bbox_inches="tight")
plt.show()
print(f"Saved: {out_png}")

# Full table to stdout so every (rel, params) value is visible
print(f"\n{'rel':>7} {'bg_h':>5} {'params':>10} {'PSNR(dB)':>9} {'CR':>8} "
      f"{'baseCR':>8} {'+dB':>7} {'epochs':>7}")
base_by_rel = {b['rel']: b for b in baselines}
for r in sorted(results, key=lambda r: (r['rel'], r['n_params'])):
    b = base_by_rel[r['rel']]
    print(f"{r['rel']:>7.0e} {r['bg_h']:>5} {r['n_params']:>10,} {r['psnr']:>9.2f} "
          f"{r['cr']:>8.2f} {b['cr']:>8.2f} {r['psnr']-b['psnr']:>7.2f} {r['epochs']:>7}")
# Out:
# Saved: psnr_vs_cr_relsweep_magnetic_reconnection.png
#
#     rel  bg_h     params  PSNR(dB)       CR   baseCR     +dB  epochs
#   1e-03     6      2,578     69.22    40.84    40.85    0.90      32
#   1e-03    12      9,688     69.39    40.79    40.85    1.07      29
#   1e-03    21     28,858     69.39    40.67    40.85    1.07      12
#   1e-03    39     97,816     69.48    40.25    40.85    1.16      22
#   2e-03     6      2,578     65.73    64.10    64.14    1.20      33
#   2e-03    12      9,688     65.77    63.99    64.14    1.24      29
#   2e-03    21     28,858     65.91    63.70    64.14    1.38      12
#   2e-03    39     97,816     66.06    62.68    64.14    1.53      22
#   3e-03     6      2,578     63.12    82.57    82.63    1.14      33
#   3e-03    12      9,688     62.96    82.39    82.63    0.98      29
#   3e-03    21     28,858     63.56    81.91    82.63    1.58      12
#   3e-03    39     97,816     63.70    80.22    82.63    1.72      22
#   4e-03     6      2,578     61.60    98.79    98.89    1.21      33
#   4e-03    12      9,688     61.72    98.53    98.89    1.33      30
#   4e-03    21     28,858     61.82    97.85    98.89    1.42      12
#   4e-03    39     97,816     61.91    95.45    98.89    1.52      22
#   5e-03     6      2,578     60.04   118.53   118.67    1.97      33
#   5e-03    12      9,688     59.36   118.16   118.67    1.29      30
#   5e-03    21     28,858     60.18   117.17   118.67    2.11      12
#   5e-03    39     97,816     60.28   113.75   118.67    2.21      22
#   6e-03     6      2,578     59.00   133.78   133.95    1.39      32
#   6e-03    12      9,688     59.11   133.31   133.95    1.50      29
#   6e-03    21     28,858     59.15   132.05   133.95    1.54      12
#   6e-03    39     97,816     59.16   127.72   133.95    1.55      22
