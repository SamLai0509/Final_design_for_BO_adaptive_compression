# %% [markdown]
# # PSNR vs Compression Ratio — model size × SZ3 error bound
#
# **Dataset:** Miranda 1024×1024×1024 (single-field float32).
#
# **Why sweep the rel-error bound too?**  The model is tiny next to the SZ3 base (100k params ≈ 0.2 MB vs an SZ3 stream of tens–hundreds of MB), so changing the parameter count alone barely moves the total CR.  The knob that actually moves CR is the **SZ3 relative-error bound** — looser bound → smaller SZ3 stream → higher CR but lower base PSNR.
#
# So we sweep `rel_err ∈ [1e-3 … 6e-3]` (spreads CR along x) **and** a few model sizes (separate curves).  Per point:
#
# ```
# CR = original_bytes / (sz_bytes(rel_err) + n_params * 2)   # params stored as bf16
# ```
#
# Result: a family of rate–distortion curves — one per model size — plus the SZ3-only baseline.

# %%
import random, sys, os, copy, time
from pathlib import Path

import numpy as np
import torch
import matplotlib.pyplot as plt

sys.path.append("/home/sam/Halo_Finder/Final_design/base_script")

# Force-reload edited modules so re-running this cell picks up bg_stage.py changes
# WITHOUT restarting the kernel (Jupyter caches modules in sys.modules).
import importlib
import bg_stage
importlib.reload(bg_stage)

from experiment import build_bg_only_cfg, estimate_bg_model_param_bytes
from bg_stage import run_bg_inference, train_bg_only, unwrap_bg_model
from bg_shard import pick_bg_h_under_budget

pysz_dir = "/home/sam/Data_Compression/SZ3/tools/pysz"
if pysz_dir not in sys.path:
    sys.path.append(pysz_dir)
from pysz import SZ

def set_seed(seed=42):
    torch.manual_seed(seed); np.random.seed(seed); random.seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Device: {device} | GPUs: {torch.cuda.device_count()}")
# Out:
# Device: cuda:0 | GPUs: 1

# %%
# ── Paths ─────────────────────────────────────────────────────────────────────
halo_finder_root = Path("/home/sam/Halo_Finder")
raw_path    = (halo_finder_root / "halo_finder_v1/miranda_1024x1024x1024_float32.raw").as_posix()
sz_lib_path = "/home/sam/Data_Compression/SZ3/build/lib64/libSZ3c.so"

# ── Dataset constants ──────────────────────────────────────────────────────────
data_shape  = (1024, 1024, 1024)
TARGET_STEM = "miranda"

# Quick-test downsample: stride>1 shrinks the cube (and re-compresses it) so the
# whole sweep runs fast.  CR is then computed on the shrunk cube — still a valid
# R-D curve, just lower resolution.  Set to 1 for the real full-res study.
SPATIAL_STRIDE = 1

sz_engine = SZ(sz_lib_path)
print("SZ engine loaded")
# Out:
# SZ engine loaded

# %%
def load_gt(stride=1):
    """Load the ground-truth float32 cube once (optionally strided)."""
    vol = np.fromfile(raw_path, dtype=np.float32).reshape(data_shape)
    if stride > 1:
        vol = np.ascontiguousarray(vol[::stride, ::stride, ::stride])
    return vol

def compress_at(vol, rel_err):
    """SZ3-compress `vol` at a relative-error bound; return (Xps, sz_bytes, sz_cr)."""
    b, cr = sz_engine.compress(vol, 1, 0, float(rel_err), 0)
    x_lq  = sz_engine.decompress(b, vol.shape, np.float32).astype(np.float32)
    return [np.asarray(x_lq, np.float32)], int(len(b)), float(cr)

# %%
t0 = time.time()
gt         = load_gt(SPATIAL_STRIDE)
Xs         = [gt]
work_shape = gt.shape
orig_bytes = gt.nbytes

def psnr_from_arrays(target, recon):
    data_range = float(target.max() - target.min())
    if data_range <= 0:
        data_range = 1.0
    mse = float(np.mean((target - recon) ** 2))
    return 100.0 if mse <= 0 else 20.0 * np.log10(data_range) - 10.0 * np.log10(mse)

print(f"Loaded GT in {time.time()-t0:.1f}s | work shape: {work_shape} "
      f"(stride={SPATIAL_STRIDE}) | {orig_bytes/1e6:.1f} MB")
# Out:
# Loaded GT in 0.7s | work shape: (1024, 1024, 1024) (stride=1) | 4295.0 MB

# %%
def build_cfg(Xs_in, Xps_in, max_train_time, bg_h, steps_per_epoch,
              lr=1e-4, epochs=200, log_prefix="", patch_size=None):
    if patch_size is None:
        patch_size = Xs_in[0].shape[2]
    cfg = build_bg_only_cfg(
        X_target=Xs_in[0], Xps=Xps_in, max_train_time=max_train_time,
        epochs=epochs, steps_per_epoch=steps_per_epoch, bg_h=bg_h,
        bg_batch=1, bg_patch_size=patch_size, lr=lr,
    )
    cfg.bg_sample_mode   = "sequential"
    cfg.bg_log_prefix    = log_prefix
    cfg.bg_arch          = "spatial"
    cfg.amp              = True
    cfg.amp_dtype        = "bf16"
    cfg.bg_ddp           = False
    cfg.bg_data_parallel = False
    return cfg

def n_params_of(model):
    return int(sum(p.numel() for p in unwrap_bg_model(model).parameters()))

print("Helpers ready")
# Out:
# Helpers ready

# %% [markdown]
# ## Sweep:  rel-error bound  ×  model size
#
# Outer loop = `REL_ERRS` (each value re-compresses the cube with SZ3 → a new base CR / base PSNR).  Inner loop = `PARAM_TARGETS` (each mapped to a `bg_h` via `pick_bg_h_under_budget`).  `lr` is fixed; each model trains for `TIME_PER_CONFIG` s for the full budget (no early-stop — fair ablation).
#
# **Total trainings = len(REL_ERRS) × #distinct model sizes** — keep both lists short for full-res 1024³, or use `SPATIAL_STRIDE>1` first to smoke-test the shape of the curves.

# %%
# ── Fixed knobs ───────────────────────────────────────────────────────────────
FIXED_LR        = 1e-3
TIME_PER_CONFIG = 120.0          # wall-clock budget per model (early-stop may end sooner)
BYTES_PER_PARAM = 2             # bf16 storage for the model weights
FREQ_WARMUP     = 1            # epochs before the FFT/freq loss term joins the loss

# Outer sweep: SZ3 relative-error bound (this is what actually moves CR)
REL_ERRS = [ 3e-3, 5e-3, 7e-3, 9e-3, 1e-2]

# Inner sweep: model parameter budgets (separate curves)
PARAM_TARGETS = [30000, 100000, 150000, 240000,360000,500000]
H_CANDIDATES  = list(range(3, 100))

# Map each budget -> largest bg_h that fits; dedupe (several budgets may share a bg_h)
_seen = set()
sweep_plan = []          # list of (bg_h, est_params)
for tgt in PARAM_TARGETS:
    h, est_p = pick_bg_h_under_budget(
        tgt, shape=work_shape, n_fields=1,
        bg_arch="spatial", h_candidates=H_CANDIDATES,
    )
    if h not in _seen:
        _seen.add(h)
        sweep_plan.append((int(h), int(est_p)))
sweep_plan.sort()

n_runs = len(REL_ERRS) * len(sweep_plan)
print(f"Fixed: lr={FIXED_LR:.1e} | direction=Z | {TIME_PER_CONFIG:.0f}s/config | "
      f"freq_warmup={FREQ_WARMUP}")
print(f"REL_ERRS: {REL_ERRS}")
print(f"Model sizes ({len(sweep_plan)} distinct):")
for h, est_p in sweep_plan:
    print(f"  bg_h={h:2d}  ~{est_p:,} params")
print(f"\n>> {n_runs} trainings total (~{n_runs*TIME_PER_CONFIG/60:.0f} min "
      f"at {TIME_PER_CONFIG:.0f}s each)")
# Out:
# [Model: spatial] Total Params: 724
#  [Params] Main (BG) Network : 724 parameters
#
# [Model: spatial] Total Params: 1,216
#  [Params] Main (BG) Network : 1,216 parameters
#
# [Model: spatial] Total Params: 1,834
#  [Params] Main (BG) Network : 1,834 parameters
#
# [Model: spatial] Total Params: 2,578
#  [Params] Main (BG) Network : 2,578 parameters
#
# [Model: spatial] Total Params: 3,448
#  [Params] Main (BG) Network : 3,448 parameters
#
# [Model: spatial] Total Params: 4,444
#  [Params] Main (BG) Network : 4,444 parameters
#
# [Model: spatial] Total Params: 5,566
#  [Params] Main (BG) Network : 5,566 parameters
#
# [Model: spatial] Total Params: 6,814
#  [Params] Main (BG) Network : 6,814 parameters
#
# [Model: spatial] Total Params: 8,188
#  [Params] Main (BG) Network : 8,188 parameters
#
# [Model: spatial] Total Params: 9,688
#  [Params] Main (BG) Network : 9,688 parameters
#
# [Model: spatial] Total Params: 11,314
#  [Params] Main (BG) Network : 11,314 parameters
#
# [Model: spatial] Total Params: 13,066
#  [Params] Main (BG) Network : 13,066 parameters
#
# [Model: spatial] Total Params: 14,944
#  [Params] Main (BG) Network : 14,944 parameters
#
# [Model: spatial] Total Params: 16,948
#  [Params] Main (BG) Network : 16,948 parameters
#
# [Model: spatial] Total Params: 19,078
#  [Params] Main (BG) Network : 19,078 parameters
#
# [Model: spatial] Total Params: 21,334
#  [Params] Main (BG) Network : 21,334 parameters
#
# [Model: spatial] Total Params: 23,716
#  [Params] Main (BG) Network : 23,716 parameters
#
# [Model: spatial] Total Params: 26,224
#  [Params] Main (BG) Network : 26,224 parameters
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
#
# [Model: spatial] Total Params: 31,618
#  [Params] Main (BG) Network : 31,618 parameters
#
# [Model: spatial] Total Params: 34,504
#  [Params] Main (BG) Network : 34,504 parameters
#
# [Model: spatial] Total Params: 37,516
#  [Params] Main (BG) Network : 37,516 parameters
#
# [Model: spatial] Total Params: 40,654
#  [Params] Main (BG) Network : 40,654 parameters
#
# [Model: spatial] Total Params: 43,918
#  [Params] Main (BG) Network : 43,918 parameters
#
# [Model: spatial] Total Params: 47,308
#  [Params] Main (BG) Network : 47,308 parameters
#
# [Model: spatial] Total Params: 50,824
#  [Params] Main (BG) Network : 50,824 parameters
#
# [Model: spatial] Total Params: 54,466
#  [Params] Main (BG) Network : 54,466 parameters
#
# [Model: spatial] Total Params: 58,234
#  [Params] Main (BG) Network : 58,234 parameters
#
# [Model: spatial] Total Params: 62,128
#  [Params] Main (BG) Network : 62,128 parameters
#
# [Model: spatial] Total Params: 66,148
#  [Params] Main (BG) Network : 66,148 parameters
#
# [Model: spatial] Total Params: 70,294
#  [Params] Main (BG) Network : 70,294 parameters
#
# [Model: spatial] Total Params: 74,566
#  [Params] Main (BG) Network : 74,566 parameters
#
# [Model: spatial] Total Params: 78,964
#  [Params] Main (BG) Network : 78,964 parameters
#
# [Model: spatial] Total Params: 83,488
#  [Params] Main (BG) Network : 83,488 parameters
#
# [Model: spatial] Total Params: 88,138
#  [Params] Main (BG) Network : 88,138 parameters
#
# [Model: spatial] Total Params: 92,914
#  [Params] Main (BG) Network : 92,914 parameters
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
#
# [Model: spatial] Total Params: 102,844
#  [Params] Main (BG) Network : 102,844 parameters
#
# [Model: spatial] Total Params: 107,998
#  [Params] Main (BG) Network : 107,998 parameters
#
# [Model: spatial] Total Params: 113,278
#  [Params] Main (BG) Network : 113,278 parameters
#
# [Model: spatial] Total Params: 118,684
#  [Params] Main (BG) Network : 118,684 parameters
#
# [Model: spatial] Total Params: 124,216
#  [Params] Main (BG) Network : 124,216 parameters
#
# [Model: spatial] Total Params: 129,874
#  [Params] Main (BG) Network : 129,874 parameters
#
# [Model: spatial] Total Params: 135,658
#  [Params] Main (BG) Network : 135,658 parameters
#
# [Model: spatial] Total Params: 141,568
#  [Params] Main (BG) Network : 141,568 parameters
#
# [Model: spatial] Total Params: 147,604
#  [Params] Main (BG) Network : 147,604 parameters
#
# [Model: spatial] Total Params: 153,766
#  [Params] Main (BG) Network : 153,766 parameters
#
# [Model: spatial] Total Params: 160,054
#  [Params] Main (BG) Network : 160,054 parameters
#
# [Model: spatial] Total Params: 166,468
#  [Params] Main (BG) Network : 166,468 parameters
#
# [Model: spatial] Total Params: 173,008
#  [Params] Main (BG) Network : 173,008 parameters
#
# [Model: spatial] Total Params: 179,674
#  [Params] Main (BG) Network : 179,674 parameters
#
# [Model: spatial] Total Params: 186,466
#  [Params] Main (BG) Network : 186,466 parameters
#
# [Model: spatial] Total Params: 193,384
#  [Params] Main (BG) Network : 193,384 parameters
#
# [Model: spatial] Total Params: 200,428
#  [Params] Main (BG) Network : 200,428 parameters
#
# [Model: spatial] Total Params: 207,598
#  [Params] Main (BG) Network : 207,598 parameters
#
# [Model: spatial] Total Params: 214,894
#  [Params] Main (BG) Network : 214,894 parameters
#
# [Model: spatial] Total Params: 222,316
#  [Params] Main (BG) Network : 222,316 parameters
#
# [Model: spatial] Total Params: 229,864
#  [Params] Main (BG) Network : 229,864 parameters
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
#
# [Model: spatial] Total Params: 245,338
#  [Params] Main (BG) Network : 245,338 parameters
#
# [Model: spatial] Total Params: 253,264
#  [Params] Main (BG) Network : 253,264 parameters
#
# [Model: spatial] Total Params: 261,316
#  [Params] Main (BG) Network : 261,316 parameters
#
# [Model: spatial] Total Params: 269,494
#  [Params] Main (BG) Network : 269,494 parameters
#
# [Model: spatial] Total Params: 277,798
#  [Params] Main (BG) Network : 277,798 parameters
#
# [Model: spatial] Total Params: 286,228
#  [Params] Main (BG) Network : 286,228 parameters
#
# [Model: spatial] Total Params: 294,784
#  [Params] Main (BG) Network : 294,784 parameters
#
# [Model: spatial] Total Params: 303,466
#  [Params] Main (BG) Network : 303,466 parameters
#
# [Model: spatial] Total Params: 312,274
#  [Params] Main (BG) Network : 312,274 parameters
#
# [Model: spatial] Total Params: 321,208
#  [Params] Main (BG) Network : 321,208 parameters
#
# [Model: spatial] Total Params: 330,268
#  [Params] Main (BG) Network : 330,268 parameters
#
# [Model: spatial] Total Params: 339,454
#  [Params] Main (BG) Network : 339,454 parameters
#
# [Model: spatial] Total Params: 348,766
#  [Params] Main (BG) Network : 348,766 parameters
#
# [Model: spatial] Total Params: 358,204
#  [Params] Main (BG) Network : 358,204 parameters
#
# [Model: spatial] Total Params: 367,768
#  [Params] Main (BG) Network : 367,768 parameters
#
# [Model: spatial] Total Params: 377,458
#  [Params] Main (BG) Network : 377,458 parameters
#
# [Model: spatial] Total Params: 387,274
#  [Params] Main (BG) Network : 387,274 parameters
#
# [Model: spatial] Total Params: 397,216
#  [Params] Main (BG) Network : 397,216 parameters
#
# [Model: spatial] Total Params: 407,284
#  [Params] Main (BG) Network : 407,284 parameters
#
# [Model: spatial] Total Params: 417,478
#  [Params] Main (BG) Network : 417,478 parameters
#
# [Model: spatial] Total Params: 427,798
#  [Params] Main (BG) Network : 427,798 parameters
#
# [Model: spatial] Total Params: 438,244
#  [Params] Main (BG) Network : 438,244 parameters
#
# [Model: spatial] Total Params: 448,816
#  [Params] Main (BG) Network : 448,816 parameters
#
# [Model: spatial] Total Params: 459,514
#  [Params] Main (BG) Network : 459,514 parameters
#
# [Model: spatial] Total Params: 470,338
#  [Params] Main (BG) Network : 470,338 parameters
#
# [Model: spatial] Total Params: 481,288
#  [Params] Main (BG) Network : 481,288 parameters
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
#
# [Model: spatial] Total Params: 503,566
#  [Params] Main (BG) Network : 503,566 parameters
#
# [Model: spatial] Total Params: 514,894
#  [Params] Main (BG) Network : 514,894 parameters
#
# [Model: spatial] Total Params: 526,348
#  [Params] Main (BG) Network : 526,348 parameters
#
# [Model: spatial] Total Params: 537,928
#  [Params] Main (BG) Network : 537,928 parameters
#
# [Model: spatial] Total Params: 549,634
#  [Params] Main (BG) Network : 549,634 parameters
#
# [Model: spatial] Total Params: 561,466
#  [Params] Main (BG) Network : 561,466 parameters
#
# [Model: spatial] Total Params: 573,424
#  [Params] Main (BG) Network : 573,424 parameters
#
# [Model: spatial] Total Params: 585,508
#  [Params] Main (BG) Network : 585,508 parameters
#
# [Model: spatial] Total Params: 597,718
#  [Params] Main (BG) Network : 597,718 parameters
#
# [Model: spatial] Total Params: 610,054
#  [Params] Main (BG) Network : 610,054 parameters
#
# [Model: spatial] Total Params: 622,516
#  [Params] Main (BG) Network : 622,516 parameters
#
# [Model: spatial] Total Params: 724
#  [Params] Main (BG) Network : 724 parameters
#
# [Model: spatial] Total Params: 1,216
#  [Params] Main (BG) Network : 1,216 parameters
#
# [Model: spatial] Total Params: 1,834
#  [Params] Main (BG) Network : 1,834 parameters
#
# [Model: spatial] Total Params: 2,578
#  [Params] Main (BG) Network : 2,578 parameters
#
# [Model: spatial] Total Params: 3,448
#  [Params] Main (BG) Network : 3,448 parameters
#
# [Model: spatial] Total Params: 4,444
#  [Params] Main (BG) Network : 4,444 parameters
#
# [Model: spatial] Total Params: 5,566
#  [Params] Main (BG) Network : 5,566 parameters
#
# [Model: spatial] Total Params: 6,814
#  [Params] Main (BG) Network : 6,814 parameters
#
# [Model: spatial] Total Params: 8,188
#  [Params] Main (BG) Network : 8,188 parameters
#
# [Model: spatial] Total Params: 9,688
#  [Params] Main (BG) Network : 9,688 parameters
#
# [Model: spatial] Total Params: 11,314
#  [Params] Main (BG) Network : 11,314 parameters
#
# [Model: spatial] Total Params: 13,066
#  [Params] Main (BG) Network : 13,066 parameters
#
# [Model: spatial] Total Params: 14,944
#  [Params] Main (BG) Network : 14,944 parameters
#
# [Model: spatial] Total Params: 16,948
#  [Params] Main (BG) Network : 16,948 parameters
#
# [Model: spatial] Total Params: 19,078
#  [Params] Main (BG) Network : 19,078 parameters
#
# [Model: spatial] Total Params: 21,334
#  [Params] Main (BG) Network : 21,334 parameters
#
# [Model: spatial] Total Params: 23,716
#  [Params] Main (BG) Network : 23,716 parameters
#
# [Model: spatial] Total Params: 26,224
#  [Params] Main (BG) Network : 26,224 parameters
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
#
# [Model: spatial] Total Params: 31,618
#  [Params] Main (BG) Network : 31,618 parameters
#
# [Model: spatial] Total Params: 34,504
#  [Params] Main (BG) Network : 34,504 parameters
#
# [Model: spatial] Total Params: 37,516
#  [Params] Main (BG) Network : 37,516 parameters
#
# [Model: spatial] Total Params: 40,654
#  [Params] Main (BG) Network : 40,654 parameters
#
# [Model: spatial] Total Params: 43,918
#  [Params] Main (BG) Network : 43,918 parameters
#
# [Model: spatial] Total Params: 47,308
#  [Params] Main (BG) Network : 47,308 parameters
#
# [Model: spatial] Total Params: 50,824
#  [Params] Main (BG) Network : 50,824 parameters
#
# [Model: spatial] Total Params: 54,466
#  [Params] Main (BG) Network : 54,466 parameters
#
# [Model: spatial] Total Params: 58,234
#  [Params] Main (BG) Network : 58,234 parameters
#
# [Model: spatial] Total Params: 62,128
#  [Params] Main (BG) Network : 62,128 parameters
#
# [Model: spatial] Total Params: 66,148
#  [Params] Main (BG) Network : 66,148 parameters
#
# [Model: spatial] Total Params: 70,294
#  [Params] Main (BG) Network : 70,294 parameters
#
# [Model: spatial] Total Params: 74,566
#  [Params] Main (BG) Network : 74,566 parameters
#
# [Model: spatial] Total Params: 78,964
#  [Params] Main (BG) Network : 78,964 parameters
#
# [Model: spatial] Total Params: 83,488
#  [Params] Main (BG) Network : 83,488 parameters
#
# [Model: spatial] Total Params: 88,138
#  [Params] Main (BG) Network : 88,138 parameters
#
# [Model: spatial] Total Params: 92,914
#  [Params] Main (BG) Network : 92,914 parameters
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
#
# [Model: spatial] Total Params: 102,844
#  [Params] Main (BG) Network : 102,844 parameters
#
# [Model: spatial] Total Params: 107,998
#  [Params] Main (BG) Network : 107,998 parameters
#
# [Model: spatial] Total Params: 113,278
#  [Params] Main (BG) Network : 113,278 parameters
#
# [Model: spatial] Total Params: 118,684
#  [Params] Main (BG) Network : 118,684 parameters
#
# [Model: spatial] Total Params: 124,216
#  [Params] Main (BG) Network : 124,216 parameters
#
# [Model: spatial] Total Params: 129,874
#  [Params] Main (BG) Network : 129,874 parameters
#
# [Model: spatial] Total Params: 135,658
#  [Params] Main (BG) Network : 135,658 parameters
#
# [Model: spatial] Total Params: 141,568
#  [Params] Main (BG) Network : 141,568 parameters
#
# [Model: spatial] Total Params: 147,604
#  [Params] Main (BG) Network : 147,604 parameters
#
# [Model: spatial] Total Params: 153,766
#  [Params] Main (BG) Network : 153,766 parameters
#
# [Model: spatial] Total Params: 160,054
#  [Params] Main (BG) Network : 160,054 parameters
#
# [Model: spatial] Total Params: 166,468
#  [Params] Main (BG) Network : 166,468 parameters
#
# [Model: spatial] Total Params: 173,008
#  [Params] Main (BG) Network : 173,008 parameters
#
# [Model: spatial] Total Params: 179,674
#  [Params] Main (BG) Network : 179,674 parameters
#
# [Model: spatial] Total Params: 186,466
#  [Params] Main (BG) Network : 186,466 parameters
#
# [Model: spatial] Total Params: 193,384
#  [Params] Main (BG) Network : 193,384 parameters
#
# [Model: spatial] Total Params: 200,428
#  [Params] Main (BG) Network : 200,428 parameters
#
# [Model: spatial] Total Params: 207,598
#  [Params] Main (BG) Network : 207,598 parameters
#
# [Model: spatial] Total Params: 214,894
#  [Params] Main (BG) Network : 214,894 parameters
#
# [Model: spatial] Total Params: 222,316
#  [Params] Main (BG) Network : 222,316 parameters
#
# [Model: spatial] Total Params: 229,864
#  [Params] Main (BG) Network : 229,864 parameters
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
#
# [Model: spatial] Total Params: 245,338
#  [Params] Main (BG) Network : 245,338 parameters
#
# [Model: spatial] Total Params: 253,264
#  [Params] Main (BG) Network : 253,264 parameters
#
# [Model: spatial] Total Params: 261,316
#  [Params] Main (BG) Network : 261,316 parameters
#
# [Model: spatial] Total Params: 269,494
#  [Params] Main (BG) Network : 269,494 parameters
#
# [Model: spatial] Total Params: 277,798
#  [Params] Main (BG) Network : 277,798 parameters
#
# [Model: spatial] Total Params: 286,228
#  [Params] Main (BG) Network : 286,228 parameters
#
# [Model: spatial] Total Params: 294,784
#  [Params] Main (BG) Network : 294,784 parameters
#
# [Model: spatial] Total Params: 303,466
#  [Params] Main (BG) Network : 303,466 parameters
#
# [Model: spatial] Total Params: 312,274
#  [Params] Main (BG) Network : 312,274 parameters
#
# [Model: spatial] Total Params: 321,208
#  [Params] Main (BG) Network : 321,208 parameters
#
# [Model: spatial] Total Params: 330,268
#  [Params] Main (BG) Network : 330,268 parameters
#
# [Model: spatial] Total Params: 339,454
#  [Params] Main (BG) Network : 339,454 parameters
#
# [Model: spatial] Total Params: 348,766
#  [Params] Main (BG) Network : 348,766 parameters
#
# [Model: spatial] Total Params: 358,204
#  [Params] Main (BG) Network : 358,204 parameters
#
# [Model: spatial] Total Params: 367,768
#  [Params] Main (BG) Network : 367,768 parameters
#
# [Model: spatial] Total Params: 377,458
#  [Params] Main (BG) Network : 377,458 parameters
#
# [Model: spatial] Total Params: 387,274
#  [Params] Main (BG) Network : 387,274 parameters
#
# [Model: spatial] Total Params: 397,216
#  [Params] Main (BG) Network : 397,216 parameters
#
# [Model: spatial] Total Params: 407,284
#  [Params] Main (BG) Network : 407,284 parameters
#
# [Model: spatial] Total Params: 417,478
#  [Params] Main (BG) Network : 417,478 parameters
#
# [Model: spatial] Total Params: 427,798
#  [Params] Main (BG) Network : 427,798 parameters
#
# [Model: spatial] Total Params: 438,244
#  [Params] Main (BG) Network : 438,244 parameters
#
# [Model: spatial] Total Params: 448,816
#  [Params] Main (BG) Network : 448,816 parameters
#
# [Model: spatial] Total Params: 459,514
#  [Params] Main (BG) Network : 459,514 parameters
#
# [Model: spatial] Total Params: 470,338
#  [Params] Main (BG) Network : 470,338 parameters
#
# [Model: spatial] Total Params: 481,288
#  [Params] Main (BG) Network : 481,288 parameters
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
#
# [Model: spatial] Total Params: 503,566
#  [Params] Main (BG) Network : 503,566 parameters
#
# [Model: spatial] Total Params: 514,894
#  [Params] Main (BG) Network : 514,894 parameters
#
# [Model: spatial] Total Params: 526,348
#  [Params] Main (BG) Network : 526,348 parameters
#
# [Model: spatial] Total Params: 537,928
#  [Params] Main (BG) Network : 537,928 parameters
#
# [Model: spatial] Total Params: 549,634
#  [Params] Main (BG) Network : 549,634 parameters
#
# [Model: spatial] Total Params: 561,466
#  [Params] Main (BG) Network : 561,466 parameters
#
# [Model: spatial] Total Params: 573,424
#  [Params] Main (BG) Network : 573,424 parameters
#
# [Model: spatial] Total Params: 585,508
#  [Params] Main (BG) Network : 585,508 parameters
#
# [Model: spatial] Total Params: 597,718
#  [Params] Main (BG) Network : 597,718 parameters
#
# [Model: spatial] Total Params: 610,054
#  [Params] Main (BG) Network : 610,054 parameters
#
# [Model: spatial] Total Params: 622,516
#  [Params] Main (BG) Network : 622,516 parameters
#
# [Model: spatial] Total Params: 724
#  [Params] Main (BG) Network : 724 parameters
#
# [Model: spatial] Total Params: 1,216
#  [Params] Main (BG) Network : 1,216 parameters
#
# [Model: spatial] Total Params: 1,834
#  [Params] Main (BG) Network : 1,834 parameters
#
# [Model: spatial] Total Params: 2,578
#  [Params] Main (BG) Network : 2,578 parameters
#
# [Model: spatial] Total Params: 3,448
#  [Params] Main (BG) Network : 3,448 parameters
#
# [Model: spatial] Total Params: 4,444
#  [Params] Main (BG) Network : 4,444 parameters
#
# [Model: spatial] Total Params: 5,566
#  [Params] Main (BG) Network : 5,566 parameters
#
# [Model: spatial] Total Params: 6,814
#  [Params] Main (BG) Network : 6,814 parameters
#
# [Model: spatial] Total Params: 8,188
#  [Params] Main (BG) Network : 8,188 parameters
#
# [Model: spatial] Total Params: 9,688
#  [Params] Main (BG) Network : 9,688 parameters
#
# [Model: spatial] Total Params: 11,314
#  [Params] Main (BG) Network : 11,314 parameters
#
# [Model: spatial] Total Params: 13,066
#  [Params] Main (BG) Network : 13,066 parameters
#
# [Model: spatial] Total Params: 14,944
#  [Params] Main (BG) Network : 14,944 parameters
#
# [Model: spatial] Total Params: 16,948
#  [Params] Main (BG) Network : 16,948 parameters
#
# [Model: spatial] Total Params: 19,078
#  [Params] Main (BG) Network : 19,078 parameters
#
# [Model: spatial] Total Params: 21,334
#  [Params] Main (BG) Network : 21,334 parameters
#
# [Model: spatial] Total Params: 23,716
#  [Params] Main (BG) Network : 23,716 parameters
#
# [Model: spatial] Total Params: 26,224
#  [Params] Main (BG) Network : 26,224 parameters
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
#
# [Model: spatial] Total Params: 31,618
#  [Params] Main (BG) Network : 31,618 parameters
#
# [Model: spatial] Total Params: 34,504
#  [Params] Main (BG) Network : 34,504 parameters
#
# [Model: spatial] Total Params: 37,516
#  [Params] Main (BG) Network : 37,516 parameters
#
# [Model: spatial] Total Params: 40,654
#  [Params] Main (BG) Network : 40,654 parameters
#
# [Model: spatial] Total Params: 43,918
#  [Params] Main (BG) Network : 43,918 parameters
#
# [Model: spatial] Total Params: 47,308
#  [Params] Main (BG) Network : 47,308 parameters
#
# [Model: spatial] Total Params: 50,824
#  [Params] Main (BG) Network : 50,824 parameters
#
# [Model: spatial] Total Params: 54,466
#  [Params] Main (BG) Network : 54,466 parameters
#
# [Model: spatial] Total Params: 58,234
#  [Params] Main (BG) Network : 58,234 parameters
#
# [Model: spatial] Total Params: 62,128
#  [Params] Main (BG) Network : 62,128 parameters
#
# [Model: spatial] Total Params: 66,148
#  [Params] Main (BG) Network : 66,148 parameters
#
# [Model: spatial] Total Params: 70,294
#  [Params] Main (BG) Network : 70,294 parameters
#
# [Model: spatial] Total Params: 74,566
#  [Params] Main (BG) Network : 74,566 parameters
#
# [Model: spatial] Total Params: 78,964
#  [Params] Main (BG) Network : 78,964 parameters
#
# [Model: spatial] Total Params: 83,488
#  [Params] Main (BG) Network : 83,488 parameters
#
# [Model: spatial] Total Params: 88,138
#  [Params] Main (BG) Network : 88,138 parameters
#
# [Model: spatial] Total Params: 92,914
#  [Params] Main (BG) Network : 92,914 parameters
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
#
# [Model: spatial] Total Params: 102,844
#  [Params] Main (BG) Network : 102,844 parameters
#
# [Model: spatial] Total Params: 107,998
#  [Params] Main (BG) Network : 107,998 parameters
#
# [Model: spatial] Total Params: 113,278
#  [Params] Main (BG) Network : 113,278 parameters
#
# [Model: spatial] Total Params: 118,684
#  [Params] Main (BG) Network : 118,684 parameters
#
# [Model: spatial] Total Params: 124,216
#  [Params] Main (BG) Network : 124,216 parameters
#
# [Model: spatial] Total Params: 129,874
#  [Params] Main (BG) Network : 129,874 parameters
#
# [Model: spatial] Total Params: 135,658
#  [Params] Main (BG) Network : 135,658 parameters
#
# [Model: spatial] Total Params: 141,568
#  [Params] Main (BG) Network : 141,568 parameters
#
# [Model: spatial] Total Params: 147,604
#  [Params] Main (BG) Network : 147,604 parameters
#
# [Model: spatial] Total Params: 153,766
#  [Params] Main (BG) Network : 153,766 parameters
#
# [Model: spatial] Total Params: 160,054
#  [Params] Main (BG) Network : 160,054 parameters
#
# [Model: spatial] Total Params: 166,468
#  [Params] Main (BG) Network : 166,468 parameters
#
# [Model: spatial] Total Params: 173,008
#  [Params] Main (BG) Network : 173,008 parameters
#
# [Model: spatial] Total Params: 179,674
#  [Params] Main (BG) Network : 179,674 parameters
#
# [Model: spatial] Total Params: 186,466
#  [Params] Main (BG) Network : 186,466 parameters
#
# [Model: spatial] Total Params: 193,384
#  [Params] Main (BG) Network : 193,384 parameters
#
# [Model: spatial] Total Params: 200,428
#  [Params] Main (BG) Network : 200,428 parameters
#
# [Model: spatial] Total Params: 207,598
#  [Params] Main (BG) Network : 207,598 parameters
#
# [Model: spatial] Total Params: 214,894
#  [Params] Main (BG) Network : 214,894 parameters
#
# [Model: spatial] Total Params: 222,316
#  [Params] Main (BG) Network : 222,316 parameters
#
# [Model: spatial] Total Params: 229,864
#  [Params] Main (BG) Network : 229,864 parameters
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
#
# [Model: spatial] Total Params: 245,338
#  [Params] Main (BG) Network : 245,338 parameters
#
# [Model: spatial] Total Params: 253,264
#  [Params] Main (BG) Network : 253,264 parameters
#
# [Model: spatial] Total Params: 261,316
#  [Params] Main (BG) Network : 261,316 parameters
#
# [Model: spatial] Total Params: 269,494
#  [Params] Main (BG) Network : 269,494 parameters
#
# [Model: spatial] Total Params: 277,798
#  [Params] Main (BG) Network : 277,798 parameters
#
# [Model: spatial] Total Params: 286,228
#  [Params] Main (BG) Network : 286,228 parameters
#
# [Model: spatial] Total Params: 294,784
#  [Params] Main (BG) Network : 294,784 parameters
#
# [Model: spatial] Total Params: 303,466
#  [Params] Main (BG) Network : 303,466 parameters
#
# [Model: spatial] Total Params: 312,274
#  [Params] Main (BG) Network : 312,274 parameters
#
# [Model: spatial] Total Params: 321,208
#  [Params] Main (BG) Network : 321,208 parameters
#
# [Model: spatial] Total Params: 330,268
#  [Params] Main (BG) Network : 330,268 parameters
#
# [Model: spatial] Total Params: 339,454
#  [Params] Main (BG) Network : 339,454 parameters
#
# [Model: spatial] Total Params: 348,766
#  [Params] Main (BG) Network : 348,766 parameters
#
# [Model: spatial] Total Params: 358,204
#  [Params] Main (BG) Network : 358,204 parameters
#
# [Model: spatial] Total Params: 367,768
#  [Params] Main (BG) Network : 367,768 parameters
#
# [Model: spatial] Total Params: 377,458
#  [Params] Main (BG) Network : 377,458 parameters
#
# [Model: spatial] Total Params: 387,274
#  [Params] Main (BG) Network : 387,274 parameters
#
# [Model: spatial] Total Params: 397,216
#  [Params] Main (BG) Network : 397,216 parameters
#
# [Model: spatial] Total Params: 407,284
#  [Params] Main (BG) Network : 407,284 parameters
#
# [Model: spatial] Total Params: 417,478
#  [Params] Main (BG) Network : 417,478 parameters
#
# [Model: spatial] Total Params: 427,798
#  [Params] Main (BG) Network : 427,798 parameters
#
# [Model: spatial] Total Params: 438,244
#  [Params] Main (BG) Network : 438,244 parameters
#
# [Model: spatial] Total Params: 448,816
#  [Params] Main (BG) Network : 448,816 parameters
#
# [Model: spatial] Total Params: 459,514
#  [Params] Main (BG) Network : 459,514 parameters
#
# [Model: spatial] Total Params: 470,338
#  [Params] Main (BG) Network : 470,338 parameters
#
# [Model: spatial] Total Params: 481,288
#  [Params] Main (BG) Network : 481,288 parameters
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
#
# [Model: spatial] Total Params: 503,566
#  [Params] Main (BG) Network : 503,566 parameters
#
# [Model: spatial] Total Params: 514,894
#  [Params] Main (BG) Network : 514,894 parameters
#
# [Model: spatial] Total Params: 526,348
#  [Params] Main (BG) Network : 526,348 parameters
#
# [Model: spatial] Total Params: 537,928
#  [Params] Main (BG) Network : 537,928 parameters
#
# [Model: spatial] Total Params: 549,634
#  [Params] Main (BG) Network : 549,634 parameters
#
# [Model: spatial] Total Params: 561,466
#  [Params] Main (BG) Network : 561,466 parameters
#
# [Model: spatial] Total Params: 573,424
#  [Params] Main (BG) Network : 573,424 parameters
#
# [Model: spatial] Total Params: 585,508
#  [Params] Main (BG) Network : 585,508 parameters
#
# [Model: spatial] Total Params: 597,718
#  [Params] Main (BG) Network : 597,718 parameters
#
# [Model: spatial] Total Params: 610,054
#  [Params] Main (BG) Network : 610,054 parameters
#
# [Model: spatial] Total Params: 622,516
#  [Params] Main (BG) Network : 622,516 parameters
#
# [Model: spatial] Total Params: 724
#  [Params] Main (BG) Network : 724 parameters
#
# [Model: spatial] Total Params: 1,216
#  [Params] Main (BG) Network : 1,216 parameters
#
# [Model: spatial] Total Params: 1,834
#  [Params] Main (BG) Network : 1,834 parameters
#
# [Model: spatial] Total Params: 2,578
#  [Params] Main (BG) Network : 2,578 parameters
#
# [Model: spatial] Total Params: 3,448
#  [Params] Main (BG) Network : 3,448 parameters
#
# [Model: spatial] Total Params: 4,444
#  [Params] Main (BG) Network : 4,444 parameters
#
# [Model: spatial] Total Params: 5,566
#  [Params] Main (BG) Network : 5,566 parameters
#
# [Model: spatial] Total Params: 6,814
#  [Params] Main (BG) Network : 6,814 parameters
#
# [Model: spatial] Total Params: 8,188
#  [Params] Main (BG) Network : 8,188 parameters
#
# [Model: spatial] Total Params: 9,688
#  [Params] Main (BG) Network : 9,688 parameters
#
# [Model: spatial] Total Params: 11,314
#  [Params] Main (BG) Network : 11,314 parameters
#
# [Model: spatial] Total Params: 13,066
#  [Params] Main (BG) Network : 13,066 parameters
#
# [Model: spatial] Total Params: 14,944
#  [Params] Main (BG) Network : 14,944 parameters
#
# [Model: spatial] Total Params: 16,948
#  [Params] Main (BG) Network : 16,948 parameters
#
# [Model: spatial] Total Params: 19,078
#  [Params] Main (BG) Network : 19,078 parameters
#
# [Model: spatial] Total Params: 21,334
#  [Params] Main (BG) Network : 21,334 parameters
#
# [Model: spatial] Total Params: 23,716
#  [Params] Main (BG) Network : 23,716 parameters
#
# [Model: spatial] Total Params: 26,224
#  [Params] Main (BG) Network : 26,224 parameters
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
#
# [Model: spatial] Total Params: 31,618
#  [Params] Main (BG) Network : 31,618 parameters
#
# [Model: spatial] Total Params: 34,504
#  [Params] Main (BG) Network : 34,504 parameters
#
# [Model: spatial] Total Params: 37,516
#  [Params] Main (BG) Network : 37,516 parameters
#
# [Model: spatial] Total Params: 40,654
#  [Params] Main (BG) Network : 40,654 parameters
#
# [Model: spatial] Total Params: 43,918
#  [Params] Main (BG) Network : 43,918 parameters
#
# [Model: spatial] Total Params: 47,308
#  [Params] Main (BG) Network : 47,308 parameters
#
# [Model: spatial] Total Params: 50,824
#  [Params] Main (BG) Network : 50,824 parameters
#
# [Model: spatial] Total Params: 54,466
#  [Params] Main (BG) Network : 54,466 parameters
#
# [Model: spatial] Total Params: 58,234
#  [Params] Main (BG) Network : 58,234 parameters
#
# [Model: spatial] Total Params: 62,128
#  [Params] Main (BG) Network : 62,128 parameters
#
# [Model: spatial] Total Params: 66,148
#  [Params] Main (BG) Network : 66,148 parameters
#
# [Model: spatial] Total Params: 70,294
#  [Params] Main (BG) Network : 70,294 parameters
#
# [Model: spatial] Total Params: 74,566
#  [Params] Main (BG) Network : 74,566 parameters
#
# [Model: spatial] Total Params: 78,964
#  [Params] Main (BG) Network : 78,964 parameters
#
# [Model: spatial] Total Params: 83,488
#  [Params] Main (BG) Network : 83,488 parameters
#
# [Model: spatial] Total Params: 88,138
#  [Params] Main (BG) Network : 88,138 parameters
#
# [Model: spatial] Total Params: 92,914
#  [Params] Main (BG) Network : 92,914 parameters
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
#
# [Model: spatial] Total Params: 102,844
#  [Params] Main (BG) Network : 102,844 parameters
#
# [Model: spatial] Total Params: 107,998
#  [Params] Main (BG) Network : 107,998 parameters
#
# [Model: spatial] Total Params: 113,278
#  [Params] Main (BG) Network : 113,278 parameters
#
# [Model: spatial] Total Params: 118,684
#  [Params] Main (BG) Network : 118,684 parameters
#
# [Model: spatial] Total Params: 124,216
#  [Params] Main (BG) Network : 124,216 parameters
#
# [Model: spatial] Total Params: 129,874
#  [Params] Main (BG) Network : 129,874 parameters
#
# [Model: spatial] Total Params: 135,658
#  [Params] Main (BG) Network : 135,658 parameters
#
# [Model: spatial] Total Params: 141,568
#  [Params] Main (BG) Network : 141,568 parameters
#
# [Model: spatial] Total Params: 147,604
#  [Params] Main (BG) Network : 147,604 parameters
#
# [Model: spatial] Total Params: 153,766
#  [Params] Main (BG) Network : 153,766 parameters
#
# [Model: spatial] Total Params: 160,054
#  [Params] Main (BG) Network : 160,054 parameters
#
# [Model: spatial] Total Params: 166,468
#  [Params] Main (BG) Network : 166,468 parameters
#
# [Model: spatial] Total Params: 173,008
#  [Params] Main (BG) Network : 173,008 parameters
#
# [Model: spatial] Total Params: 179,674
#  [Params] Main (BG) Network : 179,674 parameters
#
# [Model: spatial] Total Params: 186,466
#  [Params] Main (BG) Network : 186,466 parameters
#
# [Model: spatial] Total Params: 193,384
#  [Params] Main (BG) Network : 193,384 parameters
#
# [Model: spatial] Total Params: 200,428
#  [Params] Main (BG) Network : 200,428 parameters
#
# [Model: spatial] Total Params: 207,598
#  [Params] Main (BG) Network : 207,598 parameters
#
# [Model: spatial] Total Params: 214,894
#  [Params] Main (BG) Network : 214,894 parameters
#
# [Model: spatial] Total Params: 222,316
#  [Params] Main (BG) Network : 222,316 parameters
#
# [Model: spatial] Total Params: 229,864
#  [Params] Main (BG) Network : 229,864 parameters
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
#
# [Model: spatial] Total Params: 245,338
#  [Params] Main (BG) Network : 245,338 parameters
#
# [Model: spatial] Total Params: 253,264
#  [Params] Main (BG) Network : 253,264 parameters
#
# [Model: spatial] Total Params: 261,316
#  [Params] Main (BG) Network : 261,316 parameters
#
# [Model: spatial] Total Params: 269,494
#  [Params] Main (BG) Network : 269,494 parameters
#
# [Model: spatial] Total Params: 277,798
#  [Params] Main (BG) Network : 277,798 parameters
#
# [Model: spatial] Total Params: 286,228
#  [Params] Main (BG) Network : 286,228 parameters
#
# [Model: spatial] Total Params: 294,784
#  [Params] Main (BG) Network : 294,784 parameters
#
# [Model: spatial] Total Params: 303,466
#  [Params] Main (BG) Network : 303,466 parameters
#
# [Model: spatial] Total Params: 312,274
#  [Params] Main (BG) Network : 312,274 parameters
#
# [Model: spatial] Total Params: 321,208
#  [Params] Main (BG) Network : 321,208 parameters
#
# [Model: spatial] Total Params: 330,268
#  [Params] Main (BG) Network : 330,268 parameters
#
# [Model: spatial] Total Params: 339,454
#  [Params] Main (BG) Network : 339,454 parameters
#
# [Model: spatial] Total Params: 348,766
#  [Params] Main (BG) Network : 348,766 parameters
#
# [Model: spatial] Total Params: 358,204
#  [Params] Main (BG) Network : 358,204 parameters
#
# [Model: spatial] Total Params: 367,768
#  [Params] Main (BG) Network : 367,768 parameters
#
# [Model: spatial] Total Params: 377,458
#  [Params] Main (BG) Network : 377,458 parameters
#
# [Model: spatial] Total Params: 387,274
#  [Params] Main (BG) Network : 387,274 parameters
#
# [Model: spatial] Total Params: 397,216
#  [Params] Main (BG) Network : 397,216 parameters
#
# [Model: spatial] Total Params: 407,284
#  [Params] Main (BG) Network : 407,284 parameters
#
# [Model: spatial] Total Params: 417,478
#  [Params] Main (BG) Network : 417,478 parameters
#
# [Model: spatial] Total Params: 427,798
#  [Params] Main (BG) Network : 427,798 parameters
#
# [Model: spatial] Total Params: 438,244
#  [Params] Main (BG) Network : 438,244 parameters
#
# [Model: spatial] Total Params: 448,816
#  [Params] Main (BG) Network : 448,816 parameters
#
# [Model: spatial] Total Params: 459,514
#  [Params] Main (BG) Network : 459,514 parameters
#
# [Model: spatial] Total Params: 470,338
#  [Params] Main (BG) Network : 470,338 parameters
#
# [Model: spatial] Total Params: 481,288
#  [Params] Main (BG) Network : 481,288 parameters
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
#
# [Model: spatial] Total Params: 503,566
#  [Params] Main (BG) Network : 503,566 parameters
#
# [Model: spatial] Total Params: 514,894
#  [Params] Main (BG) Network : 514,894 parameters
#
# [Model: spatial] Total Params: 526,348
#  [Params] Main (BG) Network : 526,348 parameters
#
# [Model: spatial] Total Params: 537,928
#  [Params] Main (BG) Network : 537,928 parameters
#
# [Model: spatial] Total Params: 549,634
#  [Params] Main (BG) Network : 549,634 parameters
#
# [Model: spatial] Total Params: 561,466
#  [Params] Main (BG) Network : 561,466 parameters
#
# [Model: spatial] Total Params: 573,424
#  [Params] Main (BG) Network : 573,424 parameters
#
# [Model: spatial] Total Params: 585,508
#  [Params] Main (BG) Network : 585,508 parameters
#
# [Model: spatial] Total Params: 597,718
#  [Params] Main (BG) Network : 597,718 parameters
#
# [Model: spatial] Total Params: 610,054
#  [Params] Main (BG) Network : 610,054 parameters
#
# [Model: spatial] Total Params: 622,516
#  [Params] Main (BG) Network : 622,516 parameters
#
# [Model: spatial] Total Params: 724
#  [Params] Main (BG) Network : 724 parameters
#
# [Model: spatial] Total Params: 1,216
#  [Params] Main (BG) Network : 1,216 parameters
#
# [Model: spatial] Total Params: 1,834
#  [Params] Main (BG) Network : 1,834 parameters
#
# [Model: spatial] Total Params: 2,578
#  [Params] Main (BG) Network : 2,578 parameters
#
# [Model: spatial] Total Params: 3,448
#  [Params] Main (BG) Network : 3,448 parameters
#
# [Model: spatial] Total Params: 4,444
#  [Params] Main (BG) Network : 4,444 parameters
#
# [Model: spatial] Total Params: 5,566
#  [Params] Main (BG) Network : 5,566 parameters
#
# [Model: spatial] Total Params: 6,814
#  [Params] Main (BG) Network : 6,814 parameters
#
# [Model: spatial] Total Params: 8,188
#  [Params] Main (BG) Network : 8,188 parameters
#
# [Model: spatial] Total Params: 9,688
#  [Params] Main (BG) Network : 9,688 parameters
#
# [Model: spatial] Total Params: 11,314
#  [Params] Main (BG) Network : 11,314 parameters
#
# [Model: spatial] Total Params: 13,066
#  [Params] Main (BG) Network : 13,066 parameters
#
# [Model: spatial] Total Params: 14,944
#  [Params] Main (BG) Network : 14,944 parameters
#
# [Model: spatial] Total Params: 16,948
#  [Params] Main (BG) Network : 16,948 parameters
#
# [Model: spatial] Total Params: 19,078
#  [Params] Main (BG) Network : 19,078 parameters
#
# [Model: spatial] Total Params: 21,334
#  [Params] Main (BG) Network : 21,334 parameters
#
# [Model: spatial] Total Params: 23,716
#  [Params] Main (BG) Network : 23,716 parameters
#
# [Model: spatial] Total Params: 26,224
#  [Params] Main (BG) Network : 26,224 parameters
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
#
# [Model: spatial] Total Params: 31,618
#  [Params] Main (BG) Network : 31,618 parameters
#
# [Model: spatial] Total Params: 34,504
#  [Params] Main (BG) Network : 34,504 parameters
#
# [Model: spatial] Total Params: 37,516
#  [Params] Main (BG) Network : 37,516 parameters
#
# [Model: spatial] Total Params: 40,654
#  [Params] Main (BG) Network : 40,654 parameters
#
# [Model: spatial] Total Params: 43,918
#  [Params] Main (BG) Network : 43,918 parameters
#
# [Model: spatial] Total Params: 47,308
#  [Params] Main (BG) Network : 47,308 parameters
#
# [Model: spatial] Total Params: 50,824
#  [Params] Main (BG) Network : 50,824 parameters
#
# [Model: spatial] Total Params: 54,466
#  [Params] Main (BG) Network : 54,466 parameters
#
# [Model: spatial] Total Params: 58,234
#  [Params] Main (BG) Network : 58,234 parameters
#
# [Model: spatial] Total Params: 62,128
#  [Params] Main (BG) Network : 62,128 parameters
#
# [Model: spatial] Total Params: 66,148
#  [Params] Main (BG) Network : 66,148 parameters
#
# [Model: spatial] Total Params: 70,294
#  [Params] Main (BG) Network : 70,294 parameters
#
# [Model: spatial] Total Params: 74,566
#  [Params] Main (BG) Network : 74,566 parameters
#
# [Model: spatial] Total Params: 78,964
#  [Params] Main (BG) Network : 78,964 parameters
#
# [Model: spatial] Total Params: 83,488
#  [Params] Main (BG) Network : 83,488 parameters
#
# [Model: spatial] Total Params: 88,138
#  [Params] Main (BG) Network : 88,138 parameters
#
# [Model: spatial] Total Params: 92,914
#  [Params] Main (BG) Network : 92,914 parameters
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
#
# [Model: spatial] Total Params: 102,844
#  [Params] Main (BG) Network : 102,844 parameters
#
# [Model: spatial] Total Params: 107,998
#  [Params] Main (BG) Network : 107,998 parameters
#
# [Model: spatial] Total Params: 113,278
#  [Params] Main (BG) Network : 113,278 parameters
#
# [Model: spatial] Total Params: 118,684
#  [Params] Main (BG) Network : 118,684 parameters
#
# [Model: spatial] Total Params: 124,216
#  [Params] Main (BG) Network : 124,216 parameters
#
# [Model: spatial] Total Params: 129,874
#  [Params] Main (BG) Network : 129,874 parameters
#
# [Model: spatial] Total Params: 135,658
#  [Params] Main (BG) Network : 135,658 parameters
#
# [Model: spatial] Total Params: 141,568
#  [Params] Main (BG) Network : 141,568 parameters
#
# [Model: spatial] Total Params: 147,604
#  [Params] Main (BG) Network : 147,604 parameters
#
# [Model: spatial] Total Params: 153,766
#  [Params] Main (BG) Network : 153,766 parameters
#
# [Model: spatial] Total Params: 160,054
#  [Params] Main (BG) Network : 160,054 parameters
#
# [Model: spatial] Total Params: 166,468
#  [Params] Main (BG) Network : 166,468 parameters
#
# [Model: spatial] Total Params: 173,008
#  [Params] Main (BG) Network : 173,008 parameters
#
# [Model: spatial] Total Params: 179,674
#  [Params] Main (BG) Network : 179,674 parameters
#
# [Model: spatial] Total Params: 186,466
#  [Params] Main (BG) Network : 186,466 parameters
#
# [Model: spatial] Total Params: 193,384
#  [Params] Main (BG) Network : 193,384 parameters
#
# [Model: spatial] Total Params: 200,428
#  [Params] Main (BG) Network : 200,428 parameters
#
# [Model: spatial] Total Params: 207,598
#  [Params] Main (BG) Network : 207,598 parameters
#
# [Model: spatial] Total Params: 214,894
#  [Params] Main (BG) Network : 214,894 parameters
#
# [Model: spatial] Total Params: 222,316
#  [Params] Main (BG) Network : 222,316 parameters
#
# [Model: spatial] Total Params: 229,864
#  [Params] Main (BG) Network : 229,864 parameters
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
#
# [Model: spatial] Total Params: 245,338
#  [Params] Main (BG) Network : 245,338 parameters
#
# [Model: spatial] Total Params: 253,264
#  [Params] Main (BG) Network : 253,264 parameters
#
# [Model: spatial] Total Params: 261,316
#  [Params] Main (BG) Network : 261,316 parameters
#
# [Model: spatial] Total Params: 269,494
#  [Params] Main (BG) Network : 269,494 parameters
#
# [Model: spatial] Total Params: 277,798
#  [Params] Main (BG) Network : 277,798 parameters
#
# [Model: spatial] Total Params: 286,228
#  [Params] Main (BG) Network : 286,228 parameters
#
# [Model: spatial] Total Params: 294,784
#  [Params] Main (BG) Network : 294,784 parameters
#
# [Model: spatial] Total Params: 303,466
#  [Params] Main (BG) Network : 303,466 parameters
#
# [Model: spatial] Total Params: 312,274
#  [Params] Main (BG) Network : 312,274 parameters
#
# [Model: spatial] Total Params: 321,208
#  [Params] Main (BG) Network : 321,208 parameters
#
# [Model: spatial] Total Params: 330,268
#  [Params] Main (BG) Network : 330,268 parameters
#
# [Model: spatial] Total Params: 339,454
#  [Params] Main (BG) Network : 339,454 parameters
#
# [Model: spatial] Total Params: 348,766
#  [Params] Main (BG) Network : 348,766 parameters
#
# [Model: spatial] Total Params: 358,204
#  [Params] Main (BG) Network : 358,204 parameters
#
# [Model: spatial] Total Params: 367,768
#  [Params] Main (BG) Network : 367,768 parameters
#
# [Model: spatial] Total Params: 377,458
#  [Params] Main (BG) Network : 377,458 parameters
#
# [Model: spatial] Total Params: 387,274
#  [Params] Main (BG) Network : 387,274 parameters
#
# [Model: spatial] Total Params: 397,216
#  [Params] Main (BG) Network : 397,216 parameters
#
# [Model: spatial] Total Params: 407,284
#  [Params] Main (BG) Network : 407,284 parameters
#
# [Model: spatial] Total Params: 417,478
#  [Params] Main (BG) Network : 417,478 parameters
#
# [Model: spatial] Total Params: 427,798
#  [Params] Main (BG) Network : 427,798 parameters
#
# [Model: spatial] Total Params: 438,244
#  [Params] Main (BG) Network : 438,244 parameters
#
# [Model: spatial] Total Params: 448,816
#  [Params] Main (BG) Network : 448,816 parameters
#
# [Model: spatial] Total Params: 459,514
#  [Params] Main (BG) Network : 459,514 parameters
#
# [Model: spatial] Total Params: 470,338
#  [Params] Main (BG) Network : 470,338 parameters
#
# [Model: spatial] Total Params: 481,288
#  [Params] Main (BG) Network : 481,288 parameters
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
#
# [Model: spatial] Total Params: 503,566
#  [Params] Main (BG) Network : 503,566 parameters
#
# [Model: spatial] Total Params: 514,894
#  [Params] Main (BG) Network : 514,894 parameters
#
# [Model: spatial] Total Params: 526,348
#  [Params] Main (BG) Network : 526,348 parameters
#
# [Model: spatial] Total Params: 537,928
#  [Params] Main (BG) Network : 537,928 parameters
#
# [Model: spatial] Total Params: 549,634
#  [Params] Main (BG) Network : 549,634 parameters
#
# [Model: spatial] Total Params: 561,466
#  [Params] Main (BG) Network : 561,466 parameters
#
# [Model: spatial] Total Params: 573,424
#  [Params] Main (BG) Network : 573,424 parameters
#
# [Model: spatial] Total Params: 585,508
#  [Params] Main (BG) Network : 585,508 parameters
#
# [Model: spatial] Total Params: 597,718
#  [Params] Main (BG) Network : 597,718 parameters
#
# [Model: spatial] Total Params: 610,054
#  [Params] Main (BG) Network : 610,054 parameters
#
# [Model: spatial] Total Params: 622,516
#  [Params] Main (BG) Network : 622,516 parameters
#
# [Model: spatial] Total Params: 724
#  [Params] Main (BG) Network : 724 parameters
#
# [Model: spatial] Total Params: 1,216
#  [Params] Main (BG) Network : 1,216 parameters
#
# [Model: spatial] Total Params: 1,834
#  [Params] Main (BG) Network : 1,834 parameters
#
# [Model: spatial] Total Params: 2,578
#  [Params] Main (BG) Network : 2,578 parameters
#
# [Model: spatial] Total Params: 3,448
#  [Params] Main (BG) Network : 3,448 parameters
#
# [Model: spatial] Total Params: 4,444
#  [Params] Main (BG) Network : 4,444 parameters
#
# [Model: spatial] Total Params: 5,566
#  [Params] Main (BG) Network : 5,566 parameters
#
# [Model: spatial] Total Params: 6,814
#  [Params] Main (BG) Network : 6,814 parameters
#
# [Model: spatial] Total Params: 8,188
#  [Params] Main (BG) Network : 8,188 parameters
#
# [Model: spatial] Total Params: 9,688
#  [Params] Main (BG) Network : 9,688 parameters
#
# [Model: spatial] Total Params: 11,314
#  [Params] Main (BG) Network : 11,314 parameters
#
# [Model: spatial] Total Params: 13,066
#  [Params] Main (BG) Network : 13,066 parameters
#
# [Model: spatial] Total Params: 14,944
#  [Params] Main (BG) Network : 14,944 parameters
#
# [Model: spatial] Total Params: 16,948
#  [Params] Main (BG) Network : 16,948 parameters
#
# [Model: spatial] Total Params: 19,078
#  [Params] Main (BG) Network : 19,078 parameters
#
# [Model: spatial] Total Params: 21,334
#  [Params] Main (BG) Network : 21,334 parameters
#
# [Model: spatial] Total Params: 23,716
#  [Params] Main (BG) Network : 23,716 parameters
#
# [Model: spatial] Total Params: 26,224
#  [Params] Main (BG) Network : 26,224 parameters
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
#
# [Model: spatial] Total Params: 31,618
#  [Params] Main (BG) Network : 31,618 parameters
#
# [Model: spatial] Total Params: 34,504
#  [Params] Main (BG) Network : 34,504 parameters
#
# [Model: spatial] Total Params: 37,516
#  [Params] Main (BG) Network : 37,516 parameters
#
# [Model: spatial] Total Params: 40,654
#  [Params] Main (BG) Network : 40,654 parameters
#
# [Model: spatial] Total Params: 43,918
#  [Params] Main (BG) Network : 43,918 parameters
#
# [Model: spatial] Total Params: 47,308
#  [Params] Main (BG) Network : 47,308 parameters
#
# [Model: spatial] Total Params: 50,824
#  [Params] Main (BG) Network : 50,824 parameters
#
# [Model: spatial] Total Params: 54,466
#  [Params] Main (BG) Network : 54,466 parameters
#
# [Model: spatial] Total Params: 58,234
#  [Params] Main (BG) Network : 58,234 parameters
#
# [Model: spatial] Total Params: 62,128
#  [Params] Main (BG) Network : 62,128 parameters
#
# [Model: spatial] Total Params: 66,148
#  [Params] Main (BG) Network : 66,148 parameters
#
# [Model: spatial] Total Params: 70,294
#  [Params] Main (BG) Network : 70,294 parameters
#
# [Model: spatial] Total Params: 74,566
#  [Params] Main (BG) Network : 74,566 parameters
#
# [Model: spatial] Total Params: 78,964
#  [Params] Main (BG) Network : 78,964 parameters
#
# [Model: spatial] Total Params: 83,488
#  [Params] Main (BG) Network : 83,488 parameters
#
# [Model: spatial] Total Params: 88,138
#  [Params] Main (BG) Network : 88,138 parameters
#
# [Model: spatial] Total Params: 92,914
#  [Params] Main (BG) Network : 92,914 parameters
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
#
# [Model: spatial] Total Params: 102,844
#  [Params] Main (BG) Network : 102,844 parameters
#
# [Model: spatial] Total Params: 107,998
#  [Params] Main (BG) Network : 107,998 parameters
#
# [Model: spatial] Total Params: 113,278
#  [Params] Main (BG) Network : 113,278 parameters
#
# [Model: spatial] Total Params: 118,684
#  [Params] Main (BG) Network : 118,684 parameters
#
# [Model: spatial] Total Params: 124,216
#  [Params] Main (BG) Network : 124,216 parameters
#
# [Model: spatial] Total Params: 129,874
#  [Params] Main (BG) Network : 129,874 parameters
#
# [Model: spatial] Total Params: 135,658
#  [Params] Main (BG) Network : 135,658 parameters
#
# [Model: spatial] Total Params: 141,568
#  [Params] Main (BG) Network : 141,568 parameters
#
# [Model: spatial] Total Params: 147,604
#  [Params] Main (BG) Network : 147,604 parameters
#
# [Model: spatial] Total Params: 153,766
#  [Params] Main (BG) Network : 153,766 parameters
#
# [Model: spatial] Total Params: 160,054
#  [Params] Main (BG) Network : 160,054 parameters
#
# [Model: spatial] Total Params: 166,468
#  [Params] Main (BG) Network : 166,468 parameters
#
# [Model: spatial] Total Params: 173,008
#  [Params] Main (BG) Network : 173,008 parameters
#
# [Model: spatial] Total Params: 179,674
#  [Params] Main (BG) Network : 179,674 parameters
#
# [Model: spatial] Total Params: 186,466
#  [Params] Main (BG) Network : 186,466 parameters
#
# [Model: spatial] Total Params: 193,384
#  [Params] Main (BG) Network : 193,384 parameters
#
# [Model: spatial] Total Params: 200,428
#  [Params] Main (BG) Network : 200,428 parameters
#
# [Model: spatial] Total Params: 207,598
#  [Params] Main (BG) Network : 207,598 parameters
#
# [Model: spatial] Total Params: 214,894
#  [Params] Main (BG) Network : 214,894 parameters
#
# [Model: spatial] Total Params: 222,316
#  [Params] Main (BG) Network : 222,316 parameters
#
# [Model: spatial] Total Params: 229,864
#  [Params] Main (BG) Network : 229,864 parameters
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
#
# [Model: spatial] Total Params: 245,338
#  [Params] Main (BG) Network : 245,338 parameters
#
# [Model: spatial] Total Params: 253,264
#  [Params] Main (BG) Network : 253,264 parameters
#
# [Model: spatial] Total Params: 261,316
#  [Params] Main (BG) Network : 261,316 parameters
#
# [Model: spatial] Total Params: 269,494
#  [Params] Main (BG) Network : 269,494 parameters
#
# [Model: spatial] Total Params: 277,798
#  [Params] Main (BG) Network : 277,798 parameters
#
# [Model: spatial] Total Params: 286,228
#  [Params] Main (BG) Network : 286,228 parameters
#
# [Model: spatial] Total Params: 294,784
#  [Params] Main (BG) Network : 294,784 parameters
#
# [Model: spatial] Total Params: 303,466
#  [Params] Main (BG) Network : 303,466 parameters
#
# [Model: spatial] Total Params: 312,274
#  [Params] Main (BG) Network : 312,274 parameters
#
# [Model: spatial] Total Params: 321,208
#  [Params] Main (BG) Network : 321,208 parameters
#
# [Model: spatial] Total Params: 330,268
#  [Params] Main (BG) Network : 330,268 parameters
#
# [Model: spatial] Total Params: 339,454
#  [Params] Main (BG) Network : 339,454 parameters
#
# [Model: spatial] Total Params: 348,766
#  [Params] Main (BG) Network : 348,766 parameters
#
# [Model: spatial] Total Params: 358,204
#  [Params] Main (BG) Network : 358,204 parameters
#
# [Model: spatial] Total Params: 367,768
#  [Params] Main (BG) Network : 367,768 parameters
#
# [Model: spatial] Total Params: 377,458
#  [Params] Main (BG) Network : 377,458 parameters
#
# [Model: spatial] Total Params: 387,274
#  [Params] Main (BG) Network : 387,274 parameters
#
# [Model: spatial] Total Params: 397,216
#  [Params] Main (BG) Network : 397,216 parameters
#
# [Model: spatial] Total Params: 407,284
#  [Params] Main (BG) Network : 407,284 parameters
#
# [Model: spatial] Total Params: 417,478
#  [Params] Main (BG) Network : 417,478 parameters
#
# [Model: spatial] Total Params: 427,798
#  [Params] Main (BG) Network : 427,798 parameters
#
# [Model: spatial] Total Params: 438,244
#  [Params] Main (BG) Network : 438,244 parameters
#
# [Model: spatial] Total Params: 448,816
#  [Params] Main (BG) Network : 448,816 parameters
#
# [Model: spatial] Total Params: 459,514
#  [Params] Main (BG) Network : 459,514 parameters
#
# [Model: spatial] Total Params: 470,338
#  [Params] Main (BG) Network : 470,338 parameters
#
# [Model: spatial] Total Params: 481,288
#  [Params] Main (BG) Network : 481,288 parameters
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
#
# [Model: spatial] Total Params: 503,566
#  [Params] Main (BG) Network : 503,566 parameters
#
# [Model: spatial] Total Params: 514,894
#  [Params] Main (BG) Network : 514,894 parameters
#
# [Model: spatial] Total Params: 526,348
#  [Params] Main (BG) Network : 526,348 parameters
#
# [Model: spatial] Total Params: 537,928
#  [Params] Main (BG) Network : 537,928 parameters
#
# [Model: spatial] Total Params: 549,634
#  [Params] Main (BG) Network : 549,634 parameters
#
# [Model: spatial] Total Params: 561,466
#  [Params] Main (BG) Network : 561,466 parameters
#
# [Model: spatial] Total Params: 573,424
#  [Params] Main (BG) Network : 573,424 parameters
#
# [Model: spatial] Total Params: 585,508
#  [Params] Main (BG) Network : 585,508 parameters
#
# [Model: spatial] Total Params: 597,718
#  [Params] Main (BG) Network : 597,718 parameters
#
# [Model: spatial] Total Params: 610,054
#  [Params] Main (BG) Network : 610,054 parameters
#
# [Model: spatial] Total Params: 622,516
#  [Params] Main (BG) Network : 622,516 parameters
# Fixed: lr=1.0e-03 | direction=Z | 120s/config | freq_warmup=1
# REL_ERRS: [0.003, 0.005, 0.007, 0.009, 0.01]
# Model sizes (6 distinct):
#   bg_h=21  ~28,858 params
#   bg_h=39  ~97,816 params
#   bg_h=48  ~147,604 params
#   bg_h=61  ~237,538 params
#   bg_h=75  ~358,204 params
#   bg_h=88  ~492,364 params
#
# >> 30 trainings total (~60 min at 120s each)

# %%
# Reload bg_stage so re-running ONLY this cell picks up early-stop edits.
import importlib, bg_stage
importlib.reload(bg_stage)
from bg_stage import run_bg_inference, train_bg_only, unwrap_bg_model
print(f"bg_stage OK: {bg_stage.__file__}\n")

depth    = work_shape[0]
patch_sz = work_shape[2]

# GPU warm-up (not timed) using the loosest rel_err
_w_Xps, _, _ = compress_at(gt, max(REL_ERRS))
_wcfg = build_cfg(Xs, _w_Xps, max_train_time=0.5, bg_h=4,
                  steps_per_epoch=2, lr=1e-3, epochs=1, log_prefix="warmup")
set_seed(42)
train_bg_only(Xs=Xs, Xps=_w_Xps, device=device, cfg=_wcfg,
              evaluator=lambda m, c=_wcfg: (0.0, 0.0))
torch.cuda.synchronize() if torch.cuda.is_available() else None
del _w_Xps
print("GPU warm-up done\n")

results   = []   # dict: rel, bg_h, n_params, psnr, cr, model_mb, sz_mb, epochs
baselines = []   # dict: rel, cr, psnr, sz_mb   (SZ3 only, no model)

sweep_t0 = time.time()
for rel in REL_ERRS:
    Xps_list, sz_bytes, sz_cr = compress_at(gt, rel)
    base_psnr = psnr_from_arrays(gt, Xps_list[0])
    base_cr   = orig_bytes / sz_bytes
    baselines.append(dict(rel=rel, cr=base_cr, psnr=base_psnr, sz_mb=sz_bytes/1e6))
    print(f"\n{'#'*60}")
    print(f"# rel={rel:.0e} | SZ3 base: CR={base_cr:.2f}x ({sz_bytes/1e6:.2f} MB) | "
          f"base PSNR={base_psnr:.2f} dB")

    for bg_h, est_p in sweep_plan:
        cfg = build_cfg(Xs, Xps_list, max_train_time=TIME_PER_CONFIG, bg_h=bg_h,
                        steps_per_epoch=depth, lr=FIXED_LR, epochs=200,
                        log_prefix=f"r{rel:.0e}-h{bg_h}", patch_size=patch_sz)
        cfg.bg_early_stop          = False   # ablation: train every model the full budget
        cfg.bg_freq_warmup_epochs  = FREQ_WARMUP

        def evaluator(m, c=cfg, Xp=Xps_list):
            xh = run_bg_inference(unwrap_bg_model(m), Xs, Xp, c, rel)
            return psnr_from_arrays(gt, xh), 0.0

        set_seed(42)
        model, hist = train_bg_only(Xs=Xs, Xps=Xps_list, device=device,
                                    cfg=cfg, evaluator=evaluator)

        n_params    = n_params_of(model)
        psnr_vals   = [v[1] if isinstance(v, tuple) else v for v in hist.get("psnr", [])]
        psnr        = max(psnr_vals) if psnr_vals else float("nan")
        model_bytes = n_params * BYTES_PER_PARAM
        cr          = orig_bytes / (sz_bytes + model_bytes)
        results.append(dict(rel=rel, bg_h=bg_h, n_params=n_params, psnr=psnr, cr=cr,
                            model_mb=model_bytes/1e6, sz_mb=sz_bytes/1e6,
                            epochs=len(hist.get("loss", []))))
        print(f"  bg_h={bg_h:2d} ({n_params:,}p): PSNR={psnr:.2f} dB | CR={cr:.2f}x "
              f"(base {base_cr:.2f}x) | +{psnr-base_psnr:.2f} dB over SZ3")
        del model
        torch.cuda.empty_cache() if torch.cuda.is_available() else None

    del Xps_list

print(f"\n--- Sweep complete in {(time.time()-sweep_t0)/60:.1f} min "
      f"({len(results)} models over {len(REL_ERRS)} rel-errors) ---")
# Out:
# bg_stage OK: /home/sam/Halo_Finder/Final_design/base_script/bg_stage.py
#
#
# [Model: spatial] Total Params: 1,216
#  [Params] Main (BG) Network : 1,216 parameters
# warmup [Init] Epoch   0 | Global PSNR: 0.00 dB | MaxErr: 0.0
# warmup [plan] pure_train_budget=0.50s | epochs_cap=1 | steps/epoch=2 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# warmup [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# /home/sam/Halo_Finder/Final_design/base_script/bg_stage.py:471: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp, dtype=autocast_dtype):
# warmup Epoch   1 [BG] | train_wall=0.48s | Loss: 0.794550 | Freq: 3.273438 | Global: 0.00 dB | MaxErr: 0.0
# warmup [timing] first_epoch_pure_train≈0.484s (excludes this epoch's end-of-epoch eval)
#
# warmup --- Experiment [BG_only] finished ---
# warmup --- Pure training time: 0.48 s ---
# warmup [timing] epochs=1 | train_wall/epoch: mean=0.48s min=0.48s max=0.48s | sum=0.48s
# warmup --- Best global PSNR: 0.00 dB ---
# GPU warm-up done
#
#
# ############################################################
# # rel=3e-03 | SZ3 base: CR=72.43x (59.30 MB) | base PSNR=58.83 dB
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
# r3e-03-h21 [Init] Epoch   0 | Global PSNR: 58.83 dB | MaxErr: 0.0
# r3e-03-h21 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r3e-03-h21 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r3e-03-h21 Epoch   1 [BG] | train_wall=37.58s | Loss: 0.854616 | Freq: 1.687656 | Global: 60.59 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 [timing] first_epoch_pure_train≈37.584s (excludes this epoch's end-of-epoch eval)
# r3e-03-h21 Epoch   2 [BG] | train_wall=37.58s | Loss: 1.348903 | Freq: 0.740044 | Global: 61.29 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch   3 [BG] | train_wall=37.60s | Loss: 1.237531 | Freq: 0.678078 | Global: 61.46 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch   4 [BG] | train_wall=7.24s | Loss: 1.254847 | Freq: 0.723430 | Global: 61.69 dB | MaxErr: 0.0  [New Best!]
#
# r3e-03-h21 --- Experiment [BG_only] finished ---
# r3e-03-h21 --- Pure training time: 120.01 s ---
# r3e-03-h21 [timing] epochs=4 | train_wall/epoch: mean=30.00s min=7.24s max=37.60s | sum=120.01s
# r3e-03-h21 --- Best global PSNR: 61.69 dB ---
#   bg_h=21 (28,858p): PSNR=61.69 dB | CR=72.36x (base 72.43x) | +2.86 dB over SZ3
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
# r3e-03-h39 [Init] Epoch   0 | Global PSNR: 58.83 dB | MaxErr: 0.0
# r3e-03-h39 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r3e-03-h39 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r3e-03-h39 Epoch   1 [BG] | train_wall=20.20s | Loss: 0.762322 | Freq: 1.358162 | Global: 61.15 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 [timing] first_epoch_pure_train≈20.199s (excludes this epoch's end-of-epoch eval)
# r3e-03-h39 Epoch   2 [BG] | train_wall=20.22s | Loss: 1.197328 | Freq: 0.648743 | Global: 61.75 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 Epoch   3 [BG] | train_wall=20.15s | Loss: 1.117916 | Freq: 0.603664 | Global: 61.92 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 Epoch   4 [BG] | train_wall=20.17s | Loss: 1.090091 | Freq: 0.585953 | Global: 62.05 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 Epoch   5 [BG] | train_wall=20.14s | Loss: 1.073318 | Freq: 0.575031 | Global: 62.07 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 Epoch   6 [BG] | train_wall=19.12s | Loss: 1.056660 | Freq: 0.561194 | Global: 62.15 dB | MaxErr: 0.0  [New Best!]
#
# r3e-03-h39 --- Experiment [BG_only] finished ---
# r3e-03-h39 --- Pure training time: 120.01 s ---
# r3e-03-h39 [timing] epochs=6 | train_wall/epoch: mean=20.00s min=19.12s max=20.22s | sum=120.00s
# r3e-03-h39 --- Best global PSNR: 62.15 dB ---
#   bg_h=39 (97,816p): PSNR=62.15 dB | CR=72.19x (base 72.43x) | +3.32 dB over SZ3
#
# [Model: spatial] Total Params: 147,604
#  [Params] Main (BG) Network : 147,604 parameters
# r3e-03-h48 [Init] Epoch   0 | Global PSNR: 58.83 dB | MaxErr: 0.0
# r3e-03-h48 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r3e-03-h48 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r3e-03-h48 Epoch   1 [BG] | train_wall=21.37s | Loss: 0.741143 | Freq: 1.284531 | Global: 61.23 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h48 [timing] first_epoch_pure_train≈21.376s (excludes this epoch's end-of-epoch eval)
# r3e-03-h48 Epoch   2 [BG] | train_wall=21.40s | Loss: 1.170343 | Freq: 0.632820 | Global: 61.90 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h48 Epoch   3 [BG] | train_wall=21.38s | Loss: 1.091606 | Freq: 0.587265 | Global: 62.04 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h48 Epoch   4 [BG] | train_wall=21.30s | Loss: 1.062820 | Freq: 0.569103 | Global: 62.12 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h48 Epoch   5 [BG] | train_wall=21.34s | Loss: 1.047336 | Freq: 0.559076 | Global: 62.17 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h48 Epoch   6 [BG] | train_wall=13.21s | Loss: 1.041795 | Freq: 0.555443 | Global: 62.33 dB | MaxErr: 0.0  [New Best!]
#
# r3e-03-h48 --- Experiment [BG_only] finished ---
# r3e-03-h48 --- Pure training time: 120.01 s ---
# r3e-03-h48 [timing] epochs=6 | train_wall/epoch: mean=20.00s min=13.21s max=21.40s | sum=120.00s
# r3e-03-h48 --- Best global PSNR: 62.33 dB ---
#   bg_h=48 (147,604p): PSNR=62.33 dB | CR=72.07x (base 72.43x) | +3.51 dB over SZ3
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
# r3e-03-h61 [Init] Epoch   0 | Global PSNR: 58.83 dB | MaxErr: 0.0
# r3e-03-h61 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r3e-03-h61 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r3e-03-h61 Epoch   1 [BG] | train_wall=26.24s | Loss: 0.718445 | Freq: 1.230572 | Global: 61.26 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h61 [timing] first_epoch_pure_train≈26.241s (excludes this epoch's end-of-epoch eval)
# r3e-03-h61 Epoch   2 [BG] | train_wall=26.20s | Loss: 1.124824 | Freq: 0.605949 | Global: 61.93 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h61 Epoch   3 [BG] | train_wall=26.20s | Loss: 1.060381 | Freq: 0.567440 | Global: 62.13 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h61 Epoch   4 [BG] | train_wall=26.24s | Loss: 1.036684 | Freq: 0.552244 | Global: 62.20 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h61 Epoch   5 [BG] | train_wall=15.14s | Loss: 1.028322 | Freq: 0.548871 | Global: 62.38 dB | MaxErr: 0.0  [New Best!]
#
# r3e-03-h61 --- Experiment [BG_only] finished ---
# r3e-03-h61 --- Pure training time: 120.02 s ---
# r3e-03-h61 [timing] epochs=5 | train_wall/epoch: mean=24.00s min=15.14s max=26.24s | sum=120.02s
# r3e-03-h61 --- Best global PSNR: 62.38 dB ---
#   bg_h=61 (237,538p): PSNR=62.38 dB | CR=71.85x (base 72.43x) | +3.55 dB over SZ3
#
# [Model: spatial] Total Params: 358,204
#  [Params] Main (BG) Network : 358,204 parameters
# r3e-03-h75 [Init] Epoch   0 | Global PSNR: 58.83 dB | MaxErr: 0.0
# r3e-03-h75 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r3e-03-h75 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r3e-03-h75 Epoch   1 [BG] | train_wall=36.69s | Loss: 0.694950 | Freq: 1.180573 | Global: 61.70 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h75 [timing] first_epoch_pure_train≈36.688s (excludes this epoch's end-of-epoch eval)
# r3e-03-h75 Epoch   2 [BG] | train_wall=36.68s | Loss: 1.112359 | Freq: 0.600487 | Global: 62.05 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h75 Epoch   3 [BG] | train_wall=36.69s | Loss: 1.054303 | Freq: 0.563263 | Global: 62.22 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h75 Epoch   4 [BG] | train_wall=9.96s | Loss: 1.061501 | Freq: 0.591797 | Global: 62.35 dB | MaxErr: 0.0  [New Best!]
#
# r3e-03-h75 --- Experiment [BG_only] finished ---
# r3e-03-h75 --- Pure training time: 120.02 s ---
# r3e-03-h75 [timing] epochs=4 | train_wall/epoch: mean=30.00s min=9.96s max=36.69s | sum=120.01s
# r3e-03-h75 --- Best global PSNR: 62.35 dB ---
#   bg_h=75 (358,204p): PSNR=62.35 dB | CR=71.57x (base 72.43x) | +3.52 dB over SZ3
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
# r3e-03-h88 [Init] Epoch   0 | Global PSNR: 58.83 dB | MaxErr: 0.0
# r3e-03-h88 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r3e-03-h88 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r3e-03-h88 Epoch   1 [BG] | train_wall=42.07s | Loss: 0.680491 | Freq: 1.191940 | Global: 61.88 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h88 [timing] first_epoch_pure_train≈42.074s (excludes this epoch's end-of-epoch eval)
# r3e-03-h88 Epoch   2 [BG] | train_wall=42.15s | Loss: 1.071394 | Freq: 0.574856 | Global: 62.10 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h88 Epoch   3 [BG] | train_wall=35.79s | Loss: 1.016386 | Freq: 0.535471 | Global: 62.34 dB | MaxErr: 0.0  [New Best!]
#
# r3e-03-h88 --- Experiment [BG_only] finished ---
# r3e-03-h88 --- Pure training time: 120.02 s ---
# r3e-03-h88 [timing] epochs=3 | train_wall/epoch: mean=40.00s min=35.79s max=42.15s | sum=120.01s
# r3e-03-h88 --- Best global PSNR: 62.34 dB ---
#   bg_h=88 (492,364p): PSNR=62.34 dB | CR=71.25x (base 72.43x) | +3.51 dB over SZ3
#
# ############################################################
# # rel=5e-03 | SZ3 base: CR=108.15x (39.71 MB) | base PSNR=54.94 dB
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
# r5e-03-h21 [Init] Epoch   0 | Global PSNR: 54.94 dB | MaxErr: 0.0
# r5e-03-h21 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r5e-03-h21 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r5e-03-h21 Epoch   1 [BG] | train_wall=37.62s | Loss: 0.837596 | Freq: 1.536987 | Global: 56.45 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h21 [timing] first_epoch_pure_train≈37.623s (excludes this epoch's end-of-epoch eval)
# r5e-03-h21 Epoch   2 [BG] | train_wall=37.61s | Loss: 1.282775 | Freq: 0.660484 | Global: 57.09 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h21 Epoch   3 [BG] | train_wall=37.60s | Loss: 1.171406 | Freq: 0.594879 | Global: 57.33 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h21 Epoch   4 [BG] | train_wall=7.20s | Loss: 1.153924 | Freq: 0.615792 | Global: 57.51 dB | MaxErr: 0.0  [New Best!]
#
# r5e-03-h21 --- Experiment [BG_only] finished ---
# r5e-03-h21 --- Pure training time: 120.04 s ---
# r5e-03-h21 [timing] epochs=4 | train_wall/epoch: mean=30.01s min=7.20s max=37.62s | sum=120.03s
# r5e-03-h21 --- Best global PSNR: 57.51 dB ---
#   bg_h=21 (28,858p): PSNR=57.51 dB | CR=107.99x (base 108.15x) | +2.57 dB over SZ3
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
# r5e-03-h39 [Init] Epoch   0 | Global PSNR: 54.94 dB | MaxErr: 0.0
# r5e-03-h39 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r5e-03-h39 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r5e-03-h39 Epoch   1 [BG] | train_wall=20.21s | Loss: 0.745621 | Freq: 1.232208 | Global: 57.09 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h39 [timing] first_epoch_pure_train≈20.211s (excludes this epoch's end-of-epoch eval)
# r5e-03-h39 Epoch   2 [BG] | train_wall=20.24s | Loss: 1.130384 | Freq: 0.568077 | Global: 57.42 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h39 Epoch   3 [BG] | train_wall=20.19s | Loss: 1.048027 | Freq: 0.520926 | Global: 57.39 dB | MaxErr: 0.0
# r5e-03-h39 Epoch   4 [BG] | train_wall=20.21s | Loss: 1.027976 | Freq: 0.508276 | Global: 57.67 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h39 Epoch   5 [BG] | train_wall=20.21s | Loss: 1.004283 | Freq: 0.493258 | Global: 57.73 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h39 Epoch   6 [BG] | train_wall=18.94s | Loss: 0.991858 | Freq: 0.482721 | Global: 57.96 dB | MaxErr: 0.0  [New Best!]
#
# r5e-03-h39 --- Experiment [BG_only] finished ---
# r5e-03-h39 --- Pure training time: 120.00 s ---
# r5e-03-h39 [timing] epochs=6 | train_wall/epoch: mean=20.00s min=18.94s max=20.24s | sum=120.00s
# r5e-03-h39 --- Best global PSNR: 57.96 dB ---
#   bg_h=39 (97,816p): PSNR=57.96 dB | CR=107.62x (base 108.15x) | +3.02 dB over SZ3
#
# [Model: spatial] Total Params: 147,604
#  [Params] Main (BG) Network : 147,604 parameters
# r5e-03-h48 [Init] Epoch   0 | Global PSNR: 54.94 dB | MaxErr: 0.0
# r5e-03-h48 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r5e-03-h48 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r5e-03-h48 Epoch   1 [BG] | train_wall=21.35s | Loss: 0.722887 | Freq: 1.134445 | Global: 57.26 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h48 [timing] first_epoch_pure_train≈21.356s (excludes this epoch's end-of-epoch eval)
# r5e-03-h48 Epoch   2 [BG] | train_wall=21.36s | Loss: 1.072645 | Freq: 0.533548 | Global: 57.71 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h48 Epoch   3 [BG] | train_wall=21.27s | Loss: 1.002981 | Freq: 0.492519 | Global: 57.74 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h48 Epoch   4 [BG] | train_wall=21.36s | Loss: 0.981546 | Freq: 0.478943 | Global: 57.87 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h48 Epoch   5 [BG] | train_wall=21.35s | Loss: 0.965071 | Freq: 0.468390 | Global: 57.94 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h48 Epoch   6 [BG] | train_wall=13.31s | Loss: 0.964765 | Freq: 0.468093 | Global: 58.18 dB | MaxErr: 0.0  [New Best!]
#
# r5e-03-h48 --- Experiment [BG_only] finished ---
# r5e-03-h48 --- Pure training time: 120.02 s ---
# r5e-03-h48 [timing] epochs=6 | train_wall/epoch: mean=20.00s min=13.31s max=21.36s | sum=120.01s
# r5e-03-h48 --- Best global PSNR: 58.18 dB ---
#   bg_h=48 (147,604p): PSNR=58.18 dB | CR=107.35x (base 108.15x) | +3.24 dB over SZ3
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
# r5e-03-h61 [Init] Epoch   0 | Global PSNR: 54.94 dB | MaxErr: 0.0
# r5e-03-h61 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r5e-03-h61 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r5e-03-h61 Epoch   1 [BG] | train_wall=26.20s | Loss: 0.710113 | Freq: 1.085037 | Global: 57.23 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h61 [timing] first_epoch_pure_train≈26.199s (excludes this epoch's end-of-epoch eval)
# r5e-03-h61 Epoch   2 [BG] | train_wall=26.23s | Loss: 1.048420 | Freq: 0.520704 | Global: 57.84 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h61 Epoch   3 [BG] | train_wall=26.09s | Loss: 0.993331 | Freq: 0.487612 | Global: 57.83 dB | MaxErr: 0.0
# r5e-03-h61 Epoch   4 [BG] | train_wall=26.23s | Loss: 0.968881 | Freq: 0.472363 | Global: 57.85 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h61 Epoch   5 [BG] | train_wall=15.25s | Loss: 0.967030 | Freq: 0.472296 | Global: 58.22 dB | MaxErr: 0.0  [New Best!]
#
# r5e-03-h61 --- Experiment [BG_only] finished ---
# r5e-03-h61 --- Pure training time: 120.00 s ---
# r5e-03-h61 [timing] epochs=5 | train_wall/epoch: mean=24.00s min=15.25s max=26.23s | sum=120.00s
# r5e-03-h61 --- Best global PSNR: 58.22 dB ---
#   bg_h=61 (237,538p): PSNR=58.22 dB | CR=106.87x (base 108.15x) | +3.28 dB over SZ3
#
# [Model: spatial] Total Params: 358,204
#  [Params] Main (BG) Network : 358,204 parameters
# r5e-03-h75 [Init] Epoch   0 | Global PSNR: 54.94 dB | MaxErr: 0.0
# r5e-03-h75 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r5e-03-h75 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r5e-03-h75 Epoch   1 [BG] | train_wall=36.62s | Loss: 0.681243 | Freq: 1.036444 | Global: 57.49 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h75 [timing] first_epoch_pure_train≈36.624s (excludes this epoch's end-of-epoch eval)
# r5e-03-h75 Epoch   2 [BG] | train_wall=36.71s | Loss: 1.008963 | Freq: 0.497042 | Global: 57.85 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h75 Epoch   3 [BG] | train_wall=36.67s | Loss: 0.954787 | Freq: 0.463814 | Global: 57.88 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h75 Epoch   4 [BG] | train_wall=10.00s | Loss: 0.947170 | Freq: 0.476331 | Global: 58.17 dB | MaxErr: 0.0  [New Best!]
#
# r5e-03-h75 --- Experiment [BG_only] finished ---
# r5e-03-h75 --- Pure training time: 120.01 s ---
# r5e-03-h75 [timing] epochs=4 | train_wall/epoch: mean=30.00s min=10.00s max=36.71s | sum=120.01s
# r5e-03-h75 --- Best global PSNR: 58.17 dB ---
#   bg_h=75 (358,204p): PSNR=58.17 dB | CR=106.23x (base 108.15x) | +3.23 dB over SZ3
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
# r5e-03-h88 [Init] Epoch   0 | Global PSNR: 54.94 dB | MaxErr: 0.0
# r5e-03-h88 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r5e-03-h88 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r5e-03-h88 Epoch   1 [BG] | train_wall=42.35s | Loss: 0.670244 | Freq: 1.022251 | Global: 57.47 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h88 [timing] first_epoch_pure_train≈42.352s (excludes this epoch's end-of-epoch eval)
# r5e-03-h88 Epoch   2 [BG] | train_wall=42.36s | Loss: 1.000162 | Freq: 0.492483 | Global: 57.94 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h88 Epoch   3 [BG] | train_wall=35.31s | Loss: 0.965764 | Freq: 0.468518 | Global: 58.20 dB | MaxErr: 0.0  [New Best!]
#
# r5e-03-h88 --- Experiment [BG_only] finished ---
# r5e-03-h88 --- Pure training time: 120.03 s ---
# r5e-03-h88 [timing] epochs=3 | train_wall/epoch: mean=40.01s min=35.31s max=42.36s | sum=120.03s
# r5e-03-h88 --- Best global PSNR: 58.20 dB ---
#   bg_h=88 (492,364p): PSNR=58.20 dB | CR=105.53x (base 108.15x) | +3.26 dB over SZ3
#
# ############################################################
# # rel=7e-03 | SZ3 base: CR=144.55x (29.71 MB) | base PSNR=52.38 dB
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
# r7e-03-h21 [Init] Epoch   0 | Global PSNR: 52.38 dB | MaxErr: 0.0
# r7e-03-h21 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r7e-03-h21 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r7e-03-h21 Epoch   1 [BG] | train_wall=37.65s | Loss: 0.825551 | Freq: 1.499432 | Global: 53.93 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h21 [timing] first_epoch_pure_train≈37.650s (excludes this epoch's end-of-epoch eval)
# r7e-03-h21 Epoch   2 [BG] | train_wall=37.66s | Loss: 1.243076 | Freq: 0.613539 | Global: 53.96 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h21 Epoch   3 [BG] | train_wall=37.56s | Loss: 1.142171 | Freq: 0.553612 | Global: 54.55 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h21 Epoch   4 [BG] | train_wall=7.14s | Loss: 1.117755 | Freq: 0.567067 | Global: 54.76 dB | MaxErr: 0.0  [New Best!]
#
# r7e-03-h21 --- Experiment [BG_only] finished ---
# r7e-03-h21 --- Pure training time: 120.02 s ---
# r7e-03-h21 [timing] epochs=4 | train_wall/epoch: mean=30.00s min=7.14s max=37.66s | sum=120.02s
# r7e-03-h21 --- Best global PSNR: 54.76 dB ---
#   bg_h=21 (28,858p): PSNR=54.76 dB | CR=144.27x (base 144.55x) | +2.39 dB over SZ3
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
# r7e-03-h39 [Init] Epoch   0 | Global PSNR: 52.38 dB | MaxErr: 0.0
# r7e-03-h39 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r7e-03-h39 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r7e-03-h39 Epoch   1 [BG] | train_wall=20.08s | Loss: 0.769386 | Freq: 1.270723 | Global: 54.22 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h39 [timing] first_epoch_pure_train≈20.077s (excludes this epoch's end-of-epoch eval)
# r7e-03-h39 Epoch   2 [BG] | train_wall=20.07s | Loss: 1.089602 | Freq: 0.522919 | Global: 54.71 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h39 Epoch   3 [BG] | train_wall=20.08s | Loss: 1.022247 | Freq: 0.483065 | Global: 54.85 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h39 Epoch   4 [BG] | train_wall=20.12s | Loss: 0.996702 | Freq: 0.467400 | Global: 54.72 dB | MaxErr: 0.0
# r7e-03-h39 Epoch   5 [BG] | train_wall=20.09s | Loss: 0.982340 | Freq: 0.458464 | Global: 54.89 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h39 Epoch   6 [BG] | train_wall=19.58s | Loss: 0.971996 | Freq: 0.451511 | Global: 55.07 dB | MaxErr: 0.0  [New Best!]
#
# r7e-03-h39 --- Experiment [BG_only] finished ---
# r7e-03-h39 --- Pure training time: 120.01 s ---
# r7e-03-h39 [timing] epochs=6 | train_wall/epoch: mean=20.00s min=19.58s max=20.12s | sum=120.01s
# r7e-03-h39 --- Best global PSNR: 55.07 dB ---
#   bg_h=39 (97,816p): PSNR=55.07 dB | CR=143.61x (base 144.55x) | +2.69 dB over SZ3
#
# [Model: spatial] Total Params: 147,604
#  [Params] Main (BG) Network : 147,604 parameters
# r7e-03-h48 [Init] Epoch   0 | Global PSNR: 52.38 dB | MaxErr: 0.0
# r7e-03-h48 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r7e-03-h48 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r7e-03-h48 Epoch   1 [BG] | train_wall=21.35s | Loss: 0.756305 | Freq: 1.238609 | Global: 54.36 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h48 [timing] first_epoch_pure_train≈21.348s (excludes this epoch's end-of-epoch eval)
# r7e-03-h48 Epoch   2 [BG] | train_wall=21.35s | Loss: 1.071901 | Freq: 0.511560 | Global: 54.86 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h48 Epoch   3 [BG] | train_wall=21.34s | Loss: 1.007650 | Freq: 0.474047 | Global: 55.00 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h48 Epoch   4 [BG] | train_wall=21.34s | Loss: 0.979178 | Freq: 0.456835 | Global: 54.97 dB | MaxErr: 0.0
# r7e-03-h48 Epoch   5 [BG] | train_wall=21.32s | Loss: 0.961567 | Freq: 0.445524 | Global: 55.00 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h48 Epoch   6 [BG] | train_wall=13.31s | Loss: 0.968149 | Freq: 0.448879 | Global: 55.41 dB | MaxErr: 0.0  [New Best!]
#
# r7e-03-h48 --- Experiment [BG_only] finished ---
# r7e-03-h48 --- Pure training time: 120.00 s ---
# r7e-03-h48 [timing] epochs=6 | train_wall/epoch: mean=20.00s min=13.31s max=21.35s | sum=120.00s
# r7e-03-h48 --- Best global PSNR: 55.41 dB ---
#   bg_h=48 (147,604p): PSNR=55.41 dB | CR=143.13x (base 144.55x) | +3.04 dB over SZ3
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
# r7e-03-h61 [Init] Epoch   0 | Global PSNR: 52.38 dB | MaxErr: 0.0
# r7e-03-h61 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r7e-03-h61 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r7e-03-h61 Epoch   1 [BG] | train_wall=26.19s | Loss: 0.753577 | Freq: 1.181810 | Global: 54.30 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h61 [timing] first_epoch_pure_train≈26.188s (excludes this epoch's end-of-epoch eval)
# r7e-03-h61 Epoch   2 [BG] | train_wall=26.14s | Loss: 1.061789 | Freq: 0.506924 | Global: 54.73 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h61 Epoch   3 [BG] | train_wall=26.21s | Loss: 1.002695 | Freq: 0.470615 | Global: 54.94 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h61 Epoch   4 [BG] | train_wall=26.23s | Loss: 0.978501 | Freq: 0.455463 | Global: 54.87 dB | MaxErr: 0.0
# r7e-03-h61 Epoch   5 [BG] | train_wall=15.23s | Loss: 0.974191 | Freq: 0.454097 | Global: 55.38 dB | MaxErr: 0.0  [New Best!]
#
# r7e-03-h61 --- Experiment [BG_only] finished ---
# r7e-03-h61 --- Pure training time: 120.00 s ---
# r7e-03-h61 [timing] epochs=5 | train_wall/epoch: mean=24.00s min=15.23s max=26.23s | sum=120.00s
# r7e-03-h61 --- Best global PSNR: 55.38 dB ---
#   bg_h=61 (237,538p): PSNR=55.38 dB | CR=142.28x (base 144.55x) | +3.00 dB over SZ3
#
# [Model: spatial] Total Params: 358,204
#  [Params] Main (BG) Network : 358,204 parameters
# r7e-03-h75 [Init] Epoch   0 | Global PSNR: 52.38 dB | MaxErr: 0.0
# r7e-03-h75 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r7e-03-h75 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r7e-03-h75 Epoch   1 [BG] | train_wall=36.60s | Loss: 0.689680 | Freq: 1.015779 | Global: 54.68 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h75 [timing] first_epoch_pure_train≈36.602s (excludes this epoch's end-of-epoch eval)
# r7e-03-h75 Epoch   2 [BG] | train_wall=36.66s | Loss: 1.004586 | Freq: 0.472763 | Global: 54.82 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h75 Epoch   3 [BG] | train_wall=36.55s | Loss: 0.959112 | Freq: 0.444618 | Global: 54.88 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h75 Epoch   4 [BG] | train_wall=10.22s | Loss: 0.940284 | Freq: 0.449308 | Global: 55.38 dB | MaxErr: 0.0  [New Best!]
#
# r7e-03-h75 --- Experiment [BG_only] finished ---
# r7e-03-h75 --- Pure training time: 120.03 s ---
# r7e-03-h75 [timing] epochs=4 | train_wall/epoch: mean=30.01s min=10.22s max=36.66s | sum=120.03s
# r7e-03-h75 --- Best global PSNR: 55.38 dB ---
#   bg_h=75 (358,204p): PSNR=55.38 dB | CR=141.15x (base 144.55x) | +3.00 dB over SZ3
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
# r7e-03-h88 [Init] Epoch   0 | Global PSNR: 52.38 dB | MaxErr: 0.0
# r7e-03-h88 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r7e-03-h88 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r7e-03-h88 Epoch   1 [BG] | train_wall=42.10s | Loss: 0.697029 | Freq: 1.048342 | Global: 54.82 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h88 [timing] first_epoch_pure_train≈42.102s (excludes this epoch's end-of-epoch eval)
# r7e-03-h88 Epoch   2 [BG] | train_wall=42.12s | Loss: 0.992828 | Freq: 0.465572 | Global: 54.95 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h88 Epoch   3 [BG] | train_wall=35.82s | Loss: 0.953782 | Freq: 0.439828 | Global: 55.39 dB | MaxErr: 0.0  [New Best!]
#
# r7e-03-h88 --- Experiment [BG_only] finished ---
# r7e-03-h88 --- Pure training time: 120.04 s ---
# r7e-03-h88 [timing] epochs=3 | train_wall/epoch: mean=40.01s min=35.82s max=42.12s | sum=120.04s
# r7e-03-h88 --- Best global PSNR: 55.39 dB ---
#   bg_h=88 (492,364p): PSNR=55.39 dB | CR=139.91x (base 144.55x) | +3.02 dB over SZ3
#
# ############################################################
# # rel=9e-03 | SZ3 base: CR=181.14x (23.71 MB) | base PSNR=50.46 dB
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
# r9e-03-h21 [Init] Epoch   0 | Global PSNR: 50.46 dB | MaxErr: 0.0
# r9e-03-h21 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r9e-03-h21 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r9e-03-h21 Epoch   1 [BG] | train_wall=38.03s | Loss: 0.820538 | Freq: 1.354401 | Global: 51.87 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h21 [timing] first_epoch_pure_train≈38.029s (excludes this epoch's end-of-epoch eval)
# r9e-03-h21 Epoch   2 [BG] | train_wall=38.01s | Loss: 1.204156 | Freq: 0.575129 | Global: 52.26 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h21 Epoch   3 [BG] | train_wall=38.02s | Loss: 1.115359 | Freq: 0.522497 | Global: 52.47 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h21 Epoch   4 [BG] | train_wall=5.98s | Loss: 1.084813 | Freq: 0.535229 | Global: 52.77 dB | MaxErr: 0.0  [New Best!]
#
# r9e-03-h21 --- Experiment [BG_only] finished ---
# r9e-03-h21 --- Pure training time: 120.03 s ---
# r9e-03-h21 [timing] epochs=4 | train_wall/epoch: mean=30.01s min=5.98s max=38.03s | sum=120.03s
# r9e-03-h21 --- Best global PSNR: 52.77 dB ---
#   bg_h=21 (28,858p): PSNR=52.77 dB | CR=180.70x (base 181.14x) | +2.31 dB over SZ3
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
# r9e-03-h39 [Init] Epoch   0 | Global PSNR: 50.46 dB | MaxErr: 0.0
# r9e-03-h39 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r9e-03-h39 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r9e-03-h39 Epoch   1 [BG] | train_wall=20.56s | Loss: 0.741874 | Freq: 1.125137 | Global: 52.17 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h39 [timing] first_epoch_pure_train≈20.557s (excludes this epoch's end-of-epoch eval)
# r9e-03-h39 Epoch   2 [BG] | train_wall=20.48s | Loss: 1.099555 | Freq: 0.513506 | Global: 52.58 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h39 Epoch   3 [BG] | train_wall=20.53s | Loss: 1.034556 | Freq: 0.475681 | Global: 52.80 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h39 Epoch   4 [BG] | train_wall=20.27s | Loss: 1.013232 | Freq: 0.462631 | Global: 52.56 dB | MaxErr: 0.0
# r9e-03-h39 Epoch   5 [BG] | train_wall=20.27s | Loss: 0.999933 | Freq: 0.454557 | Global: 52.76 dB | MaxErr: 0.0
# r9e-03-h39 Epoch   6 [BG] | train_wall=17.90s | Loss: 0.998414 | Freq: 0.452022 | Global: 53.19 dB | MaxErr: 0.0  [New Best!]
#
# r9e-03-h39 --- Experiment [BG_only] finished ---
# r9e-03-h39 --- Pure training time: 120.01 s ---
# r9e-03-h39 [timing] epochs=6 | train_wall/epoch: mean=20.00s min=17.90s max=20.56s | sum=120.00s
# r9e-03-h39 --- Best global PSNR: 53.19 dB ---
#   bg_h=39 (97,816p): PSNR=53.19 dB | CR=179.66x (base 181.14x) | +2.74 dB over SZ3
#
# [Model: spatial] Total Params: 147,604
#  [Params] Main (BG) Network : 147,604 parameters
# r9e-03-h48 [Init] Epoch   0 | Global PSNR: 50.46 dB | MaxErr: 0.0
# r9e-03-h48 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r9e-03-h48 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r9e-03-h48 Epoch   1 [BG] | train_wall=21.38s | Loss: 0.734633 | Freq: 1.105978 | Global: 52.48 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h48 [timing] first_epoch_pure_train≈21.381s (excludes this epoch's end-of-epoch eval)
# r9e-03-h48 Epoch   2 [BG] | train_wall=21.40s | Loss: 1.070103 | Freq: 0.495808 | Global: 52.74 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h48 Epoch   3 [BG] | train_wall=21.38s | Loss: 1.010422 | Freq: 0.460545 | Global: 52.76 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h48 Epoch   4 [BG] | train_wall=21.38s | Loss: 0.983770 | Freq: 0.445173 | Global: 52.86 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h48 Epoch   5 [BG] | train_wall=21.40s | Loss: 0.965966 | Freq: 0.435347 | Global: 52.86 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h48 Epoch   6 [BG] | train_wall=13.05s | Loss: 0.970867 | Freq: 0.439300 | Global: 53.35 dB | MaxErr: 0.0  [New Best!]
#
# r9e-03-h48 --- Experiment [BG_only] finished ---
# r9e-03-h48 --- Pure training time: 120.00 s ---
# r9e-03-h48 [timing] epochs=6 | train_wall/epoch: mean=20.00s min=13.05s max=21.40s | sum=120.00s
# r9e-03-h48 --- Best global PSNR: 53.35 dB ---
#   bg_h=48 (147,604p): PSNR=53.35 dB | CR=178.92x (base 181.14x) | +2.89 dB over SZ3
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
# r9e-03-h61 [Init] Epoch   0 | Global PSNR: 50.46 dB | MaxErr: 0.0
# r9e-03-h61 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r9e-03-h61 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r9e-03-h61 Epoch   1 [BG] | train_wall=26.20s | Loss: 0.722942 | Freq: 1.028843 | Global: 52.52 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h61 [timing] first_epoch_pure_train≈26.206s (excludes this epoch's end-of-epoch eval)
# r9e-03-h61 Epoch   2 [BG] | train_wall=26.26s | Loss: 1.025765 | Freq: 0.471149 | Global: 52.84 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h61 Epoch   3 [BG] | train_wall=26.26s | Loss: 0.970812 | Freq: 0.437525 | Global: 52.94 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h61 Epoch   4 [BG] | train_wall=26.26s | Loss: 0.943985 | Freq: 0.422560 | Global: 52.92 dB | MaxErr: 0.0
# r9e-03-h61 Epoch   5 [BG] | train_wall=15.01s | Loss: 0.941826 | Freq: 0.422895 | Global: 53.46 dB | MaxErr: 0.0  [New Best!]
#
# r9e-03-h61 --- Experiment [BG_only] finished ---
# r9e-03-h61 --- Pure training time: 120.01 s ---
# r9e-03-h61 [timing] epochs=5 | train_wall/epoch: mean=24.00s min=15.01s max=26.26s | sum=120.00s
# r9e-03-h61 --- Best global PSNR: 53.46 dB ---
#   bg_h=61 (237,538p): PSNR=53.46 dB | CR=177.58x (base 181.14x) | +3.00 dB over SZ3
#
# [Model: spatial] Total Params: 358,204
#  [Params] Main (BG) Network : 358,204 parameters
# r9e-03-h75 [Init] Epoch   0 | Global PSNR: 50.46 dB | MaxErr: 0.0
# r9e-03-h75 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r9e-03-h75 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r9e-03-h75 Epoch   1 [BG] | train_wall=36.67s | Loss: 0.684039 | Freq: 0.931053 | Global: 52.27 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h75 [timing] first_epoch_pure_train≈36.668s (excludes this epoch's end-of-epoch eval)
# r9e-03-h75 Epoch   2 [BG] | train_wall=36.74s | Loss: 1.019827 | Freq: 0.466848 | Global: 52.67 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h75 Epoch   3 [BG] | train_wall=36.73s | Loss: 0.962429 | Freq: 0.433174 | Global: 52.88 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h75 Epoch   4 [BG] | train_wall=9.86s | Loss: 0.941970 | Freq: 0.439119 | Global: 53.27 dB | MaxErr: 0.0  [New Best!]
#
# r9e-03-h75 --- Experiment [BG_only] finished ---
# r9e-03-h75 --- Pure training time: 120.00 s ---
# r9e-03-h75 [timing] epochs=4 | train_wall/epoch: mean=30.00s min=9.86s max=36.74s | sum=120.00s
# r9e-03-h75 --- Best global PSNR: 53.27 dB ---
#   bg_h=75 (358,204p): PSNR=53.27 dB | CR=175.83x (base 181.14x) | +2.82 dB over SZ3
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
# r9e-03-h88 [Init] Epoch   0 | Global PSNR: 50.46 dB | MaxErr: 0.0
# r9e-03-h88 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r9e-03-h88 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r9e-03-h88 Epoch   1 [BG] | train_wall=42.15s | Loss: 0.667863 | Freq: 0.912725 | Global: 52.48 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h88 [timing] first_epoch_pure_train≈42.155s (excludes this epoch's end-of-epoch eval)
# r9e-03-h88 Epoch   2 [BG] | train_wall=42.22s | Loss: 1.001511 | Freq: 0.455868 | Global: 52.81 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h88 Epoch   3 [BG] | train_wall=35.66s | Loss: 0.959794 | Freq: 0.430037 | Global: 53.38 dB | MaxErr: 0.0  [New Best!]
#
# r9e-03-h88 --- Experiment [BG_only] finished ---
# r9e-03-h88 --- Pure training time: 120.04 s ---
# r9e-03-h88 [timing] epochs=3 | train_wall/epoch: mean=40.01s min=35.66s max=42.22s | sum=120.04s
# r9e-03-h88 --- Best global PSNR: 53.38 dB ---
#   bg_h=88 (492,364p): PSNR=53.38 dB | CR=173.92x (base 181.14x) | +2.93 dB over SZ3
#
# ############################################################
# # rel=1e-02 | SZ3 base: CR=199.71x (21.51 MB) | base PSNR=49.65 dB
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
# r1e-02-h21 [Init] Epoch   0 | Global PSNR: 49.65 dB | MaxErr: 0.0
# r1e-02-h21 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r1e-02-h21 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r1e-02-h21 Epoch   1 [BG] | train_wall=37.90s | Loss: 0.837862 | Freq: 1.368568 | Global: 50.62 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h21 [timing] first_epoch_pure_train≈37.904s (excludes this epoch's end-of-epoch eval)
# r1e-02-h21 Epoch   2 [BG] | train_wall=37.92s | Loss: 1.258457 | Freq: 0.604412 | Global: 51.23 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h21 Epoch   3 [BG] | train_wall=37.92s | Loss: 1.154368 | Freq: 0.539955 | Global: 51.52 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h21 Epoch   4 [BG] | train_wall=6.30s | Loss: 1.113873 | Freq: 0.546645 | Global: 51.85 dB | MaxErr: 0.0  [New Best!]
#
# r1e-02-h21 --- Experiment [BG_only] finished ---
# r1e-02-h21 --- Pure training time: 120.03 s ---
# r1e-02-h21 [timing] epochs=4 | train_wall/epoch: mean=30.01s min=6.30s max=37.92s | sum=120.03s
# r1e-02-h21 --- Best global PSNR: 51.85 dB ---
#   bg_h=21 (28,858p): PSNR=51.85 dB | CR=199.18x (base 199.71x) | +2.20 dB over SZ3
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
# r1e-02-h39 [Init] Epoch   0 | Global PSNR: 49.65 dB | MaxErr: 0.0
# r1e-02-h39 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r1e-02-h39 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r1e-02-h39 Epoch   1 [BG] | train_wall=20.43s | Loss: 0.753857 | Freq: 1.176929 | Global: 51.36 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h39 [timing] first_epoch_pure_train≈20.433s (excludes this epoch's end-of-epoch eval)
# r1e-02-h39 Epoch   2 [BG] | train_wall=20.44s | Loss: 1.094445 | Freq: 0.504230 | Global: 51.66 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h39 Epoch   3 [BG] | train_wall=20.58s | Loss: 1.029166 | Freq: 0.465864 | Global: 51.92 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h39 Epoch   4 [BG] | train_wall=20.59s | Loss: 1.003417 | Freq: 0.450640 | Global: 52.01 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h39 Epoch   5 [BG] | train_wall=20.57s | Loss: 0.987144 | Freq: 0.440971 | Global: 52.01 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h39 Epoch   6 [BG] | train_wall=17.38s | Loss: 0.986493 | Freq: 0.440101 | Global: 52.35 dB | MaxErr: 0.0  [New Best!]
#
# r1e-02-h39 --- Experiment [BG_only] finished ---
# r1e-02-h39 --- Pure training time: 120.01 s ---
# r1e-02-h39 [timing] epochs=6 | train_wall/epoch: mean=20.00s min=17.38s max=20.59s | sum=120.00s
# r1e-02-h39 --- Best global PSNR: 52.35 dB ---
#   bg_h=39 (97,816p): PSNR=52.35 dB | CR=197.91x (base 199.71x) | +2.70 dB over SZ3
#
# [Model: spatial] Total Params: 147,604
#  [Params] Main (BG) Network : 147,604 parameters
# r1e-02-h48 [Init] Epoch   0 | Global PSNR: 49.65 dB | MaxErr: 0.0
# r1e-02-h48 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r1e-02-h48 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r1e-02-h48 Epoch   1 [BG] | train_wall=21.69s | Loss: 0.725700 | Freq: 1.050121 | Global: 51.29 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h48 [timing] first_epoch_pure_train≈21.690s (excludes this epoch's end-of-epoch eval)
# r1e-02-h48 Epoch   2 [BG] | train_wall=21.69s | Loss: 1.063617 | Freq: 0.487669 | Global: 51.86 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h48 Epoch   3 [BG] | train_wall=21.72s | Loss: 1.003933 | Freq: 0.451195 | Global: 51.98 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h48 Epoch   4 [BG] | train_wall=21.69s | Loss: 0.974723 | Freq: 0.434750 | Global: 51.94 dB | MaxErr: 0.0
# r1e-02-h48 Epoch   5 [BG] | train_wall=21.69s | Loss: 0.956299 | Freq: 0.424782 | Global: 52.05 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h48 Epoch   6 [BG] | train_wall=11.54s | Loss: 0.958408 | Freq: 0.429256 | Global: 52.53 dB | MaxErr: 0.0  [New Best!]
#
# r1e-02-h48 --- Experiment [BG_only] finished ---
# r1e-02-h48 --- Pure training time: 120.02 s ---
# r1e-02-h48 [timing] epochs=6 | train_wall/epoch: mean=20.00s min=11.54s max=21.72s | sum=120.01s
# r1e-02-h48 --- Best global PSNR: 52.53 dB ---
#   bg_h=48 (147,604p): PSNR=52.53 dB | CR=197.01x (base 199.71x) | +2.88 dB over SZ3
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
# r1e-02-h61 [Init] Epoch   0 | Global PSNR: 49.65 dB | MaxErr: 0.0
# r1e-02-h61 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r1e-02-h61 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r1e-02-h61 Epoch   1 [BG] | train_wall=26.56s | Loss: 0.730900 | Freq: 1.014547 | Global: 51.57 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h61 [timing] first_epoch_pure_train≈26.562s (excludes this epoch's end-of-epoch eval)
# r1e-02-h61 Epoch   2 [BG] | train_wall=26.54s | Loss: 1.021133 | Freq: 0.462421 | Global: 51.93 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h61 Epoch   3 [BG] | train_wall=26.55s | Loss: 0.973653 | Freq: 0.433582 | Global: 51.88 dB | MaxErr: 0.0
# r1e-02-h61 Epoch   4 [BG] | train_wall=26.50s | Loss: 0.948202 | Freq: 0.420124 | Global: 52.14 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h61 Epoch   5 [BG] | train_wall=13.87s | Loss: 0.945642 | Freq: 0.421977 | Global: 52.57 dB | MaxErr: 0.0  [New Best!]
#
# r1e-02-h61 --- Experiment [BG_only] finished ---
# r1e-02-h61 --- Pure training time: 120.03 s ---
# r1e-02-h61 [timing] epochs=5 | train_wall/epoch: mean=24.00s min=13.87s max=26.56s | sum=120.02s
# r1e-02-h61 --- Best global PSNR: 52.57 dB ---
#   bg_h=61 (237,538p): PSNR=52.57 dB | CR=195.39x (base 199.71x) | +2.92 dB over SZ3
#
# [Model: spatial] Total Params: 358,204
#  [Params] Main (BG) Network : 358,204 parameters
# r1e-02-h75 [Init] Epoch   0 | Global PSNR: 49.65 dB | MaxErr: 0.0
# r1e-02-h75 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r1e-02-h75 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r1e-02-h75 Epoch   1 [BG] | train_wall=37.04s | Loss: 0.673248 | Freq: 0.892759 | Global: 51.65 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h75 [timing] first_epoch_pure_train≈37.044s (excludes this epoch's end-of-epoch eval)
# r1e-02-h75 Epoch   2 [BG] | train_wall=36.96s | Loss: 1.001250 | Freq: 0.450418 | Global: 51.84 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h75 Epoch   3 [BG] | train_wall=37.04s | Loss: 0.950085 | Freq: 0.421074 | Global: 52.11 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h75 Epoch   4 [BG] | train_wall=8.97s | Loss: 0.927353 | Freq: 0.427876 | Global: 52.45 dB | MaxErr: 0.0  [New Best!]
#
# r1e-02-h75 --- Experiment [BG_only] finished ---
# r1e-02-h75 --- Pure training time: 120.02 s ---
# r1e-02-h75 [timing] epochs=4 | train_wall/epoch: mean=30.00s min=8.97s max=37.04s | sum=120.01s
# r1e-02-h75 --- Best global PSNR: 52.45 dB ---
#   bg_h=75 (358,204p): PSNR=52.45 dB | CR=193.27x (base 199.71x) | +2.80 dB over SZ3
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
# r1e-02-h88 [Init] Epoch   0 | Global PSNR: 49.65 dB | MaxErr: 0.0
# r1e-02-h88 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r1e-02-h88 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r1e-02-h88 Epoch   1 [BG] | train_wall=42.47s | Loss: 0.692615 | Freq: 0.942665 | Global: 51.42 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h88 [timing] first_epoch_pure_train≈42.470s (excludes this epoch's end-of-epoch eval)
# r1e-02-h88 Epoch   2 [BG] | train_wall=42.50s | Loss: 1.006535 | Freq: 0.453352 | Global: 51.86 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h88 Epoch   3 [BG] | train_wall=35.03s | Loss: 0.970852 | Freq: 0.431060 | Global: 52.51 dB | MaxErr: 0.0  [New Best!]
#
# r1e-02-h88 --- Experiment [BG_only] finished ---
# r1e-02-h88 --- Pure training time: 120.00 s ---
# r1e-02-h88 [timing] epochs=3 | train_wall/epoch: mean=40.00s min=35.03s max=42.50s | sum=120.00s
# r1e-02-h88 --- Best global PSNR: 52.51 dB ---
#   bg_h=88 (492,364p): PSNR=52.51 dB | CR=190.97x (base 199.71x) | +2.86 dB over SZ3
#
# --- Sweep complete in 117.8 min (30 models over 5 rel-errors) ---

# %%
fig, ax = plt.subplots(figsize=(10, 6.5))

# One curve per model size; points span the rel_err sweep (-> CR axis)
param_sizes = sorted(set(r["n_params"] for r in results))
cmap = plt.cm.viridis
colors = {p: cmap(i / max(1, len(param_sizes) - 1)) for i, p in enumerate(param_sizes)}

# Distinct marker shape + line style per curve (cycled if there are more curves)
MARKERS = ["o", "s", "^", "D", "v", "P", "X", "*", "<", ">", "h", "p"]
LINESTYLES = ["-", "--", "-.", ":", (0, (3, 1, 1, 1)), (0, (5, 1)), (0, (1, 1))]

def fmt_p(p):
    return f"{p/1000:.0f}k" if p >= 1000 else str(p)

for i, p in enumerate(param_sizes):
    pts = sorted([r for r in results if r["n_params"] == p], key=lambda r: r["cr"])
    ax.plot([r["cr"] for r in pts], [r["psnr"] for r in pts],
            marker=MARKERS[i % len(MARKERS)],
            linestyle=LINESTYLES[i % len(LINESTYLES)],
            color=colors[p], markersize=7, linewidth=1.8, zorder=3,
            label=f"{fmt_p(p)} params")

# SZ3-only baseline curve
bl = sorted(baselines, key=lambda b: b["cr"])
ax.plot([b["cr"] for b in bl], [b["psnr"] for b in bl],
        marker="*", linestyle=(0, (4, 2)), color="black",
        markersize=10, linewidth=1.6, zorder=2,
        label="SZ3 only (no model)")
# Annotate baseline points with their rel_err
for b in bl:
    ax.annotate(f"{b['rel']:.0e}", xy=(b["cr"], b["psnr"]),
                xytext=(0, -14), textcoords="offset points",
                ha="center", fontsize=7, color="black")

ax.set_xlabel("Compression Ratio  (orig / [SZ3 + model bytes])")
ax.set_ylabel("PSNR (dB)  [full volume]")
ax.set_title(
    f"PSNR vs CR — Miranda {work_shape} (stride={SPATIAL_STRIDE})\n"
    f"rel_err {min(REL_ERRS):.0e}–{max(REL_ERRS):.0e} (labels) · lr={FIXED_LR:.0e} · "
    f"{TIME_PER_CONFIG:.0f}s/config · curves = model size"
)
ax.grid(True, alpha=0.35)
ax.legend(loc="best", fontsize=9, title="model size")
plt.tight_layout()
out_png = f"psnr_vs_cr_relsweep_{TARGET_STEM}.png"
plt.savefig(out_png, dpi=150, bbox_inches="tight")
plt.show()
print(f"Saved: {out_png}")

# Full table to stdout so every (rel, params) value is visible
print(f"\n{'rel':>7} {'bg_h':>5} {'params':>10} {'PSNR(dB)':>9} {'CR':>8} "
      f"{'baseCR':>8} {'+dB':>7} {'epochs':>7}")
base_by_rel = {b['rel']: b for b in baselines}
for r in sorted(results, key=lambda r: (r['rel'], r['n_params'])):
    b = base_by_rel[r['rel']]
    print(f"{r['rel']:>7.0e} {r['bg_h']:>5} {r['n_params']:>10,} {r['psnr']:>9.2f} "
          f"{r['cr']:>8.2f} {b['cr']:>8.2f} {r['psnr']-b['psnr']:>7.2f} {r['epochs']:>7}")
