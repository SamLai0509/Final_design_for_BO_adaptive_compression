# %% [markdown]
# # PSNR vs Compression Ratio — model size × SZ3 error bound
#
# **Dataset:** Miranda 1024×1024×1024 (single-field float32).
#
# **Why sweep the rel-error bound too?**  The model is tiny next to the SZ3 base (100k params ≈ 0.2 MB vs an SZ3 stream of tens–hundreds of MB), so changing the parameter count alone barely moves the total CR.  The knob that actually moves CR is the **SZ3 relative-error bound** — looser bound → smaller SZ3 stream → higher CR but lower base PSNR.
#
# So we sweep `rel_err ∈ [1e-3 … 6e-3]` (spreads CR along x) **and** a few model sizes (separate curves).  Per point:
#
# ```
# CR = original_bytes / (sz_bytes(rel_err) + n_params * 2)   # params stored as bf16
# ```
#
# Result: a family of rate–distortion curves — one per model size — plus the SZ3-only baseline.

# %%
import random, sys, os, copy, time
from pathlib import Path

import numpy as np
import torch
import matplotlib.pyplot as plt

sys.path.append("/home/sam/Halo_Finder/Final_design/base_script")

# Force-reload edited modules so re-running this cell picks up bg_stage.py changes
# WITHOUT restarting the kernel (Jupyter caches modules in sys.modules).
import importlib
import bg_stage
importlib.reload(bg_stage)

from experiment import build_bg_only_cfg, estimate_bg_model_param_bytes
from bg_stage import run_bg_inference, train_bg_only, unwrap_bg_model
from bg_shard import pick_bg_h_under_budget

pysz_dir = "/home/sam/Data_Compression/SZ3/tools/pysz"
if pysz_dir not in sys.path:
    sys.path.append(pysz_dir)
from pysz import SZ

def set_seed(seed=42):
    torch.manual_seed(seed); np.random.seed(seed); random.seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Device: {device} | GPUs: {torch.cuda.device_count()}")
# Out:
# Device: cuda:0 | GPUs: 1

# %%
# ── Paths ─────────────────────────────────────────────────────────────────────
halo_finder_root = Path("/home/sam/Halo_Finder")
raw_path    = (halo_finder_root / "halo_finder_v1/miranda_1024x1024x1024_float32.raw").as_posix()
sz_lib_path = "/home/sam/Data_Compression/SZ3/build/lib64/libSZ3c.so"

# ── Dataset constants ──────────────────────────────────────────────────────────
data_shape  = (1024, 1024, 1024)
TARGET_STEM = "miranda"

# Quick-test downsample: stride>1 shrinks the cube (and re-compresses it) so the
# whole sweep runs fast.  CR is then computed on the shrunk cube — still a valid
# R-D curve, just lower resolution.  Set to 1 for the real full-res study.
SPATIAL_STRIDE = 1

sz_engine = SZ(sz_lib_path)
print("SZ engine loaded")
# Out:
# SZ engine loaded

# %%
def load_gt(stride=1):
    """Load the ground-truth float32 cube once (optionally strided)."""
    vol = np.fromfile(raw_path, dtype=np.float32).reshape(data_shape)
    if stride > 1:
        vol = np.ascontiguousarray(vol[::stride, ::stride, ::stride])
    return vol

def compress_at(vol, rel_err):
    """SZ3-compress `vol` at a relative-error bound; return (Xps, sz_bytes, sz_cr)."""
    b, cr = sz_engine.compress(vol, 1, 0, float(rel_err), 0)
    x_lq  = sz_engine.decompress(b, vol.shape, np.float32).astype(np.float32)
    return [np.asarray(x_lq, np.float32)], int(len(b)), float(cr)

# %%
t0 = time.time()
gt         = load_gt(SPATIAL_STRIDE)
Xs         = [gt]
work_shape = gt.shape
orig_bytes = gt.nbytes

def psnr_from_arrays(target, recon):
    data_range = float(target.max() - target.min())
    if data_range <= 0:
        data_range = 1.0
    mse = float(np.mean((target - recon) ** 2))
    return 100.0 if mse <= 0 else 20.0 * np.log10(data_range) - 10.0 * np.log10(mse)

print(f"Loaded GT in {time.time()-t0:.1f}s | work shape: {work_shape} "
      f"(stride={SPATIAL_STRIDE}) | {orig_bytes/1e6:.1f} MB")
# Out:
# Loaded GT in 1.5s | work shape: (1024, 1024, 1024) (stride=1) | 4295.0 MB

# %%
def build_cfg(Xs_in, Xps_in, max_train_time, bg_h, steps_per_epoch,
              lr=1e-4, epochs=200, log_prefix="", patch_size=None):
    if patch_size is None:
        patch_size = Xs_in[0].shape[2]
    cfg = build_bg_only_cfg(
        X_target=Xs_in[0], Xps=Xps_in, max_train_time=max_train_time,
        epochs=epochs, steps_per_epoch=steps_per_epoch, bg_h=bg_h,
        bg_batch=1, bg_patch_size=patch_size, lr=lr,
    )
    cfg.bg_sample_mode   = "sequential"
    cfg.bg_log_prefix    = log_prefix
    cfg.bg_arch          = "spatial"
    cfg.amp              = True
    cfg.amp_dtype        = "bf16"
    cfg.bg_ddp           = False
    cfg.bg_data_parallel = False
    return cfg

def n_params_of(model):
    return int(sum(p.numel() for p in unwrap_bg_model(model).parameters()))

print("Helpers ready")
# Out:
# Helpers ready

# %% [markdown]
# ## Sweep:  rel-error bound  ×  model size
#
# Outer loop = `REL_ERRS` (each value re-compresses the cube with SZ3 → a new base CR / base PSNR).  Inner loop = `PARAM_TARGETS` (each mapped to a `bg_h` via `pick_bg_h_under_budget`).  `lr` is fixed; each model trains for `TIME_PER_CONFIG` s for the full budget (no early-stop — fair ablation).
#
# **Total trainings = len(REL_ERRS) × #distinct model sizes** — keep both lists short for full-res 1024³, or use `SPATIAL_STRIDE>1` first to smoke-test the shape of the curves.

# %%
# ── Fixed knobs ───────────────────────────────────────────────────────────────
FIXED_LR        = 1e-3
TIME_PER_CONFIG = 120.0          # wall-clock budget per model (early-stop may end sooner)
BYTES_PER_PARAM = 2             # bf16 storage for the model weights
FREQ_WARMUP     = 1            # epochs before the FFT/freq loss term joins the loss

# Outer sweep: SZ3 relative-error bound (this is what actually moves CR)
REL_ERRS = [ 3e-3, 5e-3, 7e-3, 9e-3, 1e-2]

# Inner sweep: model parameter budgets (separate curves)
PARAM_TARGETS = [30000, 100000, 240000, 500000]
H_CANDIDATES  = list(range(3, 100))

# Map each budget -> largest bg_h that fits; dedupe (several budgets may share a bg_h)
_seen = set()
sweep_plan = []          # list of (bg_h, est_params)
for tgt in PARAM_TARGETS:
    h, est_p = pick_bg_h_under_budget(
        tgt, shape=work_shape, n_fields=1,
        bg_arch="spatial", h_candidates=H_CANDIDATES,
    )
    if h not in _seen:
        _seen.add(h)
        sweep_plan.append((int(h), int(est_p)))
sweep_plan.sort()

n_runs = len(REL_ERRS) * len(sweep_plan)
print(f"Fixed: lr={FIXED_LR:.1e} | direction=Z | {TIME_PER_CONFIG:.0f}s/config | "
      f"freq_warmup={FREQ_WARMUP}")
print(f"REL_ERRS: {REL_ERRS}")
print(f"Model sizes ({len(sweep_plan)} distinct):")
for h, est_p in sweep_plan:
    print(f"  bg_h={h:2d}  ~{est_p:,} params")
print(f"\n>> {n_runs} trainings total (~{n_runs*TIME_PER_CONFIG/60:.0f} min "
      f"at {TIME_PER_CONFIG:.0f}s each)")
# Out:
# [Model: spatial] Total Params: 724
#  [Params] Main (BG) Network : 724 parameters
#
# [Model: spatial] Total Params: 1,216
#  [Params] Main (BG) Network : 1,216 parameters
#
# [Model: spatial] Total Params: 1,834
#  [Params] Main (BG) Network : 1,834 parameters
#
# [Model: spatial] Total Params: 2,578
#  [Params] Main (BG) Network : 2,578 parameters
#
# [Model: spatial] Total Params: 3,448
#  [Params] Main (BG) Network : 3,448 parameters
#
# [Model: spatial] Total Params: 4,444
#  [Params] Main (BG) Network : 4,444 parameters
#
# [Model: spatial] Total Params: 5,566
#  [Params] Main (BG) Network : 5,566 parameters
#
# [Model: spatial] Total Params: 6,814
#  [Params] Main (BG) Network : 6,814 parameters
#
# [Model: spatial] Total Params: 8,188
#  [Params] Main (BG) Network : 8,188 parameters
#
# [Model: spatial] Total Params: 9,688
#  [Params] Main (BG) Network : 9,688 parameters
#
# [Model: spatial] Total Params: 11,314
#  [Params] Main (BG) Network : 11,314 parameters
#
# [Model: spatial] Total Params: 13,066
#  [Params] Main (BG) Network : 13,066 parameters
#
# [Model: spatial] Total Params: 14,944
#  [Params] Main (BG) Network : 14,944 parameters
#
# [Model: spatial] Total Params: 16,948
#  [Params] Main (BG) Network : 16,948 parameters
#
# [Model: spatial] Total Params: 19,078
#  [Params] Main (BG) Network : 19,078 parameters
#
# [Model: spatial] Total Params: 21,334
#  [Params] Main (BG) Network : 21,334 parameters
#
# [Model: spatial] Total Params: 23,716
#  [Params] Main (BG) Network : 23,716 parameters
#
# [Model: spatial] Total Params: 26,224
#  [Params] Main (BG) Network : 26,224 parameters
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
#
# [Model: spatial] Total Params: 31,618
#  [Params] Main (BG) Network : 31,618 parameters
#
# [Model: spatial] Total Params: 34,504
#  [Params] Main (BG) Network : 34,504 parameters
#
# [Model: spatial] Total Params: 37,516
#  [Params] Main (BG) Network : 37,516 parameters
#
# [Model: spatial] Total Params: 40,654
#  [Params] Main (BG) Network : 40,654 parameters
#
# [Model: spatial] Total Params: 43,918
#  [Params] Main (BG) Network : 43,918 parameters
#
# [Model: spatial] Total Params: 47,308
#  [Params] Main (BG) Network : 47,308 parameters
#
# [Model: spatial] Total Params: 50,824
#  [Params] Main (BG) Network : 50,824 parameters
#
# [Model: spatial] Total Params: 54,466
#  [Params] Main (BG) Network : 54,466 parameters
#
# [Model: spatial] Total Params: 58,234
#  [Params] Main (BG) Network : 58,234 parameters
#
# [Model: spatial] Total Params: 62,128
#  [Params] Main (BG) Network : 62,128 parameters
#
# [Model: spatial] Total Params: 66,148
#  [Params] Main (BG) Network : 66,148 parameters
#
# [Model: spatial] Total Params: 70,294
#  [Params] Main (BG) Network : 70,294 parameters
#
# [Model: spatial] Total Params: 74,566
#  [Params] Main (BG) Network : 74,566 parameters
#
# [Model: spatial] Total Params: 78,964
#  [Params] Main (BG) Network : 78,964 parameters
#
# [Model: spatial] Total Params: 83,488
#  [Params] Main (BG) Network : 83,488 parameters
#
# [Model: spatial] Total Params: 88,138
#  [Params] Main (BG) Network : 88,138 parameters
#
# [Model: spatial] Total Params: 92,914
#  [Params] Main (BG) Network : 92,914 parameters
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
#
# [Model: spatial] Total Params: 102,844
#  [Params] Main (BG) Network : 102,844 parameters
#
# [Model: spatial] Total Params: 107,998
#  [Params] Main (BG) Network : 107,998 parameters
#
# [Model: spatial] Total Params: 113,278
#  [Params] Main (BG) Network : 113,278 parameters
#
# [Model: spatial] Total Params: 118,684
#  [Params] Main (BG) Network : 118,684 parameters
#
# [Model: spatial] Total Params: 124,216
#  [Params] Main (BG) Network : 124,216 parameters
#
# [Model: spatial] Total Params: 129,874
#  [Params] Main (BG) Network : 129,874 parameters
#
# [Model: spatial] Total Params: 135,658
#  [Params] Main (BG) Network : 135,658 parameters
#
# [Model: spatial] Total Params: 141,568
#  [Params] Main (BG) Network : 141,568 parameters
#
# [Model: spatial] Total Params: 147,604
#  [Params] Main (BG) Network : 147,604 parameters
#
# [Model: spatial] Total Params: 153,766
#  [Params] Main (BG) Network : 153,766 parameters
#
# [Model: spatial] Total Params: 160,054
#  [Params] Main (BG) Network : 160,054 parameters
#
# [Model: spatial] Total Params: 166,468
#  [Params] Main (BG) Network : 166,468 parameters
#
# [Model: spatial] Total Params: 173,008
#  [Params] Main (BG) Network : 173,008 parameters
#
# [Model: spatial] Total Params: 179,674
#  [Params] Main (BG) Network : 179,674 parameters
#
# [Model: spatial] Total Params: 186,466
#  [Params] Main (BG) Network : 186,466 parameters
#
# [Model: spatial] Total Params: 193,384
#  [Params] Main (BG) Network : 193,384 parameters
#
# [Model: spatial] Total Params: 200,428
#  [Params] Main (BG) Network : 200,428 parameters
#
# [Model: spatial] Total Params: 207,598
#  [Params] Main (BG) Network : 207,598 parameters
#
# [Model: spatial] Total Params: 214,894
#  [Params] Main (BG) Network : 214,894 parameters
#
# [Model: spatial] Total Params: 222,316
#  [Params] Main (BG) Network : 222,316 parameters
#
# [Model: spatial] Total Params: 229,864
#  [Params] Main (BG) Network : 229,864 parameters
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
#
# [Model: spatial] Total Params: 245,338
#  [Params] Main (BG) Network : 245,338 parameters
#
# [Model: spatial] Total Params: 253,264
#  [Params] Main (BG) Network : 253,264 parameters
#
# [Model: spatial] Total Params: 261,316
#  [Params] Main (BG) Network : 261,316 parameters
#
# [Model: spatial] Total Params: 269,494
#  [Params] Main (BG) Network : 269,494 parameters
#
# [Model: spatial] Total Params: 277,798
#  [Params] Main (BG) Network : 277,798 parameters
#
# [Model: spatial] Total Params: 286,228
#  [Params] Main (BG) Network : 286,228 parameters
#
# [Model: spatial] Total Params: 294,784
#  [Params] Main (BG) Network : 294,784 parameters
#
# [Model: spatial] Total Params: 303,466
#  [Params] Main (BG) Network : 303,466 parameters
#
# [Model: spatial] Total Params: 312,274
#  [Params] Main (BG) Network : 312,274 parameters
#
# [Model: spatial] Total Params: 321,208
#  [Params] Main (BG) Network : 321,208 parameters
#
# [Model: spatial] Total Params: 330,268
#  [Params] Main (BG) Network : 330,268 parameters
#
# [Model: spatial] Total Params: 339,454
#  [Params] Main (BG) Network : 339,454 parameters
#
# [Model: spatial] Total Params: 348,766
#  [Params] Main (BG) Network : 348,766 parameters
#
# [Model: spatial] Total Params: 358,204
#  [Params] Main (BG) Network : 358,204 parameters
#
# [Model: spatial] Total Params: 367,768
#  [Params] Main (BG) Network : 367,768 parameters
#
# [Model: spatial] Total Params: 377,458
#  [Params] Main (BG) Network : 377,458 parameters
#
# [Model: spatial] Total Params: 387,274
#  [Params] Main (BG) Network : 387,274 parameters
#
# [Model: spatial] Total Params: 397,216
#  [Params] Main (BG) Network : 397,216 parameters
#
# [Model: spatial] Total Params: 407,284
#  [Params] Main (BG) Network : 407,284 parameters
#
# [Model: spatial] Total Params: 417,478
#  [Params] Main (BG) Network : 417,478 parameters
#
# [Model: spatial] Total Params: 427,798
#  [Params] Main (BG) Network : 427,798 parameters
#
# [Model: spatial] Total Params: 438,244
#  [Params] Main (BG) Network : 438,244 parameters
#
# [Model: spatial] Total Params: 448,816
#  [Params] Main (BG) Network : 448,816 parameters
#
# [Model: spatial] Total Params: 459,514
#  [Params] Main (BG) Network : 459,514 parameters
#
# [Model: spatial] Total Params: 470,338
#  [Params] Main (BG) Network : 470,338 parameters
#
# [Model: spatial] Total Params: 481,288
#  [Params] Main (BG) Network : 481,288 parameters
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
#
# [Model: spatial] Total Params: 503,566
#  [Params] Main (BG) Network : 503,566 parameters
#
# [Model: spatial] Total Params: 514,894
#  [Params] Main (BG) Network : 514,894 parameters
#
# [Model: spatial] Total Params: 526,348
#  [Params] Main (BG) Network : 526,348 parameters
#
# [Model: spatial] Total Params: 537,928
#  [Params] Main (BG) Network : 537,928 parameters
#
# [Model: spatial] Total Params: 549,634
#  [Params] Main (BG) Network : 549,634 parameters
#
# [Model: spatial] Total Params: 561,466
#  [Params] Main (BG) Network : 561,466 parameters
#
# [Model: spatial] Total Params: 573,424
#  [Params] Main (BG) Network : 573,424 parameters
#
# [Model: spatial] Total Params: 585,508
#  [Params] Main (BG) Network : 585,508 parameters
#
# [Model: spatial] Total Params: 597,718
#  [Params] Main (BG) Network : 597,718 parameters
#
# [Model: spatial] Total Params: 610,054
#  [Params] Main (BG) Network : 610,054 parameters
#
# [Model: spatial] Total Params: 622,516
#  [Params] Main (BG) Network : 622,516 parameters
#
# [Model: spatial] Total Params: 724
#  [Params] Main (BG) Network : 724 parameters
#
# [Model: spatial] Total Params: 1,216
#  [Params] Main (BG) Network : 1,216 parameters
#
# [Model: spatial] Total Params: 1,834
#  [Params] Main (BG) Network : 1,834 parameters
#
# [Model: spatial] Total Params: 2,578
#  [Params] Main (BG) Network : 2,578 parameters
#
# [Model: spatial] Total Params: 3,448
#  [Params] Main (BG) Network : 3,448 parameters
#
# [Model: spatial] Total Params: 4,444
#  [Params] Main (BG) Network : 4,444 parameters
#
# [Model: spatial] Total Params: 5,566
#  [Params] Main (BG) Network : 5,566 parameters
#
# [Model: spatial] Total Params: 6,814
#  [Params] Main (BG) Network : 6,814 parameters
#
# [Model: spatial] Total Params: 8,188
#  [Params] Main (BG) Network : 8,188 parameters
#
# [Model: spatial] Total Params: 9,688
#  [Params] Main (BG) Network : 9,688 parameters
#
# [Model: spatial] Total Params: 11,314
#  [Params] Main (BG) Network : 11,314 parameters
#
# [Model: spatial] Total Params: 13,066
#  [Params] Main (BG) Network : 13,066 parameters
#
# [Model: spatial] Total Params: 14,944
#  [Params] Main (BG) Network : 14,944 parameters
#
# [Model: spatial] Total Params: 16,948
#  [Params] Main (BG) Network : 16,948 parameters
#
# [Model: spatial] Total Params: 19,078
#  [Params] Main (BG) Network : 19,078 parameters
#
# [Model: spatial] Total Params: 21,334
#  [Params] Main (BG) Network : 21,334 parameters
#
# [Model: spatial] Total Params: 23,716
#  [Params] Main (BG) Network : 23,716 parameters
#
# [Model: spatial] Total Params: 26,224
#  [Params] Main (BG) Network : 26,224 parameters
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
#
# [Model: spatial] Total Params: 31,618
#  [Params] Main (BG) Network : 31,618 parameters
#
# [Model: spatial] Total Params: 34,504
#  [Params] Main (BG) Network : 34,504 parameters
#
# [Model: spatial] Total Params: 37,516
#  [Params] Main (BG) Network : 37,516 parameters
#
# [Model: spatial] Total Params: 40,654
#  [Params] Main (BG) Network : 40,654 parameters
#
# [Model: spatial] Total Params: 43,918
#  [Params] Main (BG) Network : 43,918 parameters
#
# [Model: spatial] Total Params: 47,308
#  [Params] Main (BG) Network : 47,308 parameters
#
# [Model: spatial] Total Params: 50,824
#  [Params] Main (BG) Network : 50,824 parameters
#
# [Model: spatial] Total Params: 54,466
#  [Params] Main (BG) Network : 54,466 parameters
#
# [Model: spatial] Total Params: 58,234
#  [Params] Main (BG) Network : 58,234 parameters
#
# [Model: spatial] Total Params: 62,128
#  [Params] Main (BG) Network : 62,128 parameters
#
# [Model: spatial] Total Params: 66,148
#  [Params] Main (BG) Network : 66,148 parameters
#
# [Model: spatial] Total Params: 70,294
#  [Params] Main (BG) Network : 70,294 parameters
#
# [Model: spatial] Total Params: 74,566
#  [Params] Main (BG) Network : 74,566 parameters
#
# [Model: spatial] Total Params: 78,964
#  [Params] Main (BG) Network : 78,964 parameters
#
# [Model: spatial] Total Params: 83,488
#  [Params] Main (BG) Network : 83,488 parameters
#
# [Model: spatial] Total Params: 88,138
#  [Params] Main (BG) Network : 88,138 parameters
#
# [Model: spatial] Total Params: 92,914
#  [Params] Main (BG) Network : 92,914 parameters
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
#
# [Model: spatial] Total Params: 102,844
#  [Params] Main (BG) Network : 102,844 parameters
#
# [Model: spatial] Total Params: 107,998
#  [Params] Main (BG) Network : 107,998 parameters
#
# [Model: spatial] Total Params: 113,278
#  [Params] Main (BG) Network : 113,278 parameters
#
# [Model: spatial] Total Params: 118,684
#  [Params] Main (BG) Network : 118,684 parameters
#
# [Model: spatial] Total Params: 124,216
#  [Params] Main (BG) Network : 124,216 parameters
#
# [Model: spatial] Total Params: 129,874
#  [Params] Main (BG) Network : 129,874 parameters
#
# [Model: spatial] Total Params: 135,658
#  [Params] Main (BG) Network : 135,658 parameters
#
# [Model: spatial] Total Params: 141,568
#  [Params] Main (BG) Network : 141,568 parameters
#
# [Model: spatial] Total Params: 147,604
#  [Params] Main (BG) Network : 147,604 parameters
#
# [Model: spatial] Total Params: 153,766
#  [Params] Main (BG) Network : 153,766 parameters
#
# [Model: spatial] Total Params: 160,054
#  [Params] Main (BG) Network : 160,054 parameters
#
# [Model: spatial] Total Params: 166,468
#  [Params] Main (BG) Network : 166,468 parameters
#
# [Model: spatial] Total Params: 173,008
#  [Params] Main (BG) Network : 173,008 parameters
#
# [Model: spatial] Total Params: 179,674
#  [Params] Main (BG) Network : 179,674 parameters
#
# [Model: spatial] Total Params: 186,466
#  [Params] Main (BG) Network : 186,466 parameters
#
# [Model: spatial] Total Params: 193,384
#  [Params] Main (BG) Network : 193,384 parameters
#
# [Model: spatial] Total Params: 200,428
#  [Params] Main (BG) Network : 200,428 parameters
#
# [Model: spatial] Total Params: 207,598
#  [Params] Main (BG) Network : 207,598 parameters
#
# [Model: spatial] Total Params: 214,894
#  [Params] Main (BG) Network : 214,894 parameters
#
# [Model: spatial] Total Params: 222,316
#  [Params] Main (BG) Network : 222,316 parameters
#
# [Model: spatial] Total Params: 229,864
#  [Params] Main (BG) Network : 229,864 parameters
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
#
# [Model: spatial] Total Params: 245,338
#  [Params] Main (BG) Network : 245,338 parameters
#
# [Model: spatial] Total Params: 253,264
#  [Params] Main (BG) Network : 253,264 parameters
#
# [Model: spatial] Total Params: 261,316
#  [Params] Main (BG) Network : 261,316 parameters
#
# [Model: spatial] Total Params: 269,494
#  [Params] Main (BG) Network : 269,494 parameters
#
# [Model: spatial] Total Params: 277,798
#  [Params] Main (BG) Network : 277,798 parameters
#
# [Model: spatial] Total Params: 286,228
#  [Params] Main (BG) Network : 286,228 parameters
#
# [Model: spatial] Total Params: 294,784
#  [Params] Main (BG) Network : 294,784 parameters
#
# [Model: spatial] Total Params: 303,466
#  [Params] Main (BG) Network : 303,466 parameters
#
# [Model: spatial] Total Params: 312,274
#  [Params] Main (BG) Network : 312,274 parameters
#
# [Model: spatial] Total Params: 321,208
#  [Params] Main (BG) Network : 321,208 parameters
#
# [Model: spatial] Total Params: 330,268
#  [Params] Main (BG) Network : 330,268 parameters
#
# [Model: spatial] Total Params: 339,454
#  [Params] Main (BG) Network : 339,454 parameters
#
# [Model: spatial] Total Params: 348,766
#  [Params] Main (BG) Network : 348,766 parameters
#
# [Model: spatial] Total Params: 358,204
#  [Params] Main (BG) Network : 358,204 parameters
#
# [Model: spatial] Total Params: 367,768
#  [Params] Main (BG) Network : 367,768 parameters
#
# [Model: spatial] Total Params: 377,458
#  [Params] Main (BG) Network : 377,458 parameters
#
# [Model: spatial] Total Params: 387,274
#  [Params] Main (BG) Network : 387,274 parameters
#
# [Model: spatial] Total Params: 397,216
#  [Params] Main (BG) Network : 397,216 parameters
#
# [Model: spatial] Total Params: 407,284
#  [Params] Main (BG) Network : 407,284 parameters
#
# [Model: spatial] Total Params: 417,478
#  [Params] Main (BG) Network : 417,478 parameters
#
# [Model: spatial] Total Params: 427,798
#  [Params] Main (BG) Network : 427,798 parameters
#
# [Model: spatial] Total Params: 438,244
#  [Params] Main (BG) Network : 438,244 parameters
#
# [Model: spatial] Total Params: 448,816
#  [Params] Main (BG) Network : 448,816 parameters
#
# [Model: spatial] Total Params: 459,514
#  [Params] Main (BG) Network : 459,514 parameters
#
# [Model: spatial] Total Params: 470,338
#  [Params] Main (BG) Network : 470,338 parameters
#
# [Model: spatial] Total Params: 481,288
#  [Params] Main (BG) Network : 481,288 parameters
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
#
# [Model: spatial] Total Params: 503,566
#  [Params] Main (BG) Network : 503,566 parameters
#
# [Model: spatial] Total Params: 514,894
#  [Params] Main (BG) Network : 514,894 parameters
#
# [Model: spatial] Total Params: 526,348
#  [Params] Main (BG) Network : 526,348 parameters
#
# [Model: spatial] Total Params: 537,928
#  [Params] Main (BG) Network : 537,928 parameters
#
# [Model: spatial] Total Params: 549,634
#  [Params] Main (BG) Network : 549,634 parameters
#
# [Model: spatial] Total Params: 561,466
#  [Params] Main (BG) Network : 561,466 parameters
#
# [Model: spatial] Total Params: 573,424
#  [Params] Main (BG) Network : 573,424 parameters
#
# [Model: spatial] Total Params: 585,508
#  [Params] Main (BG) Network : 585,508 parameters
#
# [Model: spatial] Total Params: 597,718
#  [Params] Main (BG) Network : 597,718 parameters
#
# [Model: spatial] Total Params: 610,054
#  [Params] Main (BG) Network : 610,054 parameters
#
# [Model: spatial] Total Params: 622,516
#  [Params] Main (BG) Network : 622,516 parameters
#
# [Model: spatial] Total Params: 724
#  [Params] Main (BG) Network : 724 parameters
#
# [Model: spatial] Total Params: 1,216
#  [Params] Main (BG) Network : 1,216 parameters
#
# [Model: spatial] Total Params: 1,834
#  [Params] Main (BG) Network : 1,834 parameters
#
# [Model: spatial] Total Params: 2,578
#  [Params] Main (BG) Network : 2,578 parameters
#
# [Model: spatial] Total Params: 3,448
#  [Params] Main (BG) Network : 3,448 parameters
#
# [Model: spatial] Total Params: 4,444
#  [Params] Main (BG) Network : 4,444 parameters
#
# [Model: spatial] Total Params: 5,566
#  [Params] Main (BG) Network : 5,566 parameters
#
# [Model: spatial] Total Params: 6,814
#  [Params] Main (BG) Network : 6,814 parameters
#
# [Model: spatial] Total Params: 8,188
#  [Params] Main (BG) Network : 8,188 parameters
#
# [Model: spatial] Total Params: 9,688
#  [Params] Main (BG) Network : 9,688 parameters
#
# [Model: spatial] Total Params: 11,314
#  [Params] Main (BG) Network : 11,314 parameters
#
# [Model: spatial] Total Params: 13,066
#  [Params] Main (BG) Network : 13,066 parameters
#
# [Model: spatial] Total Params: 14,944
#  [Params] Main (BG) Network : 14,944 parameters
#
# [Model: spatial] Total Params: 16,948
#  [Params] Main (BG) Network : 16,948 parameters
#
# [Model: spatial] Total Params: 19,078
#  [Params] Main (BG) Network : 19,078 parameters
#
# [Model: spatial] Total Params: 21,334
#  [Params] Main (BG) Network : 21,334 parameters
#
# [Model: spatial] Total Params: 23,716
#  [Params] Main (BG) Network : 23,716 parameters
#
# [Model: spatial] Total Params: 26,224
#  [Params] Main (BG) Network : 26,224 parameters
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
#
# [Model: spatial] Total Params: 31,618
#  [Params] Main (BG) Network : 31,618 parameters
#
# [Model: spatial] Total Params: 34,504
#  [Params] Main (BG) Network : 34,504 parameters
#
# [Model: spatial] Total Params: 37,516
#  [Params] Main (BG) Network : 37,516 parameters
#
# [Model: spatial] Total Params: 40,654
#  [Params] Main (BG) Network : 40,654 parameters
#
# [Model: spatial] Total Params: 43,918
#  [Params] Main (BG) Network : 43,918 parameters
#
# [Model: spatial] Total Params: 47,308
#  [Params] Main (BG) Network : 47,308 parameters
#
# [Model: spatial] Total Params: 50,824
#  [Params] Main (BG) Network : 50,824 parameters
#
# [Model: spatial] Total Params: 54,466
#  [Params] Main (BG) Network : 54,466 parameters
#
# [Model: spatial] Total Params: 58,234
#  [Params] Main (BG) Network : 58,234 parameters
#
# [Model: spatial] Total Params: 62,128
#  [Params] Main (BG) Network : 62,128 parameters
#
# [Model: spatial] Total Params: 66,148
#  [Params] Main (BG) Network : 66,148 parameters
#
# [Model: spatial] Total Params: 70,294
#  [Params] Main (BG) Network : 70,294 parameters
#
# [Model: spatial] Total Params: 74,566
#  [Params] Main (BG) Network : 74,566 parameters
#
# [Model: spatial] Total Params: 78,964
#  [Params] Main (BG) Network : 78,964 parameters
#
# [Model: spatial] Total Params: 83,488
#  [Params] Main (BG) Network : 83,488 parameters
#
# [Model: spatial] Total Params: 88,138
#  [Params] Main (BG) Network : 88,138 parameters
#
# [Model: spatial] Total Params: 92,914
#  [Params] Main (BG) Network : 92,914 parameters
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
#
# [Model: spatial] Total Params: 102,844
#  [Params] Main (BG) Network : 102,844 parameters
#
# [Model: spatial] Total Params: 107,998
#  [Params] Main (BG) Network : 107,998 parameters
#
# [Model: spatial] Total Params: 113,278
#  [Params] Main (BG) Network : 113,278 parameters
#
# [Model: spatial] Total Params: 118,684
#  [Params] Main (BG) Network : 118,684 parameters
#
# [Model: spatial] Total Params: 124,216
#  [Params] Main (BG) Network : 124,216 parameters
#
# [Model: spatial] Total Params: 129,874
#  [Params] Main (BG) Network : 129,874 parameters
#
# [Model: spatial] Total Params: 135,658
#  [Params] Main (BG) Network : 135,658 parameters
#
# [Model: spatial] Total Params: 141,568
#  [Params] Main (BG) Network : 141,568 parameters
#
# [Model: spatial] Total Params: 147,604
#  [Params] Main (BG) Network : 147,604 parameters
#
# [Model: spatial] Total Params: 153,766
#  [Params] Main (BG) Network : 153,766 parameters
#
# [Model: spatial] Total Params: 160,054
#  [Params] Main (BG) Network : 160,054 parameters
#
# [Model: spatial] Total Params: 166,468
#  [Params] Main (BG) Network : 166,468 parameters
#
# [Model: spatial] Total Params: 173,008
#  [Params] Main (BG) Network : 173,008 parameters
#
# [Model: spatial] Total Params: 179,674
#  [Params] Main (BG) Network : 179,674 parameters
#
# [Model: spatial] Total Params: 186,466
#  [Params] Main (BG) Network : 186,466 parameters
#
# [Model: spatial] Total Params: 193,384
#  [Params] Main (BG) Network : 193,384 parameters
#
# [Model: spatial] Total Params: 200,428
#  [Params] Main (BG) Network : 200,428 parameters
#
# [Model: spatial] Total Params: 207,598
#  [Params] Main (BG) Network : 207,598 parameters
#
# [Model: spatial] Total Params: 214,894
#  [Params] Main (BG) Network : 214,894 parameters
#
# [Model: spatial] Total Params: 222,316
#  [Params] Main (BG) Network : 222,316 parameters
#
# [Model: spatial] Total Params: 229,864
#  [Params] Main (BG) Network : 229,864 parameters
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
#
# [Model: spatial] Total Params: 245,338
#  [Params] Main (BG) Network : 245,338 parameters
#
# [Model: spatial] Total Params: 253,264
#  [Params] Main (BG) Network : 253,264 parameters
#
# [Model: spatial] Total Params: 261,316
#  [Params] Main (BG) Network : 261,316 parameters
#
# [Model: spatial] Total Params: 269,494
#  [Params] Main (BG) Network : 269,494 parameters
#
# [Model: spatial] Total Params: 277,798
#  [Params] Main (BG) Network : 277,798 parameters
#
# [Model: spatial] Total Params: 286,228
#  [Params] Main (BG) Network : 286,228 parameters
#
# [Model: spatial] Total Params: 294,784
#  [Params] Main (BG) Network : 294,784 parameters
#
# [Model: spatial] Total Params: 303,466
#  [Params] Main (BG) Network : 303,466 parameters
#
# [Model: spatial] Total Params: 312,274
#  [Params] Main (BG) Network : 312,274 parameters
#
# [Model: spatial] Total Params: 321,208
#  [Params] Main (BG) Network : 321,208 parameters
#
# [Model: spatial] Total Params: 330,268
#  [Params] Main (BG) Network : 330,268 parameters
#
# [Model: spatial] Total Params: 339,454
#  [Params] Main (BG) Network : 339,454 parameters
#
# [Model: spatial] Total Params: 348,766
#  [Params] Main (BG) Network : 348,766 parameters
#
# [Model: spatial] Total Params: 358,204
#  [Params] Main (BG) Network : 358,204 parameters
#
# [Model: spatial] Total Params: 367,768
#  [Params] Main (BG) Network : 367,768 parameters
#
# [Model: spatial] Total Params: 377,458
#  [Params] Main (BG) Network : 377,458 parameters
#
# [Model: spatial] Total Params: 387,274
#  [Params] Main (BG) Network : 387,274 parameters
#
# [Model: spatial] Total Params: 397,216
#  [Params] Main (BG) Network : 397,216 parameters
#
# [Model: spatial] Total Params: 407,284
#  [Params] Main (BG) Network : 407,284 parameters
#
# [Model: spatial] Total Params: 417,478
#  [Params] Main (BG) Network : 417,478 parameters
#
# [Model: spatial] Total Params: 427,798
#  [Params] Main (BG) Network : 427,798 parameters
#
# [Model: spatial] Total Params: 438,244
#  [Params] Main (BG) Network : 438,244 parameters
#
# [Model: spatial] Total Params: 448,816
#  [Params] Main (BG) Network : 448,816 parameters
#
# [Model: spatial] Total Params: 459,514
#  [Params] Main (BG) Network : 459,514 parameters
#
# [Model: spatial] Total Params: 470,338
#  [Params] Main (BG) Network : 470,338 parameters
#
# [Model: spatial] Total Params: 481,288
#  [Params] Main (BG) Network : 481,288 parameters
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
#
# [Model: spatial] Total Params: 503,566
#  [Params] Main (BG) Network : 503,566 parameters
#
# [Model: spatial] Total Params: 514,894
#  [Params] Main (BG) Network : 514,894 parameters
#
# [Model: spatial] Total Params: 526,348
#  [Params] Main (BG) Network : 526,348 parameters
#
# [Model: spatial] Total Params: 537,928
#  [Params] Main (BG) Network : 537,928 parameters
#
# [Model: spatial] Total Params: 549,634
#  [Params] Main (BG) Network : 549,634 parameters
#
# [Model: spatial] Total Params: 561,466
#  [Params] Main (BG) Network : 561,466 parameters
#
# [Model: spatial] Total Params: 573,424
#  [Params] Main (BG) Network : 573,424 parameters
#
# [Model: spatial] Total Params: 585,508
#  [Params] Main (BG) Network : 585,508 parameters
#
# [Model: spatial] Total Params: 597,718
#  [Params] Main (BG) Network : 597,718 parameters
#
# [Model: spatial] Total Params: 610,054
#  [Params] Main (BG) Network : 610,054 parameters
#
# [Model: spatial] Total Params: 622,516
#  [Params] Main (BG) Network : 622,516 parameters
#
# [Model: spatial] Total Params: 724
#  [Params] Main (BG) Network : 724 parameters
#
# [Model: spatial] Total Params: 1,216
#  [Params] Main (BG) Network : 1,216 parameters
#
# [Model: spatial] Total Params: 1,834
#  [Params] Main (BG) Network : 1,834 parameters
#
# [Model: spatial] Total Params: 2,578
#  [Params] Main (BG) Network : 2,578 parameters
#
# [Model: spatial] Total Params: 3,448
#  [Params] Main (BG) Network : 3,448 parameters
#
# [Model: spatial] Total Params: 4,444
#  [Params] Main (BG) Network : 4,444 parameters
#
# [Model: spatial] Total Params: 5,566
#  [Params] Main (BG) Network : 5,566 parameters
#
# [Model: spatial] Total Params: 6,814
#  [Params] Main (BG) Network : 6,814 parameters
#
# [Model: spatial] Total Params: 8,188
#  [Params] Main (BG) Network : 8,188 parameters
#
# [Model: spatial] Total Params: 9,688
#  [Params] Main (BG) Network : 9,688 parameters
#
# [Model: spatial] Total Params: 11,314
#  [Params] Main (BG) Network : 11,314 parameters
#
# [Model: spatial] Total Params: 13,066
#  [Params] Main (BG) Network : 13,066 parameters
#
# [Model: spatial] Total Params: 14,944
#  [Params] Main (BG) Network : 14,944 parameters
#
# [Model: spatial] Total Params: 16,948
#  [Params] Main (BG) Network : 16,948 parameters
#
# [Model: spatial] Total Params: 19,078
#  [Params] Main (BG) Network : 19,078 parameters
#
# [Model: spatial] Total Params: 21,334
#  [Params] Main (BG) Network : 21,334 parameters
#
# [Model: spatial] Total Params: 23,716
#  [Params] Main (BG) Network : 23,716 parameters
#
# [Model: spatial] Total Params: 26,224
#  [Params] Main (BG) Network : 26,224 parameters
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
#
# [Model: spatial] Total Params: 31,618
#  [Params] Main (BG) Network : 31,618 parameters
#
# [Model: spatial] Total Params: 34,504
#  [Params] Main (BG) Network : 34,504 parameters
#
# [Model: spatial] Total Params: 37,516
#  [Params] Main (BG) Network : 37,516 parameters
#
# [Model: spatial] Total Params: 40,654
#  [Params] Main (BG) Network : 40,654 parameters
#
# [Model: spatial] Total Params: 43,918
#  [Params] Main (BG) Network : 43,918 parameters
#
# [Model: spatial] Total Params: 47,308
#  [Params] Main (BG) Network : 47,308 parameters
#
# [Model: spatial] Total Params: 50,824
#  [Params] Main (BG) Network : 50,824 parameters
#
# [Model: spatial] Total Params: 54,466
#  [Params] Main (BG) Network : 54,466 parameters
#
# [Model: spatial] Total Params: 58,234
#  [Params] Main (BG) Network : 58,234 parameters
#
# [Model: spatial] Total Params: 62,128
#  [Params] Main (BG) Network : 62,128 parameters
#
# [Model: spatial] Total Params: 66,148
#  [Params] Main (BG) Network : 66,148 parameters
#
# [Model: spatial] Total Params: 70,294
#  [Params] Main (BG) Network : 70,294 parameters
#
# [Model: spatial] Total Params: 74,566
#  [Params] Main (BG) Network : 74,566 parameters
#
# [Model: spatial] Total Params: 78,964
#  [Params] Main (BG) Network : 78,964 parameters
#
# [Model: spatial] Total Params: 83,488
#  [Params] Main (BG) Network : 83,488 parameters
#
# [Model: spatial] Total Params: 88,138
#  [Params] Main (BG) Network : 88,138 parameters
#
# [Model: spatial] Total Params: 92,914
#  [Params] Main (BG) Network : 92,914 parameters
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
#
# [Model: spatial] Total Params: 102,844
#  [Params] Main (BG) Network : 102,844 parameters
#
# [Model: spatial] Total Params: 107,998
#  [Params] Main (BG) Network : 107,998 parameters
#
# [Model: spatial] Total Params: 113,278
#  [Params] Main (BG) Network : 113,278 parameters
#
# [Model: spatial] Total Params: 118,684
#  [Params] Main (BG) Network : 118,684 parameters
#
# [Model: spatial] Total Params: 124,216
#  [Params] Main (BG) Network : 124,216 parameters
#
# [Model: spatial] Total Params: 129,874
#  [Params] Main (BG) Network : 129,874 parameters
#
# [Model: spatial] Total Params: 135,658
#  [Params] Main (BG) Network : 135,658 parameters
#
# [Model: spatial] Total Params: 141,568
#  [Params] Main (BG) Network : 141,568 parameters
#
# [Model: spatial] Total Params: 147,604
#  [Params] Main (BG) Network : 147,604 parameters
#
# [Model: spatial] Total Params: 153,766
#  [Params] Main (BG) Network : 153,766 parameters
#
# [Model: spatial] Total Params: 160,054
#  [Params] Main (BG) Network : 160,054 parameters
#
# [Model: spatial] Total Params: 166,468
#  [Params] Main (BG) Network : 166,468 parameters
#
# [Model: spatial] Total Params: 173,008
#  [Params] Main (BG) Network : 173,008 parameters
#
# [Model: spatial] Total Params: 179,674
#  [Params] Main (BG) Network : 179,674 parameters
#
# [Model: spatial] Total Params: 186,466
#  [Params] Main (BG) Network : 186,466 parameters
#
# [Model: spatial] Total Params: 193,384
#  [Params] Main (BG) Network : 193,384 parameters
#
# [Model: spatial] Total Params: 200,428
#  [Params] Main (BG) Network : 200,428 parameters
#
# [Model: spatial] Total Params: 207,598
#  [Params] Main (BG) Network : 207,598 parameters
#
# [Model: spatial] Total Params: 214,894
#  [Params] Main (BG) Network : 214,894 parameters
#
# [Model: spatial] Total Params: 222,316
#  [Params] Main (BG) Network : 222,316 parameters
#
# [Model: spatial] Total Params: 229,864
#  [Params] Main (BG) Network : 229,864 parameters
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
#
# [Model: spatial] Total Params: 245,338
#  [Params] Main (BG) Network : 245,338 parameters
#
# [Model: spatial] Total Params: 253,264
#  [Params] Main (BG) Network : 253,264 parameters
#
# [Model: spatial] Total Params: 261,316
#  [Params] Main (BG) Network : 261,316 parameters
#
# [Model: spatial] Total Params: 269,494
#  [Params] Main (BG) Network : 269,494 parameters
#
# [Model: spatial] Total Params: 277,798
#  [Params] Main (BG) Network : 277,798 parameters
#
# [Model: spatial] Total Params: 286,228
#  [Params] Main (BG) Network : 286,228 parameters
#
# [Model: spatial] Total Params: 294,784
#  [Params] Main (BG) Network : 294,784 parameters
#
# [Model: spatial] Total Params: 303,466
#  [Params] Main (BG) Network : 303,466 parameters
#
# [Model: spatial] Total Params: 312,274
#  [Params] Main (BG) Network : 312,274 parameters
#
# [Model: spatial] Total Params: 321,208
#  [Params] Main (BG) Network : 321,208 parameters
#
# [Model: spatial] Total Params: 330,268
#  [Params] Main (BG) Network : 330,268 parameters
#
# [Model: spatial] Total Params: 339,454
#  [Params] Main (BG) Network : 339,454 parameters
#
# [Model: spatial] Total Params: 348,766
#  [Params] Main (BG) Network : 348,766 parameters
#
# [Model: spatial] Total Params: 358,204
#  [Params] Main (BG) Network : 358,204 parameters
#
# [Model: spatial] Total Params: 367,768
#  [Params] Main (BG) Network : 367,768 parameters
#
# [Model: spatial] Total Params: 377,458
#  [Params] Main (BG) Network : 377,458 parameters
#
# [Model: spatial] Total Params: 387,274
#  [Params] Main (BG) Network : 387,274 parameters
#
# [Model: spatial] Total Params: 397,216
#  [Params] Main (BG) Network : 397,216 parameters
#
# [Model: spatial] Total Params: 407,284
#  [Params] Main (BG) Network : 407,284 parameters
#
# [Model: spatial] Total Params: 417,478
#  [Params] Main (BG) Network : 417,478 parameters
#
# [Model: spatial] Total Params: 427,798
#  [Params] Main (BG) Network : 427,798 parameters
#
# [Model: spatial] Total Params: 438,244
#  [Params] Main (BG) Network : 438,244 parameters
#
# [Model: spatial] Total Params: 448,816
#  [Params] Main (BG) Network : 448,816 parameters
#
# [Model: spatial] Total Params: 459,514
#  [Params] Main (BG) Network : 459,514 parameters
#
# [Model: spatial] Total Params: 470,338
#  [Params] Main (BG) Network : 470,338 parameters
#
# [Model: spatial] Total Params: 481,288
#  [Params] Main (BG) Network : 481,288 parameters
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
#
# [Model: spatial] Total Params: 503,566
#  [Params] Main (BG) Network : 503,566 parameters
#
# [Model: spatial] Total Params: 514,894
#  [Params] Main (BG) Network : 514,894 parameters
#
# [Model: spatial] Total Params: 526,348
#  [Params] Main (BG) Network : 526,348 parameters
#
# [Model: spatial] Total Params: 537,928
#  [Params] Main (BG) Network : 537,928 parameters
#
# [Model: spatial] Total Params: 549,634
#  [Params] Main (BG) Network : 549,634 parameters
#
# [Model: spatial] Total Params: 561,466
#  [Params] Main (BG) Network : 561,466 parameters
#
# [Model: spatial] Total Params: 573,424
#  [Params] Main (BG) Network : 573,424 parameters
#
# [Model: spatial] Total Params: 585,508
#  [Params] Main (BG) Network : 585,508 parameters
#
# [Model: spatial] Total Params: 597,718
#  [Params] Main (BG) Network : 597,718 parameters
#
# [Model: spatial] Total Params: 610,054
#  [Params] Main (BG) Network : 610,054 parameters
#
# [Model: spatial] Total Params: 622,516
#  [Params] Main (BG) Network : 622,516 parameters
# Fixed: lr=1.0e-03 | direction=Z | 120s/config | freq_warmup=1
# REL_ERRS: [0.003, 0.005, 0.007, 0.009, 0.01]
# Model sizes (4 distinct):
#   bg_h=21  ~28,858 params
#   bg_h=39  ~97,816 params
#   bg_h=61  ~237,538 params
#   bg_h=88  ~492,364 params
#
# >> 20 trainings total (~40 min at 120s each)

# %%
# Reload bg_stage so re-running ONLY this cell picks up early-stop edits.
import importlib, bg_stage
importlib.reload(bg_stage)
from bg_stage import run_bg_inference, train_bg_only, unwrap_bg_model
print(f"bg_stage OK: {bg_stage.__file__}\n")

depth    = work_shape[0]
patch_sz = work_shape[2]

# GPU warm-up (not timed) using the loosest rel_err
_w_Xps, _, _ = compress_at(gt, max(REL_ERRS))
_wcfg = build_cfg(Xs, _w_Xps, max_train_time=0.5, bg_h=4,
                  steps_per_epoch=2, lr=1e-3, epochs=1, log_prefix="warmup")
set_seed(42)
train_bg_only(Xs=Xs, Xps=_w_Xps, device=device, cfg=_wcfg,
              evaluator=lambda m, c=_wcfg: (0.0, 0.0))
torch.cuda.synchronize() if torch.cuda.is_available() else None
del _w_Xps
print("GPU warm-up done\n")

results   = []   # dict: rel, bg_h, n_params, psnr, cr, model_mb, sz_mb, epochs
baselines = []   # dict: rel, cr, psnr, sz_mb   (SZ3 only, no model)

sweep_t0 = time.time()
for rel in REL_ERRS:
    Xps_list, sz_bytes, sz_cr = compress_at(gt, rel)
    base_psnr = psnr_from_arrays(gt, Xps_list[0])
    base_cr   = orig_bytes / sz_bytes
    baselines.append(dict(rel=rel, cr=base_cr, psnr=base_psnr, sz_mb=sz_bytes/1e6))
    print(f"\n{'#'*60}")
    print(f"# rel={rel:.0e} | SZ3 base: CR={base_cr:.2f}x ({sz_bytes/1e6:.2f} MB) | "
          f"base PSNR={base_psnr:.2f} dB")

    for bg_h, est_p in sweep_plan:
        cfg = build_cfg(Xs, Xps_list, max_train_time=TIME_PER_CONFIG, bg_h=bg_h,
                        steps_per_epoch=depth, lr=FIXED_LR, epochs=200,
                        log_prefix=f"r{rel:.0e}-h{bg_h}", patch_size=patch_sz)
        cfg.bg_early_stop          = False   # ablation: train every model the full budget
        cfg.bg_freq_warmup_epochs  = FREQ_WARMUP

        def evaluator(m, c=cfg, Xp=Xps_list):
            xh = run_bg_inference(unwrap_bg_model(m), Xs, Xp, c, rel)
            return psnr_from_arrays(gt, xh), 0.0

        set_seed(42)
        model, hist = train_bg_only(Xs=Xs, Xps=Xps_list, device=device,
                                    cfg=cfg, evaluator=evaluator)

        n_params    = n_params_of(model)
        psnr_vals   = [v[1] if isinstance(v, tuple) else v for v in hist.get("psnr", [])]
        psnr        = max(psnr_vals) if psnr_vals else float("nan")
        model_bytes = n_params * BYTES_PER_PARAM
        cr          = orig_bytes / (sz_bytes + model_bytes)
        results.append(dict(rel=rel, bg_h=bg_h, n_params=n_params, psnr=psnr, cr=cr,
                            model_mb=model_bytes/1e6, sz_mb=sz_bytes/1e6,
                            epochs=len(hist.get("loss", []))))
        print(f"  bg_h={bg_h:2d} ({n_params:,}p): PSNR={psnr:.2f} dB | CR={cr:.2f}x "
              f"(base {base_cr:.2f}x) | +{psnr-base_psnr:.2f} dB over SZ3")
        del model
        torch.cuda.empty_cache() if torch.cuda.is_available() else None

    del Xps_list

print(f"\n--- Sweep complete in {(time.time()-sweep_t0)/60:.1f} min "
      f"({len(results)} models over {len(REL_ERRS)} rel-errors) ---")
# Out:
# bg_stage OK: /home/sam/Halo_Finder/Final_design/base_script/bg_stage.py
#
#
# [Model: spatial] Total Params: 1,216
#  [Params] Main (BG) Network : 1,216 parameters
# warmup [Init] Epoch   0 | Global PSNR: 0.00 dB | MaxErr: 0.0
# warmup [plan] pure_train_budget=0.50s | epochs_cap=1 | steps/epoch=2 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# warmup [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# warmup [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# warmup Epoch   1 [BG] | train_wall=0.00s | Loss: 0.000000 | Global: 0.00 dB | MaxErr: 0.0
# warmup [timing] first_epoch_pure_train≈0.569s (excludes this epoch's end-of-epoch eval)
#
# warmup --- Experiment [BG_only] finished ---
# warmup --- Pure training time: 0.57 s ---
# warmup [timing] epochs=1 | train_wall/epoch: mean=0.00s min=0.00s max=0.00s | sum=0.00s
# warmup --- Best global PSNR: 0.00 dB ---
# GPU warm-up done
#
#
# ############################################################
# # rel=3e-03 | SZ3 base: CR=72.43x (59.30 MB) | base PSNR=58.83 dB
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
# r3e-03-h21 [Init] Epoch   0 | Global PSNR: 58.83 dB | MaxErr: 0.0
# r3e-03-h21 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r3e-03-h21 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r3e-03-h21 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# /home/sam/Halo_Finder/Final_design/base_script/bg_stage.py:522: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=use_amp, dtype=autocast_dtype):
# r3e-03-h21 Epoch   1 [BG] | train_wall=8.64s | Loss: 0.852151 | Freq: 1.678432 | Global: 60.58 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 [timing] first_epoch_pure_train≈9.199s (excludes this epoch's end-of-epoch eval)
# r3e-03-h21 Epoch   2 [BG] | train_wall=6.64s | Loss: 1.354429 | Freq: 0.744671 | Global: 61.38 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch   3 [BG] | train_wall=6.64s | Loss: 1.243721 | Freq: 0.682796 | Global: 61.53 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch   4 [BG] | train_wall=6.64s | Loss: 1.208140 | Freq: 0.660770 | Global: 61.60 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch   5 [BG] | train_wall=6.64s | Loss: 1.188430 | Freq: 0.647961 | Global: 61.70 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch   6 [BG] | train_wall=6.65s | Loss: 1.173519 | Freq: 0.638302 | Global: 61.71 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch   7 [BG] | train_wall=6.65s | Loss: 1.161256 | Freq: 0.630409 | Global: 61.78 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch   8 [BG] | train_wall=6.65s | Loss: 1.151824 | Freq: 0.624359 | Global: 61.84 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch   9 [BG] | train_wall=6.65s | Loss: 1.141811 | Freq: 0.617832 | Global: 61.86 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch  10 [BG] | train_wall=6.65s | Loss: 1.134659 | Freq: 0.613197 | Global: 61.89 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch  11 [BG] | train_wall=6.66s | Loss: 1.127831 | Freq: 0.608650 | Global: 61.91 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch  12 [BG] | train_wall=6.65s | Loss: 1.120424 | Freq: 0.603607 | Global: 61.94 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch  13 [BG] | train_wall=6.65s | Loss: 1.114776 | Freq: 0.599598 | Global: 61.94 dB | MaxErr: 0.0
# r3e-03-h21 Epoch  14 [BG] | train_wall=6.65s | Loss: 1.109120 | Freq: 0.595688 | Global: 61.98 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch  15 [BG] | train_wall=6.65s | Loss: 1.102332 | Freq: 0.591042 | Global: 61.99 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch  16 [BG] | train_wall=6.69s | Loss: 1.096607 | Freq: 0.586975 | Global: 62.02 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h21 Epoch  17 [BG] | train_wall=6.66s | Loss: 1.090703 | Freq: 0.582741 | Global: 62.00 dB | MaxErr: 0.0
# r3e-03-h21 Epoch  18 [BG] | train_wall=4.36s | Loss: 1.091864 | Freq: 0.582381 | Global: 62.10 dB | MaxErr: 0.0  [New Best!]
#
# r3e-03-h21 --- Experiment [BG_only] finished ---
# r3e-03-h21 --- Pure training time: 120.00 s ---
# r3e-03-h21 [timing] epochs=18 | train_wall/epoch: mean=6.63s min=4.36s max=8.64s | sum=119.43s
# r3e-03-h21 --- Best global PSNR: 62.10 dB ---
#   bg_h=21 (28,858p): PSNR=62.10 dB | CR=72.36x (base 72.43x) | +3.27 dB over SZ3
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
# r3e-03-h39 [Init] Epoch   0 | Global PSNR: 58.83 dB | MaxErr: 0.0
# r3e-03-h39 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r3e-03-h39 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r3e-03-h39 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# r3e-03-h39 Epoch   1 [BG] | train_wall=14.89s | Loss: 0.772848 | Freq: 1.377346 | Global: 61.17 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 [timing] first_epoch_pure_train≈15.447s (excludes this epoch's end-of-epoch eval)
# r3e-03-h39 Epoch   2 [BG] | train_wall=13.14s | Loss: 1.204921 | Freq: 0.654667 | Global: 61.74 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 Epoch   3 [BG] | train_wall=13.14s | Loss: 1.119902 | Freq: 0.605244 | Global: 61.83 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 Epoch   4 [BG] | train_wall=13.16s | Loss: 1.092768 | Freq: 0.587906 | Global: 62.07 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 Epoch   5 [BG] | train_wall=13.15s | Loss: 1.073079 | Freq: 0.575634 | Global: 62.17 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 Epoch   6 [BG] | train_wall=13.17s | Loss: 1.059258 | Freq: 0.566589 | Global: 62.04 dB | MaxErr: 0.0
# r3e-03-h39 Epoch   7 [BG] | train_wall=13.15s | Loss: 1.050077 | Freq: 0.560247 | Global: 62.12 dB | MaxErr: 0.0
# r3e-03-h39 Epoch   8 [BG] | train_wall=13.25s | Loss: 1.036694 | Freq: 0.551414 | Global: 62.26 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h39 Epoch   9 [BG] | train_wall=12.38s | Loss: 1.023801 | Freq: 0.539670 | Global: 62.31 dB | MaxErr: 0.0  [New Best!]
#
# r3e-03-h39 --- Experiment [BG_only] finished ---
# r3e-03-h39 --- Pure training time: 120.00 s ---
# r3e-03-h39 [timing] epochs=9 | train_wall/epoch: mean=13.27s min=12.38s max=14.89s | sum=119.44s
# r3e-03-h39 --- Best global PSNR: 62.31 dB ---
#   bg_h=39 (97,816p): PSNR=62.31 dB | CR=72.19x (base 72.43x) | +3.48 dB over SZ3
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
# r3e-03-h61 [Init] Epoch   0 | Global PSNR: 58.83 dB | MaxErr: 0.0
# r3e-03-h61 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r3e-03-h61 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r3e-03-h61 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# r3e-03-h61 Epoch   1 [BG] | train_wall=20.23s | Loss: 0.710291 | Freq: 1.209888 | Global: 61.41 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h61 [timing] first_epoch_pure_train≈20.791s (excludes this epoch's end-of-epoch eval)
# r3e-03-h61 Epoch   2 [BG] | train_wall=18.40s | Loss: 1.128406 | Freq: 0.610729 | Global: 62.01 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h61 Epoch   3 [BG] | train_wall=18.35s | Loss: 1.060812 | Freq: 0.568069 | Global: 61.99 dB | MaxErr: 0.0
# r3e-03-h61 Epoch   4 [BG] | train_wall=18.32s | Loss: 1.042999 | Freq: 0.556078 | Global: 62.27 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h61 Epoch   5 [BG] | train_wall=18.34s | Loss: 1.021912 | Freq: 0.542171 | Global: 62.19 dB | MaxErr: 0.0
# r3e-03-h61 Epoch   6 [BG] | train_wall=18.42s | Loss: 1.004224 | Freq: 0.529776 | Global: 62.28 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h61 Epoch   7 [BG] | train_wall=7.37s | Loss: 1.004579 | Freq: 0.540897 | Global: 62.39 dB | MaxErr: 0.0  [New Best!]
#
# r3e-03-h61 --- Experiment [BG_only] finished ---
# r3e-03-h61 --- Pure training time: 120.00 s ---
# r3e-03-h61 [timing] epochs=7 | train_wall/epoch: mean=17.06s min=7.37s max=20.23s | sum=119.44s
# r3e-03-h61 --- Best global PSNR: 62.39 dB ---
#   bg_h=61 (237,538p): PSNR=62.39 dB | CR=71.85x (base 72.43x) | +3.57 dB over SZ3
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
# r3e-03-h88 [Init] Epoch   0 | Global PSNR: 58.83 dB | MaxErr: 0.0
# r3e-03-h88 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r3e-03-h88 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r3e-03-h88 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# r3e-03-h88 Epoch   1 [BG] | train_wall=34.67s | Loss: 0.704635 | Freq: 1.248619 | Global: 61.62 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h88 [timing] first_epoch_pure_train≈35.235s (excludes this epoch's end-of-epoch eval)
# r3e-03-h88 Epoch   2 [BG] | train_wall=33.05s | Loss: 1.076470 | Freq: 0.577717 | Global: 62.03 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h88 Epoch   3 [BG] | train_wall=32.99s | Loss: 1.033743 | Freq: 0.550528 | Global: 62.13 dB | MaxErr: 0.0  [New Best!]
# r3e-03-h88 Epoch   4 [BG] | train_wall=18.75s | Loss: 1.008165 | Freq: 0.535475 | Global: 62.37 dB | MaxErr: 0.0  [New Best!]
#
# r3e-03-h88 --- Experiment [BG_only] finished ---
# r3e-03-h88 --- Pure training time: 120.03 s ---
# r3e-03-h88 [timing] epochs=4 | train_wall/epoch: mean=29.87s min=18.75s max=34.67s | sum=119.47s
# r3e-03-h88 --- Best global PSNR: 62.37 dB ---
#   bg_h=88 (492,364p): PSNR=62.37 dB | CR=71.25x (base 72.43x) | +3.55 dB over SZ3
#
# ############################################################
# # rel=5e-03 | SZ3 base: CR=108.15x (39.71 MB) | base PSNR=54.94 dB
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
# r5e-03-h21 [Init] Epoch   0 | Global PSNR: 54.94 dB | MaxErr: 0.0
# r5e-03-h21 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r5e-03-h21 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r5e-03-h21 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# r5e-03-h21 Epoch   1 [BG] | train_wall=6.65s | Loss: 0.837906 | Freq: 1.539501 | Global: 56.36 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h21 [timing] first_epoch_pure_train≈7.212s (excludes this epoch's end-of-epoch eval)
# r5e-03-h21 Epoch   2 [BG] | train_wall=6.65s | Loss: 1.276366 | Freq: 0.654316 | Global: 57.08 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h21 Epoch   3 [BG] | train_wall=6.76s | Loss: 1.174710 | Freq: 0.595959 | Global: 57.30 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h21 Epoch   4 [BG] | train_wall=6.68s | Loss: 1.132547 | Freq: 0.572306 | Global: 57.47 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h21 Epoch   5 [BG] | train_wall=6.73s | Loss: 1.111149 | Freq: 0.559183 | Global: 57.46 dB | MaxErr: 0.0
# r5e-03-h21 Epoch   6 [BG] | train_wall=6.78s | Loss: 1.095672 | Freq: 0.549601 | Global: 57.61 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h21 Epoch   7 [BG] | train_wall=6.76s | Loss: 1.088019 | Freq: 0.544916 | Global: 57.68 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h21 Epoch   8 [BG] | train_wall=6.72s | Loss: 1.076624 | Freq: 0.538054 | Global: 57.64 dB | MaxErr: 0.0
# r5e-03-h21 Epoch   9 [BG] | train_wall=6.66s | Loss: 1.067499 | Freq: 0.532192 | Global: 57.69 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h21 Epoch  10 [BG] | train_wall=6.68s | Loss: 1.059175 | Freq: 0.527185 | Global: 57.79 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h21 Epoch  11 [BG] | train_wall=6.66s | Loss: 1.054959 | Freq: 0.523991 | Global: 57.71 dB | MaxErr: 0.0
# r5e-03-h21 Epoch  12 [BG] | train_wall=6.78s | Loss: 1.047529 | Freq: 0.519583 | Global: 57.79 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h21 Epoch  13 [BG] | train_wall=6.66s | Loss: 1.046271 | Freq: 0.518089 | Global: 57.78 dB | MaxErr: 0.0
# r5e-03-h21 Epoch  14 [BG] | train_wall=6.78s | Loss: 1.038605 | Freq: 0.513552 | Global: 57.83 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h21 Epoch  15 [BG] | train_wall=6.66s | Loss: 1.031246 | Freq: 0.508783 | Global: 57.76 dB | MaxErr: 0.0
# r5e-03-h21 Epoch  16 [BG] | train_wall=6.76s | Loss: 1.026509 | Freq: 0.505648 | Global: 57.75 dB | MaxErr: 0.0
# r5e-03-h21 Epoch  17 [BG] | train_wall=6.67s | Loss: 1.019534 | Freq: 0.501493 | Global: 57.80 dB | MaxErr: 0.0
# r5e-03-h21 Epoch  18 [BG] | train_wall=5.37s | Loss: 1.029328 | Freq: 0.505083 | Global: 57.96 dB | MaxErr: 0.0  [New Best!]
#
# r5e-03-h21 --- Experiment [BG_only] finished ---
# r5e-03-h21 --- Pure training time: 120.00 s ---
# r5e-03-h21 [timing] epochs=18 | train_wall/epoch: mean=6.64s min=5.37s max=6.78s | sum=119.43s
# r5e-03-h21 --- Best global PSNR: 57.96 dB ---
#   bg_h=21 (28,858p): PSNR=57.96 dB | CR=107.99x (base 108.15x) | +3.02 dB over SZ3
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
# r5e-03-h39 [Init] Epoch   0 | Global PSNR: 54.94 dB | MaxErr: 0.0
# r5e-03-h39 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r5e-03-h39 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r5e-03-h39 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# r5e-03-h39 Epoch   1 [BG] | train_wall=13.25s | Loss: 0.749536 | Freq: 1.230209 | Global: 57.11 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h39 [timing] first_epoch_pure_train≈13.810s (excludes this epoch's end-of-epoch eval)
# r5e-03-h39 Epoch   2 [BG] | train_wall=13.17s | Loss: 1.112141 | Freq: 0.557148 | Global: 57.57 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h39 Epoch   3 [BG] | train_wall=13.17s | Loss: 1.043026 | Freq: 0.517544 | Global: 57.73 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h39 Epoch   4 [BG] | train_wall=13.25s | Loss: 1.013697 | Freq: 0.499567 | Global: 57.69 dB | MaxErr: 0.0
# r5e-03-h39 Epoch   5 [BG] | train_wall=13.20s | Loss: 0.997485 | Freq: 0.489456 | Global: 57.82 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h39 Epoch   6 [BG] | train_wall=13.21s | Loss: 0.984063 | Freq: 0.481043 | Global: 57.92 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h39 Epoch   7 [BG] | train_wall=13.25s | Loss: 0.969559 | Freq: 0.471815 | Global: 57.94 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h39 Epoch   8 [BG] | train_wall=13.27s | Loss: 0.955167 | Freq: 0.462824 | Global: 58.06 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h39 Epoch   9 [BG] | train_wall=13.26s | Loss: 0.945011 | Freq: 0.455992 | Global: 58.03 dB | MaxErr: 0.0
# r5e-03-h39 Epoch  10 [BG] | train_wall=0.40s | Loss: 0.916866 | Freq: 0.480091 | Global: 58.11 dB | MaxErr: 0.0  [New Best!]
#
# r5e-03-h39 --- Experiment [BG_only] finished ---
# r5e-03-h39 --- Pure training time: 120.01 s ---
# r5e-03-h39 [timing] epochs=10 | train_wall/epoch: mean=11.94s min=0.40s max=13.27s | sum=119.44s
# r5e-03-h39 --- Best global PSNR: 58.11 dB ---
#   bg_h=39 (97,816p): PSNR=58.11 dB | CR=107.62x (base 108.15x) | +3.17 dB over SZ3
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
# r5e-03-h61 [Init] Epoch   0 | Global PSNR: 54.94 dB | MaxErr: 0.0
# r5e-03-h61 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r5e-03-h61 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r5e-03-h61 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# r5e-03-h61 Epoch   1 [BG] | train_wall=18.38s | Loss: 0.695879 | Freq: 1.060061 | Global: 57.19 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h61 [timing] first_epoch_pure_train≈18.944s (excludes this epoch's end-of-epoch eval)
# r5e-03-h61 Epoch   2 [BG] | train_wall=18.38s | Loss: 1.049654 | Freq: 0.521841 | Global: 57.79 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h61 Epoch   3 [BG] | train_wall=18.42s | Loss: 0.990604 | Freq: 0.485605 | Global: 57.85 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h61 Epoch   4 [BG] | train_wall=18.39s | Loss: 0.966139 | Freq: 0.470158 | Global: 57.95 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h61 Epoch   5 [BG] | train_wall=18.33s | Loss: 0.948073 | Freq: 0.459360 | Global: 57.82 dB | MaxErr: 0.0
# r5e-03-h61 Epoch   6 [BG] | train_wall=18.32s | Loss: 0.931664 | Freq: 0.449188 | Global: 57.89 dB | MaxErr: 0.0
# r5e-03-h61 Epoch   7 [BG] | train_wall=9.21s | Loss: 0.925083 | Freq: 0.447872 | Global: 58.34 dB | MaxErr: 0.0  [New Best!]
#
# r5e-03-h61 --- Experiment [BG_only] finished ---
# r5e-03-h61 --- Pure training time: 120.01 s ---
# r5e-03-h61 [timing] epochs=7 | train_wall/epoch: mean=17.06s min=9.21s max=18.42s | sum=119.44s
# r5e-03-h61 --- Best global PSNR: 58.34 dB ---
#   bg_h=61 (237,538p): PSNR=58.34 dB | CR=106.87x (base 108.15x) | +3.39 dB over SZ3
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
# r5e-03-h88 [Init] Epoch   0 | Global PSNR: 54.94 dB | MaxErr: 0.0
# r5e-03-h88 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r5e-03-h88 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r5e-03-h88 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# r5e-03-h88 Epoch   1 [BG] | train_wall=33.06s | Loss: 0.699001 | Freq: 1.096989 | Global: 57.49 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h88 [timing] first_epoch_pure_train≈33.626s (excludes this epoch's end-of-epoch eval)
# r5e-03-h88 Epoch   2 [BG] | train_wall=33.00s | Loss: 1.011930 | Freq: 0.499094 | Global: 57.62 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h88 Epoch   3 [BG] | train_wall=33.07s | Loss: 0.950246 | Freq: 0.459984 | Global: 57.91 dB | MaxErr: 0.0  [New Best!]
# r5e-03-h88 Epoch   4 [BG] | train_wall=20.30s | Loss: 0.928352 | Freq: 0.445754 | Global: 58.35 dB | MaxErr: 0.0  [New Best!]
#
# r5e-03-h88 --- Experiment [BG_only] finished ---
# r5e-03-h88 --- Pure training time: 120.00 s ---
# r5e-03-h88 [timing] epochs=4 | train_wall/epoch: mean=29.86s min=20.30s max=33.07s | sum=119.44s
# r5e-03-h88 --- Best global PSNR: 58.35 dB ---
#   bg_h=88 (492,364p): PSNR=58.35 dB | CR=105.53x (base 108.15x) | +3.41 dB over SZ3
#
# ############################################################
# # rel=7e-03 | SZ3 base: CR=144.55x (29.71 MB) | base PSNR=52.38 dB
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
# r7e-03-h21 [Init] Epoch   0 | Global PSNR: 52.38 dB | MaxErr: 0.0
# r7e-03-h21 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r7e-03-h21 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r7e-03-h21 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# r7e-03-h21 Epoch   1 [BG] | train_wall=6.69s | Loss: 0.833279 | Freq: 1.548176 | Global: 53.69 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h21 [timing] first_epoch_pure_train≈7.248s (excludes this epoch's end-of-epoch eval)
# r7e-03-h21 Epoch   2 [BG] | train_wall=6.65s | Loss: 1.246360 | Freq: 0.613432 | Global: 54.35 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h21 Epoch   3 [BG] | train_wall=6.71s | Loss: 1.142662 | Freq: 0.552555 | Global: 54.67 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h21 Epoch   4 [BG] | train_wall=6.68s | Loss: 1.104806 | Freq: 0.531502 | Global: 54.74 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h21 Epoch   5 [BG] | train_wall=6.66s | Loss: 1.082293 | Freq: 0.518499 | Global: 54.73 dB | MaxErr: 0.0
# r7e-03-h21 Epoch   6 [BG] | train_wall=6.70s | Loss: 1.067596 | Freq: 0.509666 | Global: 54.73 dB | MaxErr: 0.0
# r7e-03-h21 Epoch   7 [BG] | train_wall=6.74s | Loss: 1.055958 | Freq: 0.502407 | Global: 54.85 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h21 Epoch   8 [BG] | train_wall=6.71s | Loss: 1.046641 | Freq: 0.496609 | Global: 54.76 dB | MaxErr: 0.0
# r7e-03-h21 Epoch   9 [BG] | train_wall=6.72s | Loss: 1.037804 | Freq: 0.491217 | Global: 54.84 dB | MaxErr: 0.0
# r7e-03-h21 Epoch  10 [BG] | train_wall=6.66s | Loss: 1.033376 | Freq: 0.488256 | Global: 54.75 dB | MaxErr: 0.0
# r7e-03-h21 Epoch  11 [BG] | train_wall=6.77s | Loss: 1.028054 | Freq: 0.485025 | Global: 54.92 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h21 Epoch  12 [BG] | train_wall=6.73s | Loss: 1.023472 | Freq: 0.482264 | Global: 54.91 dB | MaxErr: 0.0
# r7e-03-h21 Epoch  13 [BG] | train_wall=6.71s | Loss: 1.018569 | Freq: 0.479334 | Global: 54.90 dB | MaxErr: 0.0
# r7e-03-h21 Epoch  14 [BG] | train_wall=6.78s | Loss: 1.013591 | Freq: 0.476303 | Global: 55.03 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h21 Epoch  15 [BG] | train_wall=6.77s | Loss: 1.010641 | Freq: 0.474413 | Global: 55.05 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h21 Epoch  16 [BG] | train_wall=6.67s | Loss: 1.006618 | Freq: 0.472033 | Global: 54.83 dB | MaxErr: 0.0
# r7e-03-h21 Epoch  17 [BG] | train_wall=6.67s | Loss: 1.003539 | Freq: 0.470287 | Global: 54.95 dB | MaxErr: 0.0
# r7e-03-h21 Epoch  18 [BG] | train_wall=5.40s | Loss: 1.013825 | Freq: 0.474579 | Global: 55.23 dB | MaxErr: 0.0  [New Best!]
#
# r7e-03-h21 --- Experiment [BG_only] finished ---
# r7e-03-h21 --- Pure training time: 120.01 s ---
# r7e-03-h21 [timing] epochs=18 | train_wall/epoch: mean=6.64s min=5.40s max=6.78s | sum=119.44s
# r7e-03-h21 --- Best global PSNR: 55.23 dB ---
#   bg_h=21 (28,858p): PSNR=55.23 dB | CR=144.27x (base 144.55x) | +2.85 dB over SZ3
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
# r7e-03-h39 [Init] Epoch   0 | Global PSNR: 52.38 dB | MaxErr: 0.0
# r7e-03-h39 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r7e-03-h39 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r7e-03-h39 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# r7e-03-h39 Epoch   1 [BG] | train_wall=13.17s | Loss: 0.769785 | Freq: 1.258980 | Global: 54.35 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h39 [timing] first_epoch_pure_train≈13.730s (excludes this epoch's end-of-epoch eval)
# r7e-03-h39 Epoch   2 [BG] | train_wall=13.15s | Loss: 1.090187 | Freq: 0.522469 | Global: 54.81 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h39 Epoch   3 [BG] | train_wall=13.15s | Loss: 1.022242 | Freq: 0.482586 | Global: 54.92 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h39 Epoch   4 [BG] | train_wall=13.21s | Loss: 0.997384 | Freq: 0.467377 | Global: 54.99 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h39 Epoch   5 [BG] | train_wall=13.20s | Loss: 0.985129 | Freq: 0.460375 | Global: 54.94 dB | MaxErr: 0.0
# r7e-03-h39 Epoch   6 [BG] | train_wall=13.17s | Loss: 0.972963 | Freq: 0.453108 | Global: 55.04 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h39 Epoch   7 [BG] | train_wall=13.23s | Loss: 0.961700 | Freq: 0.446653 | Global: 54.97 dB | MaxErr: 0.0
# r7e-03-h39 Epoch   8 [BG] | train_wall=13.20s | Loss: 0.950819 | Freq: 0.440565 | Global: 55.06 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h39 Epoch   9 [BG] | train_wall=13.27s | Loss: 0.946903 | Freq: 0.438442 | Global: 54.96 dB | MaxErr: 0.0
# r7e-03-h39 Epoch  10 [BG] | train_wall=0.70s | Loss: 0.905660 | Freq: 0.447555 | Global: 55.26 dB | MaxErr: 0.0  [New Best!]
#
# r7e-03-h39 --- Experiment [BG_only] finished ---
# r7e-03-h39 --- Pure training time: 120.01 s ---
# r7e-03-h39 [timing] epochs=10 | train_wall/epoch: mean=11.94s min=0.70s max=13.27s | sum=119.45s
# r7e-03-h39 --- Best global PSNR: 55.26 dB ---
#   bg_h=39 (97,816p): PSNR=55.26 dB | CR=143.61x (base 144.55x) | +2.88 dB over SZ3
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
# r7e-03-h61 [Init] Epoch   0 | Global PSNR: 52.38 dB | MaxErr: 0.0
# r7e-03-h61 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r7e-03-h61 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r7e-03-h61 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# r7e-03-h61 Epoch   1 [BG] | train_wall=18.37s | Loss: 0.710755 | Freq: 1.117655 | Global: 54.58 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h61 [timing] first_epoch_pure_train≈18.934s (excludes this epoch's end-of-epoch eval)
# r7e-03-h61 Epoch   2 [BG] | train_wall=18.42s | Loss: 1.031065 | Freq: 0.487961 | Global: 54.81 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h61 Epoch   3 [BG] | train_wall=18.37s | Loss: 0.981234 | Freq: 0.457884 | Global: 54.69 dB | MaxErr: 0.0
# r7e-03-h61 Epoch   4 [BG] | train_wall=18.38s | Loss: 0.950929 | Freq: 0.440557 | Global: 54.92 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h61 Epoch   5 [BG] | train_wall=18.36s | Loss: 0.929957 | Freq: 0.428917 | Global: 54.99 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h61 Epoch   6 [BG] | train_wall=18.36s | Loss: 0.915941 | Freq: 0.420639 | Global: 55.05 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h61 Epoch   7 [BG] | train_wall=9.18s | Loss: 0.917732 | Freq: 0.424628 | Global: 55.45 dB | MaxErr: 0.0  [New Best!]
#
# r7e-03-h61 --- Experiment [BG_only] finished ---
# r7e-03-h61 --- Pure training time: 120.01 s ---
# r7e-03-h61 [timing] epochs=7 | train_wall/epoch: mean=17.06s min=9.18s max=18.42s | sum=119.44s
# r7e-03-h61 --- Best global PSNR: 55.45 dB ---
#   bg_h=61 (237,538p): PSNR=55.45 dB | CR=142.28x (base 144.55x) | +3.08 dB over SZ3
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
# r7e-03-h88 [Init] Epoch   0 | Global PSNR: 52.38 dB | MaxErr: 0.0
# r7e-03-h88 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r7e-03-h88 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r7e-03-h88 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# r7e-03-h88 Epoch   1 [BG] | train_wall=33.02s | Loss: 0.689675 | Freq: 1.031353 | Global: 54.68 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h88 [timing] first_epoch_pure_train≈33.582s (excludes this epoch's end-of-epoch eval)
# r7e-03-h88 Epoch   2 [BG] | train_wall=33.04s | Loss: 1.002126 | Freq: 0.470943 | Global: 54.88 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h88 Epoch   3 [BG] | train_wall=33.11s | Loss: 0.950744 | Freq: 0.439730 | Global: 54.98 dB | MaxErr: 0.0  [New Best!]
# r7e-03-h88 Epoch   4 [BG] | train_wall=20.29s | Loss: 0.937624 | Freq: 0.433096 | Global: 55.55 dB | MaxErr: 0.0  [New Best!]
#
# r7e-03-h88 --- Experiment [BG_only] finished ---
# r7e-03-h88 --- Pure training time: 120.03 s ---
# r7e-03-h88 [timing] epochs=4 | train_wall/epoch: mean=29.87s min=20.29s max=33.11s | sum=119.47s
# r7e-03-h88 --- Best global PSNR: 55.55 dB ---
#   bg_h=88 (492,364p): PSNR=55.55 dB | CR=139.91x (base 144.55x) | +3.18 dB over SZ3
#
# ############################################################
# # rel=9e-03 | SZ3 base: CR=181.14x (23.71 MB) | base PSNR=50.46 dB
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
# r9e-03-h21 [Init] Epoch   0 | Global PSNR: 50.46 dB | MaxErr: 0.0
# r9e-03-h21 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r9e-03-h21 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r9e-03-h21 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# r9e-03-h21 Epoch   1 [BG] | train_wall=6.65s | Loss: 0.845010 | Freq: 1.387573 | Global: 51.66 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h21 [timing] first_epoch_pure_train≈7.213s (excludes this epoch's end-of-epoch eval)
# r9e-03-h21 Epoch   2 [BG] | train_wall=6.71s | Loss: 1.255334 | Freq: 0.606977 | Global: 52.13 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h21 Epoch   3 [BG] | train_wall=6.76s | Loss: 1.155696 | Freq: 0.546150 | Global: 52.58 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h21 Epoch   4 [BG] | train_wall=6.75s | Loss: 1.117032 | Freq: 0.523935 | Global: 52.43 dB | MaxErr: 0.0
# r9e-03-h21 Epoch   5 [BG] | train_wall=6.77s | Loss: 1.093503 | Freq: 0.509872 | Global: 52.49 dB | MaxErr: 0.0
# r9e-03-h21 Epoch   6 [BG] | train_wall=6.70s | Loss: 1.079477 | Freq: 0.501165 | Global: 52.73 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h21 Epoch   7 [BG] | train_wall=6.76s | Loss: 1.069682 | Freq: 0.495527 | Global: 52.59 dB | MaxErr: 0.0
# r9e-03-h21 Epoch   8 [BG] | train_wall=6.78s | Loss: 1.055711 | Freq: 0.487381 | Global: 52.45 dB | MaxErr: 0.0
# r9e-03-h21 Epoch   9 [BG] | train_wall=6.77s | Loss: 1.044527 | Freq: 0.481104 | Global: 52.82 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h21 Epoch  10 [BG] | train_wall=6.68s | Loss: 1.037723 | Freq: 0.477680 | Global: 52.86 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h21 Epoch  11 [BG] | train_wall=6.75s | Loss: 1.026927 | Freq: 0.471422 | Global: 52.81 dB | MaxErr: 0.0
# r9e-03-h21 Epoch  12 [BG] | train_wall=6.78s | Loss: 1.024203 | Freq: 0.469835 | Global: 52.88 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h21 Epoch  13 [BG] | train_wall=6.76s | Loss: 1.017529 | Freq: 0.466072 | Global: 52.85 dB | MaxErr: 0.0
# r9e-03-h21 Epoch  14 [BG] | train_wall=6.73s | Loss: 1.011677 | Freq: 0.462496 | Global: 52.65 dB | MaxErr: 0.0
# r9e-03-h21 Epoch  15 [BG] | train_wall=6.70s | Loss: 1.008368 | Freq: 0.460421 | Global: 53.10 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h21 Epoch  16 [BG] | train_wall=6.72s | Loss: 1.004528 | Freq: 0.457932 | Global: 52.98 dB | MaxErr: 0.0
# r9e-03-h21 Epoch  17 [BG] | train_wall=6.69s | Loss: 0.998238 | Freq: 0.455070 | Global: 52.88 dB | MaxErr: 0.0
# r9e-03-h21 Epoch  18 [BG] | train_wall=4.96s | Loss: 1.008519 | Freq: 0.459693 | Global: 53.20 dB | MaxErr: 0.0  [New Best!]
#
# r9e-03-h21 --- Experiment [BG_only] finished ---
# r9e-03-h21 --- Pure training time: 120.00 s ---
# r9e-03-h21 [timing] epochs=18 | train_wall/epoch: mean=6.64s min=4.96s max=6.78s | sum=119.43s
# r9e-03-h21 --- Best global PSNR: 53.20 dB ---
#   bg_h=21 (28,858p): PSNR=53.20 dB | CR=180.70x (base 181.14x) | +2.74 dB over SZ3
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
# r9e-03-h39 [Init] Epoch   0 | Global PSNR: 50.46 dB | MaxErr: 0.0
# r9e-03-h39 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r9e-03-h39 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r9e-03-h39 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# r9e-03-h39 Epoch   1 [BG] | train_wall=13.17s | Loss: 0.768411 | Freq: 1.197933 | Global: 52.18 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h39 [timing] first_epoch_pure_train≈13.730s (excludes this epoch's end-of-epoch eval)
# r9e-03-h39 Epoch   2 [BG] | train_wall=13.15s | Loss: 1.104900 | Freq: 0.517675 | Global: 52.75 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h39 Epoch   3 [BG] | train_wall=13.18s | Loss: 1.025035 | Freq: 0.469574 | Global: 52.86 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h39 Epoch   4 [BG] | train_wall=13.27s | Loss: 0.997443 | Freq: 0.453117 | Global: 53.02 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h39 Epoch   5 [BG] | train_wall=13.21s | Loss: 0.985518 | Freq: 0.445728 | Global: 52.92 dB | MaxErr: 0.0
# r9e-03-h39 Epoch   6 [BG] | train_wall=13.24s | Loss: 0.976172 | Freq: 0.439323 | Global: 53.05 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h39 Epoch   7 [BG] | train_wall=13.23s | Loss: 0.964886 | Freq: 0.433966 | Global: 52.93 dB | MaxErr: 0.0
# r9e-03-h39 Epoch   8 [BG] | train_wall=13.19s | Loss: 0.958616 | Freq: 0.430616 | Global: 53.01 dB | MaxErr: 0.0
# r9e-03-h39 Epoch   9 [BG] | train_wall=13.25s | Loss: 0.945872 | Freq: 0.424082 | Global: 52.89 dB | MaxErr: 0.0
# r9e-03-h39 Epoch  10 [BG] | train_wall=0.55s | Loss: 0.904957 | Freq: 0.440430 | Global: 52.52 dB | MaxErr: 0.0
#
# r9e-03-h39 --- Experiment [BG_only] finished ---
# r9e-03-h39 --- Pure training time: 120.00 s ---
# r9e-03-h39 [timing] epochs=10 | train_wall/epoch: mean=11.94s min=0.55s max=13.27s | sum=119.44s
# r9e-03-h39 --- Best global PSNR: 53.05 dB ---
#   bg_h=39 (97,816p): PSNR=53.05 dB | CR=179.66x (base 181.14x) | +2.60 dB over SZ3
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
# r9e-03-h61 [Init] Epoch   0 | Global PSNR: 50.46 dB | MaxErr: 0.0
# r9e-03-h61 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r9e-03-h61 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r9e-03-h61 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# r9e-03-h61 Epoch   1 [BG] | train_wall=18.40s | Loss: 0.711603 | Freq: 0.990692 | Global: 52.20 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h61 [timing] first_epoch_pure_train≈18.963s (excludes this epoch's end-of-epoch eval)
# r9e-03-h61 Epoch   2 [BG] | train_wall=18.39s | Loss: 1.032353 | Freq: 0.474617 | Global: 52.78 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h61 Epoch   3 [BG] | train_wall=18.42s | Loss: 0.977972 | Freq: 0.441828 | Global: 52.90 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h61 Epoch   4 [BG] | train_wall=18.35s | Loss: 0.957247 | Freq: 0.429333 | Global: 52.86 dB | MaxErr: 0.0
# r9e-03-h61 Epoch   5 [BG] | train_wall=18.37s | Loss: 0.937809 | Freq: 0.418911 | Global: 52.91 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h61 Epoch   6 [BG] | train_wall=18.33s | Loss: 0.921631 | Freq: 0.410370 | Global: 53.01 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h61 Epoch   7 [BG] | train_wall=9.19s | Loss: 0.921336 | Freq: 0.413964 | Global: 53.48 dB | MaxErr: 0.0  [New Best!]
#
# r9e-03-h61 --- Experiment [BG_only] finished ---
# r9e-03-h61 --- Pure training time: 120.01 s ---
# r9e-03-h61 [timing] epochs=7 | train_wall/epoch: mean=17.06s min=9.19s max=18.42s | sum=119.45s
# r9e-03-h61 --- Best global PSNR: 53.48 dB ---
#   bg_h=61 (237,538p): PSNR=53.48 dB | CR=177.58x (base 181.14x) | +3.02 dB over SZ3
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
# r9e-03-h88 [Init] Epoch   0 | Global PSNR: 50.46 dB | MaxErr: 0.0
# r9e-03-h88 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r9e-03-h88 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r9e-03-h88 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# r9e-03-h88 Epoch   1 [BG] | train_wall=32.98s | Loss: 0.676511 | Freq: 0.913664 | Global: 52.74 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h88 [timing] first_epoch_pure_train≈33.538s (excludes this epoch's end-of-epoch eval)
# r9e-03-h88 Epoch   2 [BG] | train_wall=33.00s | Loss: 0.997818 | Freq: 0.454088 | Global: 52.81 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h88 Epoch   3 [BG] | train_wall=33.00s | Loss: 0.952223 | Freq: 0.426477 | Global: 52.92 dB | MaxErr: 0.0  [New Best!]
# r9e-03-h88 Epoch   4 [BG] | train_wall=20.46s | Loss: 0.941201 | Freq: 0.421869 | Global: 53.48 dB | MaxErr: 0.0  [New Best!]
#
# r9e-03-h88 --- Experiment [BG_only] finished ---
# r9e-03-h88 --- Pure training time: 120.01 s ---
# r9e-03-h88 [timing] epochs=4 | train_wall/epoch: mean=29.86s min=20.46s max=33.00s | sum=119.45s
# r9e-03-h88 --- Best global PSNR: 53.48 dB ---
#   bg_h=88 (492,364p): PSNR=53.48 dB | CR=173.92x (base 181.14x) | +3.02 dB over SZ3
#
# ############################################################
# # rel=1e-02 | SZ3 base: CR=199.71x (21.51 MB) | base PSNR=49.65 dB
#
# [Model: spatial] Total Params: 28,858
#  [Params] Main (BG) Network : 28,858 parameters
# r1e-02-h21 [Init] Epoch   0 | Global PSNR: 49.65 dB | MaxErr: 0.0
# r1e-02-h21 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r1e-02-h21 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r1e-02-h21 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# r1e-02-h21 Epoch   1 [BG] | train_wall=6.66s | Loss: 0.834254 | Freq: 1.410175 | Global: 50.93 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h21 [timing] first_epoch_pure_train≈7.217s (excludes this epoch's end-of-epoch eval)
# r1e-02-h21 Epoch   2 [BG] | train_wall=6.65s | Loss: 1.213172 | Freq: 0.576546 | Global: 51.37 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h21 Epoch   3 [BG] | train_wall=6.77s | Loss: 1.115495 | Freq: 0.517063 | Global: 51.42 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h21 Epoch   4 [BG] | train_wall=6.77s | Loss: 1.089213 | Freq: 0.501957 | Global: 51.69 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h21 Epoch   5 [BG] | train_wall=6.77s | Loss: 1.070619 | Freq: 0.491388 | Global: 51.71 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h21 Epoch   6 [BG] | train_wall=6.72s | Loss: 1.057778 | Freq: 0.483677 | Global: 51.83 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h21 Epoch   7 [BG] | train_wall=6.77s | Loss: 1.046347 | Freq: 0.476814 | Global: 52.01 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h21 Epoch   8 [BG] | train_wall=6.74s | Loss: 1.038470 | Freq: 0.472204 | Global: 51.91 dB | MaxErr: 0.0
# r1e-02-h21 Epoch   9 [BG] | train_wall=6.74s | Loss: 1.032030 | Freq: 0.468689 | Global: 51.96 dB | MaxErr: 0.0
# r1e-02-h21 Epoch  10 [BG] | train_wall=6.72s | Loss: 1.025157 | Freq: 0.464510 | Global: 52.02 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h21 Epoch  11 [BG] | train_wall=6.74s | Loss: 1.019883 | Freq: 0.460852 | Global: 51.90 dB | MaxErr: 0.0
# r1e-02-h21 Epoch  12 [BG] | train_wall=6.67s | Loss: 1.015057 | Freq: 0.458160 | Global: 51.99 dB | MaxErr: 0.0
# r1e-02-h21 Epoch  13 [BG] | train_wall=6.67s | Loss: 1.009402 | Freq: 0.455301 | Global: 52.10 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h21 Epoch  14 [BG] | train_wall=6.68s | Loss: 1.006147 | Freq: 0.453773 | Global: 52.01 dB | MaxErr: 0.0
# r1e-02-h21 Epoch  15 [BG] | train_wall=6.76s | Loss: 1.003444 | Freq: 0.451759 | Global: 52.12 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h21 Epoch  16 [BG] | train_wall=6.73s | Loss: 0.999106 | Freq: 0.449606 | Global: 52.19 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h21 Epoch  17 [BG] | train_wall=6.68s | Loss: 0.996659 | Freq: 0.448053 | Global: 52.18 dB | MaxErr: 0.0
# r1e-02-h21 Epoch  18 [BG] | train_wall=5.19s | Loss: 1.005889 | Freq: 0.452346 | Global: 52.36 dB | MaxErr: 0.0  [New Best!]
#
# r1e-02-h21 --- Experiment [BG_only] finished ---
# r1e-02-h21 --- Pure training time: 120.00 s ---
# r1e-02-h21 [timing] epochs=18 | train_wall/epoch: mean=6.64s min=5.19s max=6.77s | sum=119.43s
# r1e-02-h21 --- Best global PSNR: 52.36 dB ---
#   bg_h=21 (28,858p): PSNR=52.36 dB | CR=199.18x (base 199.71x) | +2.70 dB over SZ3
#
# [Model: spatial] Total Params: 97,816
#  [Params] Main (BG) Network : 97,816 parameters
# r1e-02-h39 [Init] Epoch   0 | Global PSNR: 49.65 dB | MaxErr: 0.0
# r1e-02-h39 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r1e-02-h39 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r1e-02-h39 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# r1e-02-h39 Epoch   1 [BG] | train_wall=13.27s | Loss: 0.755400 | Freq: 1.170788 | Global: 51.21 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h39 [timing] first_epoch_pure_train≈13.837s (excludes this epoch's end-of-epoch eval)
# r1e-02-h39 Epoch   2 [BG] | train_wall=13.19s | Loss: 1.102651 | Freq: 0.509907 | Global: 51.75 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h39 Epoch   3 [BG] | train_wall=13.17s | Loss: 1.039094 | Freq: 0.472376 | Global: 51.83 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h39 Epoch   4 [BG] | train_wall=13.22s | Loss: 1.010703 | Freq: 0.455395 | Global: 51.81 dB | MaxErr: 0.0
# r1e-02-h39 Epoch   5 [BG] | train_wall=13.26s | Loss: 0.995845 | Freq: 0.446352 | Global: 51.88 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h39 Epoch   6 [BG] | train_wall=13.23s | Loss: 0.983391 | Freq: 0.439137 | Global: 51.53 dB | MaxErr: 0.0
# r1e-02-h39 Epoch   7 [BG] | train_wall=13.22s | Loss: 0.968834 | Freq: 0.431396 | Global: 51.94 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h39 Epoch   8 [BG] | train_wall=13.27s | Loss: 0.959153 | Freq: 0.426208 | Global: 52.07 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h39 Epoch   9 [BG] | train_wall=13.24s | Loss: 0.951791 | Freq: 0.422009 | Global: 52.19 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h39 Epoch  10 [BG] | train_wall=0.35s | Loss: 0.937837 | Freq: 0.452619 | Global: 51.88 dB | MaxErr: 0.0
#
# r1e-02-h39 --- Experiment [BG_only] finished ---
# r1e-02-h39 --- Pure training time: 120.01 s ---
# r1e-02-h39 [timing] epochs=10 | train_wall/epoch: mean=11.94s min=0.35s max=13.27s | sum=119.43s
# r1e-02-h39 --- Best global PSNR: 52.19 dB ---
#   bg_h=39 (97,816p): PSNR=52.19 dB | CR=197.91x (base 199.71x) | +2.53 dB over SZ3
#
# [Model: spatial] Total Params: 237,538
#  [Params] Main (BG) Network : 237,538 parameters
# r1e-02-h61 [Init] Epoch   0 | Global PSNR: 49.65 dB | MaxErr: 0.0
# r1e-02-h61 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r1e-02-h61 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r1e-02-h61 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# r1e-02-h61 Epoch   1 [BG] | train_wall=18.41s | Loss: 0.729496 | Freq: 1.020998 | Global: 51.37 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h61 [timing] first_epoch_pure_train≈18.966s (excludes this epoch's end-of-epoch eval)
# r1e-02-h61 Epoch   2 [BG] | train_wall=18.44s | Loss: 1.052020 | Freq: 0.480450 | Global: 51.85 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h61 Epoch   3 [BG] | train_wall=18.35s | Loss: 0.997703 | Freq: 0.448074 | Global: 51.97 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h61 Epoch   4 [BG] | train_wall=18.40s | Loss: 0.965843 | Freq: 0.429653 | Global: 51.89 dB | MaxErr: 0.0
# r1e-02-h61 Epoch   5 [BG] | train_wall=18.34s | Loss: 0.945729 | Freq: 0.418768 | Global: 52.00 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h61 Epoch   6 [BG] | train_wall=18.34s | Loss: 0.934845 | Freq: 0.412609 | Global: 52.03 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h61 Epoch   7 [BG] | train_wall=9.15s | Loss: 0.934000 | Freq: 0.416962 | Global: 52.56 dB | MaxErr: 0.0  [New Best!]
#
# r1e-02-h61 --- Experiment [BG_only] finished ---
# r1e-02-h61 --- Pure training time: 120.00 s ---
# r1e-02-h61 [timing] epochs=7 | train_wall/epoch: mean=17.06s min=9.15s max=18.44s | sum=119.44s
# r1e-02-h61 --- Best global PSNR: 52.56 dB ---
#   bg_h=61 (237,538p): PSNR=52.56 dB | CR=195.39x (base 199.71x) | +2.91 dB over SZ3
#
# [Model: spatial] Total Params: 492,364
#  [Params] Main (BG) Network : 492,364 parameters
# r1e-02-h88 [Init] Epoch   0 | Global PSNR: 49.65 dB | MaxErr: 0.0
# r1e-02-h88 [plan] pure_train_budget=120.00s | epochs_cap=200 | steps/epoch=1024 | patch=1024 | batch=1 | sample=sequential | data_parallel=False | amp=bf16
# r1e-02-h88 [early-stop] DISABLED (cfg.bg_early_stop is False/unset)
# r1e-02-h88 [gpu-sampling] 1 fields resident on cuda:0 (~8.6 GB)
# r1e-02-h88 Epoch   1 [BG] | train_wall=33.03s | Loss: 0.687685 | Freq: 0.930618 | Global: 51.67 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h88 [timing] first_epoch_pure_train≈33.594s (excludes this epoch's end-of-epoch eval)
# r1e-02-h88 Epoch   2 [BG] | train_wall=33.08s | Loss: 1.001837 | Freq: 0.450302 | Global: 51.86 dB | MaxErr: 0.0  [New Best!]
# r1e-02-h88 Epoch   3 [BG] | train_wall=33.06s | Loss: 0.953256 | Freq: 0.421770 | Global: 51.70 dB | MaxErr: 0.0
# r1e-02-h88 Epoch   4 [BG] | train_wall=20.28s | Loss: 0.944196 | Freq: 0.418109 | Global: 52.59 dB | MaxErr: 0.0  [New Best!]
#
# r1e-02-h88 --- Experiment [BG_only] finished ---
# r1e-02-h88 --- Pure training time: 120.01 s ---
# r1e-02-h88 [timing] epochs=4 | train_wall/epoch: mean=29.86s min=20.28s max=33.08s | sum=119.45s
# r1e-02-h88 --- Best global PSNR: 52.59 dB ---
#   bg_h=88 (492,364p): PSNR=52.59 dB | CR=190.97x (base 199.71x) | +2.93 dB over SZ3
#
# --- Sweep complete in 96.1 min (20 models over 5 rel-errors) ---

# %%
fig, ax = plt.subplots(figsize=(10, 6.5))

# One curve per model size; points span the rel_err sweep (-> CR axis)
param_sizes = sorted(set(r["n_params"] for r in results))

# 【改动 1：避免黄色】
cmap = plt.cm.viridis
# 乘以 0.75，把取值范围限制在 [0, 0.75]，避开 viridis 末端的亮黄色
colors = {p: cmap((i / max(1, len(param_sizes) - 1)) * 0.75) for i, p in enumerate(param_sizes)}

# Distinct marker shape + line style per curve (cycled if there are more curves)
MARKERS = ["o", "s", "^", "D", "v", "P", "X", "*", "<", ">", "h", "p"]
LINESTYLES = ["-", "--", "-.", ":", (0, (3, 1, 1, 1)), (0, (5, 1)), (0, (1, 1))]

def fmt_p(p):
    return f"{p/1000:.0f}k" if p >= 1000 else str(p)

for i, p in enumerate(param_sizes):
    pts = sorted([r for r in results if r["n_params"] == p], key=lambda r: r["cr"])
    ax.plot([r["cr"] for r in pts], [r["psnr"] for r in pts],
            marker=MARKERS[i % len(MARKERS)],
            linestyle=LINESTYLES[i % len(LINESTYLES)],
            color=colors[p], 
            
            # 【改动 2：空心 + 放大 marker】
            markerfacecolor='none',  # 空心填充
            markeredgewidth=2.0,     # 边缘稍微加粗，让空心形状更清晰
            markersize=12,           # 放大 marker (原本是 7)
            
            linewidth=1.8, zorder=3,
            label=f"{fmt_p(p)} params")

# SZ3-only baseline curve
bl = sorted(baselines, key=lambda b: b["cr"])
ax.plot([b["cr"] for b in bl], [b["psnr"] for b in bl],
        marker="*", linestyle=(0, (4, 2)), color="black",
        markersize=15, linewidth=1.6, zorder=2,      # 这里的 baseline 也适当放大了 (从 10 变成 15)
        label="SZ3 only (no model)")

ax.set_xlabel("Compression Ratio", fontsize=25)
ax.set_ylabel("PSNR (dB)", fontsize=25)
ax.tick_params(axis='both', which='major', labelsize=25)

ax.grid(True, alpha=0.35)
ax.legend(loc="best", fontsize=15, title="model size", title_fontsize=15)
plt.tight_layout()
out_pdf = f"psnr_vs_cr_relsweep_{TARGET_STEM}.pdf"
plt.savefig(out_pdf, dpi=150, bbox_inches="tight")
plt.show()
print(f"Saved: {out_pdf}")

# Full table to stdout so every (rel, params) value is visible
print(f"\n{'rel':>7} {'bg_h':>5} {'params':>10} {'PSNR(dB)':>9} {'CR':>8} "
      f"{'baseCR':>8} {'+dB':>7} {'epochs':>7}")
base_by_rel = {b['rel']: b for b in baselines}
for r in sorted(results, key=lambda r: (r['rel'], r['n_params'])):
    b = base_by_rel[r['rel']]
    print(f"{r['rel']:>7.0e} {r['bg_h']:>5} {r['n_params']:>10,} {r['psnr']:>9.2f} "
          f"{r['cr']:>8.2f} {b['cr']:>8.2f} {r['psnr']-b['psnr']:>7.2f} {r['epochs']:>7}")
# Out:
# Saved: psnr_vs_cr_relsweep_miranda.pdf
#
#     rel  bg_h     params  PSNR(dB)       CR   baseCR     +dB  epochs
#   3e-03    21     28,858     62.10    72.36    72.43    3.27      18
#   3e-03    39     97,816     62.31    72.19    72.43    3.48       9
#   3e-03    61    237,538     62.39    71.85    72.43    3.57       7
#   3e-03    88    492,364     62.37    71.25    72.43    3.55       4
#   5e-03    21     28,858     57.96   107.99   108.15    3.02      18
#   5e-03    39     97,816     58.11   107.62   108.15    3.17      10
#   5e-03    61    237,538     58.34   106.87   108.15    3.39       7
#   5e-03    88    492,364     58.35   105.53   108.15    3.41       4
#   7e-03    21     28,858     55.23   144.27   144.55    2.85      18
#   7e-03    39     97,816     55.26   143.61   144.55    2.88      10
#   7e-03    61    237,538     55.45   142.28   144.55    3.08       7
#   7e-03    88    492,364     55.55   139.91   144.55    3.18       4
#   9e-03    21     28,858     53.20   180.70   181.14    2.74      18
#   9e-03    39     97,816     53.05   179.66   181.14    2.60      10
#   9e-03    61    237,538     53.48   177.58   181.14    3.02       7
#   9e-03    88    492,364     53.48   173.92   181.14    3.02       4
#   1e-02    21     28,858     52.36   199.18   199.71    2.70      18
#   1e-02    39     97,816     52.19   197.91   199.71    2.53      10
#   1e-02    61    237,538     52.56   195.39   199.71    2.91       7
#   1e-02    88    492,364     52.59   190.97   199.71    2.93       4
